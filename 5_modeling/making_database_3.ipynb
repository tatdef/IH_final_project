# %% [markdown]
# ## Importing information

# %%
import pandas as pd
import json
import numpy as np
import os

# %%
def create_profile(x, url):
    with open(str(url)+str(x)) as f:
        dict1 = json.load(f)
    list_col= ['experience', 'education', 'languages','languages','publications', 'certifications','volunteer', 'honors', 'projects']
    for n in list_col:
        if n in dict1:
            for i in range(len(dict1[n])): 
                dict1[str(n+str(i+1))]= dict1[n][i]
    data = pd.DataFrame.from_dict(dict1, orient='index').T
    return data

# %%
file_list = [f for f in os.listdir('../data/jsons') if f.endswith(".json")]
len(file_list)
# Out:
# 49

# %%
initial_profile=create_profile('brachetantoine.json', '../data/jsons/')

# %%
profiles = initial_profile
for i in file_list:
    a= create_profile(i, '../data/jsons/')
    profiles= pd.concat((profiles,a),axis=0)

# %%
file_list2 = [f for f in os.listdir('../data/jsons2') if f.endswith(".json")]
len(file_list2)
# Out:
# 124

# %%
profiles2 = initial_profile
for i in file_list2:
    a= create_profile(i,'../data/jsons2/')
    profiles2= pd.concat((profiles2,a),axis=0)

# %%
data=pd.concat([profiles, profiles2]).reset_index(drop=True)
data.head(2)
# Out:
#                                              summary  \
# 0  Antoine croit à l’intelligence de tous et à la...
# 1  French Entrepreneur - Founder and Managing Par...
#
#                                     industryName lastName student  \
# 0                  IT Services and IT Consulting  Brachet   False
# 1  Venture Capital and Private Equity Principals    Demri   False
#
#   geoCountryName            geoCountryUrn geoLocationBackfilled    elt  \
# 0         France  urn:li:fs_geo:105015875                 False  False
# 1         France  urn:li:fs_geo:105015875                 False  False
#
#               industryUrn firstName  ... publications9 publications10  \
# 0   urn:li:fs_industry:96   Antoine  ...           NaN            NaN
# 1  urn:li:fs_industry:106     Bobby  ...           NaN            NaN
#
#   maidenName projects8 certifications5 certifications6 certifications7  \
# 0        NaN       NaN             NaN             NaN             NaN
# 1        NaN       NaN             NaN             NaN             NaN
#
#   certifications8 certifications9 certifications10
# 0             NaN             NaN              NaN
# 1             NaN             NaN              NaN
#
# [2 rows x 89 columns]

# %% [markdown]
# ## Initial dataset cleaning

# %%
data.shape
# Out:
# (173, 89)

# %%
print(list(data.columns))
# Out:
# ['summary', 'industryName', 'lastName', 'student', 'geoCountryName', 'geoCountryUrn', 'geoLocationBackfilled', 'elt', 'industryUrn', 'firstName', 'entityUrn', 'geoLocation', 'geoLocationName', 'location', 'headline', 'displayPictureUrl', 'img_100_100', 'img_200_200', 'img_400_400', 'img_800_800', 'profile_id', 'profile_urn', 'member_urn', 'public_id', 'experience', 'education', 'languages', 'publications', 'certifications', 'volunteer', 'honors', 'projects', 'experience1', 'experience2', 'experience3', 'experience4', 'experience5', 'education1', 'education2', 'education3', 'languages1', 'languages2', 'languages3', 'publications1', 'publications2', 'publications3', 'publications4', 'publications5', 'publications6', 'publications7', 'publications8', 'locationName', 'honors1', 'honors2', 'honors3', 'honors4', 'honors5', 'honors6', 'honors7', 'volunteer1', 'volunteer2', 'volunteer3', 'projects1', 'projects2', 'projects3', 'birthDate', 'languages4', 'projects4', 'projects5', 'address', 'languages5', 'languages6', 'certifications1', 'projects6', 'projects7', 'certifications2', 'certifications3', 'certifications4', 'languages7', 'publications9', 'publications10', 'maidenName', 'projects8', 'certifications5', 'certifications6', 'certifications7', 'certifications8', 'certifications9', 'certifications10']

# %% [markdown]
# ### Drop duplicates in rows

# %%
mask = data.duplicated(subset=['headline', 'firstName', 'lastName'], keep='first')
dropped = data.loc[mask]
dropped
# Out:
#                                               summary  \
# 3   Antoine croit à l’intelligence de tous et à la...
# 48  Antoine croit à l’intelligence de tous et à la...
# 50  French Entrepreneur - Founder and Managing Par...
# 51  Inspired by the power we can build to change t...
# 84                                                NaN
#
#                                      industryName lastName student  \
# 3                   IT Services and IT Consulting  Brachet   False
# 48                  IT Services and IT Consulting  Brachet   False
# 50  Venture Capital and Private Equity Principals    Demri   False
# 51                 Civic and Social Organizations  Durieux   False
# 84                                       Internet    Paret   False
#
#    geoCountryName            geoCountryUrn geoLocationBackfilled    elt  \
# 3          France  urn:li:fs_geo:105015875                 False  False
# 48         France  urn:li:fs_geo:105015875                 False  False
# 50         France  urn:li:fs_geo:105015875                 False  False
# 51         France  urn:li:fs_geo:105015875                 False  False
# 84         France  urn:li:fs_geo:105015875                 False   True
#
#                industryUrn firstName  ... publications9 publications10  \
# 3    urn:li:fs_industry:96   Antoine  ...           NaN            NaN
# 48   urn:li:fs_industry:96   Antoine  ...           NaN            NaN
# 50  urn:li:fs_industry:106     Bobby  ...           NaN            NaN
# 51   urn:li:fs_industry:90     Sarah  ...           NaN            NaN
# 84    urn:li:fs_industry:6   Jeremie  ...           NaN            NaN
#
#    maidenName projects8 certifications5 certifications6 certifications7  \
# 3         NaN       NaN             NaN             NaN             NaN
# 48        NaN       NaN             NaN             NaN             NaN
# 50        NaN       NaN             NaN             NaN             NaN
# 51        NaN       NaN             NaN             NaN             NaN
# 84        NaN       NaN             NaN             NaN             NaN
#
#    certifications8 certifications9 certifications10
# 3              NaN             NaN              NaN
# 48             NaN             NaN              NaN
# 50             NaN             NaN              NaN
# 51             NaN             NaN              NaN
# 84             NaN             NaN              NaN
#
# [5 rows x 89 columns]

# %%
data.drop_duplicates(subset=['headline', 'firstName', 'lastName'], keep='first', inplace=True)

# %% [markdown]
# ### Dropping unnecessary columns (specific to LIn, personal information, etc.)

# %%
pd.options.display.max_rows = 100

# %%
todrop=['industryName', 'experience', 'education', 'languages','languages','publications', 
        'certifications','volunteer', 'honors', 'projects', 
        'displayPictureUrl', 'img_100_100', 'img_200_200', 'img_400_400', 
        'img_800_800', 'student', 'maidenName', 'birthDate', 
        'address','geoCountryUrn', 'geoLocationBackfilled', 'elt', 'industryUrn',
        'entityUrn', 'geoLocation', 'location', 'locationName', 
        'profile_id', 'profile_urn', 'member_urn', 'public_id']
data.drop(columns=todrop, inplace=True)

# %%
data.describe().T.sort_index()
# Out:
#                  count unique  \
# certifications1     42     42
# certifications10     3      3
# certifications2     21     21
# certifications3     12     12
# certifications4      7      7
# certifications5      6      6
# certifications6      6      6
# certifications7      6      6
# certifications8      4      4
# certifications9      4      4
# education1         161    161
# education2         145    145
# education3         120    120
# experience1        167    167
# experience2        162    162
# experience3        161    161
# experience4        157    157
# experience5        150    150
# firstName          168    123
# geoCountryName     166      3
# geoLocationName    141     37
# headline           167    167
# honors1             31     31
# honors2             20     20
# honors3             11     11
# honors4              9      9
# honors5              7      7
# honors6              6      6
# honors7              2      2
# languages1         118     32
# languages2         109     32
# languages3          93     43
# languages4          49     34
# languages5          22     17
# languages6           7      7
# languages7           2      2
# lastName           168    154
# projects1           48     48
# projects2           31     31
# projects3           20     20
# projects4           14     14
# projects5           10     10
# projects6            4      4
# projects7            4      4
# projects8            1      1
# publications1       63     63
# publications10      13     13
# publications2       46     46
# publications3       38     38
# publications4       37     37
# publications5       28     28
# publications6       25     25
# publications7       21     21
# publications8       18     18
# publications9       16     16
# summary            108    108
# volunteer1          75     75
# volunteer2          63     63
# volunteer3          43     43
#
#                                                                 top freq
# certifications1                              {'name': 'Psychology'}    1
# certifications10  {'authority': 'LinkedIn', 'name': 'Project Man...    1
# certifications2   {'authority': 'OpenClassrooms', 'name': 'Learn...    1
# certifications3   {'authority': 'COLIBRIS', 'name': 'Quelle démo...    1
# certifications4   {'authority': 'A Cloud Guru', 'name': 'Introdu...    1
# certifications5   {'authority': 'Google', 'name': 'Google Ads Ce...    1
# certifications6   {'authority': 'Google', 'name': 'Certification...    1
# certifications7   {'authority': 'HubSpot', 'name': 'Hubspot Inbo...    1
# certifications8   {'authority': 'LinkedIn', 'name': 'Become an H...    1
# certifications9   {'authority': 'ETS Global', 'name': 'TOEIC', '...    1
# education1        {'entityUrn': 'urn:li:fs_education:(ACoAAAA615...    1
# education2        {'entityUrn': 'urn:li:fs_education:(ACoAAAA615...    1
# education3        {'entityUrn': 'urn:li:fs_education:(ACoAAAA615...    1
# experience1       {'locationName': 'Paris Area, France', 'entity...    1
# experience2       {'entityUrn': 'urn:li:fs_position:(ACoAAAA615E...    1
# experience3       {'locationName': 'Paris', 'entityUrn': 'urn:li...    1
# experience4       {'locationName': 'Paris Area, France', 'entity...    1
# experience5       {'locationName': 'Paris', 'entityUrn': 'urn:li...    1
# firstName                                                   Nicolas    6
# geoCountryName                                               France  159
# geoLocationName                                Paris, Île-de-France   58
# headline          Directeur associé de bluenove, initiateur du m...    1
# honors1           {'description': 'THE WEBBY AWARDS IS THE LEADI...    1
# honors2           {'description': 'The leading international awa...    1
# honors3           {'description': 'Eurobest is the world's pre-e...    1
# honors4           {'description': 'The London International Awar...    1
# honors5           {'description': 'Le Grand Prix de l’Innovation...    1
# honors6           {'description': 'The Cannes Lions Internationa...    1
# honors7           {'description': 'The Cannes Lions Internationa...    1
# languages1        {'name': 'English', 'proficiency': 'FULL_PROFE...   19
# languages2        {'name': 'French', 'proficiency': 'NATIVE_OR_B...   28
# languages3        {'name': 'Français', 'proficiency': 'NATIVE_OR...   32
# languages4        {'name': 'Français', 'proficiency': 'NATIVE_OR...    8
# languages5        {'name': 'Espagnol', 'proficiency': 'FULL_PROF...    2
# languages6         {'name': 'Spanish', 'proficiency': 'ELEMENTARY'}    1
# languages7         {'name': 'Italien', 'proficiency': 'ELEMENTARY'}    1
# lastName                                                    Coutant    2
# projects1         {'members': [{'member': {'firstName': 'Bastien...    1
# projects2         {'members': [{'member': {'firstName': 'Bastien...    1
# projects3         {'members': [{'member': {'firstName': 'Coline'...    1
# projects4         {'occupation': 'urn:li:fs_position:(ACoAAABaH0...    1
# projects5         {'occupation': 'urn:li:fs_position:(ACoAAABaH0...    1
# projects6         {'occupation': 'urn:li:fs_position:(ACoAAAfEoR...    1
# projects7         {'occupation': 'urn:li:fs_position:(ACoAAAfEoR...    1
# projects8         {'occupation': 'urn:li:fs_position:(ACoAAAMqDL...    1
# publications1     {'date': {'month': 9, 'year': 2017, 'day': 1},...    1
# publications10    {'date': {'year': 2012}, 'name': '"Les Politiq...    1
# publications2     {'date': {'month': 3, 'year': 2016, 'day': 1},...    1
# publications3     {'date': {'month': 6, 'year': 2014, 'day': 30}...    1
# publications4     {'date': {'month': 6, 'year': 2014, 'day': 11}...    1
# publications5     {'date': {'month': 4, 'year': 2014, 'day': 22}...    1
# publications6     {'date': {'month': 9, 'year': 2006, 'day': 25}...    1
# publications7     {'name': 'Mes Contributions dans le Huffington...    1
# publications8     {'name': 'Mes contributions dans lePlus de l'O...    1
# publications9     {'date': {'year': 2013}, 'name': 'Qué Politica...    1
# summary           Antoine croit à l’intelligence de tous et à la...    1
# volunteer1        {'role': 'Co-Founder', 'companyName': 'Collect...    1
# volunteer2        {'role': 'Board Member', 'companyName': 'Empow...    1
# volunteer3        {'role': 'Co-founder', 'companyName': 'Rencont...    1

# %% [markdown]
# ### Exploding columns

# %%
# there must be a more functional way to do what is happening below
# but i'm too tired :)

# %%
for i in range (1,4): 
    data=pd.concat([data, 
    pd.DataFrame(data['education'+str(i)].apply(pd.Series)).add_prefix('ed_'+str(i)), 
    pd.DataFrame(data['volunteer'+str(i)].apply(pd.Series)).add_prefix('vol_'+str(i))], 
    axis=1).reset_index(drop=True)
    data.drop(columns=['education'+str(i),'volunteer'+str(i)], inplace=True)

# %%
for i in range (1,6): 
    data=pd.concat([data, 
    pd.DataFrame(data['experience'+str(i)].apply(pd.Series)).add_prefix('exp_'+str(i))], 
    axis=1).reset_index(drop=True)
    data.drop(columns='experience'+str(i), inplace=True)

# %%
for i in range (1,8): 
    data=pd.concat([data, 
    pd.DataFrame(data['honors'+str(i)].apply(pd.Series)).add_prefix('hon_'+str(i)), 
    pd.DataFrame(data['languages'+str(i)].apply(pd.Series)).add_prefix('lang_'+str(i))], 
    axis=1).reset_index(drop=True)
    data.drop(columns=['honors'+str(i),'languages'+str(i)], inplace=True)

# %%
for i in range (1,9): 
    data=pd.concat([data, 
    pd.DataFrame(data['projects'+str(i)].apply(pd.Series)).add_prefix('proj_'+str(i))], 
    axis=1).reset_index(drop=True)
    data.drop(columns='projects'+str(i), inplace=True)

# %%
for i in range (1,11): 
    data=pd.concat([data, 
    pd.DataFrame(data['certifications'+str(i)].apply(pd.Series)).add_prefix('cert_'+str(i)), 
    pd.DataFrame(data['publications'+str(i)].apply(pd.Series)).add_prefix('pub_'+str(i))], 
    axis=1).reset_index(drop=True)
    data.drop(columns=['certifications'+str(i),'publications'+str(i)], inplace=True)

# %%
list_columns=[i for i in data.columns if ("Urn" in i or "Logo" in i or "_region" in i or '_abuse' in i or '_geo' in i or '_proj' in i or '_organi' in i or '_0' in i)]
#to check before dropping 
data[list_columns].T
data.drop(columns=list_columns, inplace=True)

# %% [markdown]
# ### We seem to still have duplicates

# %%
print(sorted(list(data.lastName.str.lower())))
# Out:
# ['albet', 'alemanno', 'ami', 'andré', 'arrouard', 'auclair', 'auclair', 'baillot', 'banzet', 'barbaut', 'barbero', 'barbier', 'barre', 'bauquet', 'behar', 'behar', 'benkirane', 'bensa', 'berenguer-moncada', 'bertrand', 'bertrand', 'bessoles', 'besson', 'besson', 'bianchin-fabre', 'bloch', 'bouché', 'boudehen', 'bourlitio', 'brachet', 'briante guillemont', 'buchotte', 'bézard', 'canivet', 'chadenet', 'chaput', 'chatellier', 'chaygneaud-dupuy', 'chevallereau', 'choisne', 'claret', 'cochin', 'colas', 'colas', 'colombe', 'combaz', 'coudard', 'coutant', 'coutant', 'd', 'd.', 'daniel', 'daniel', 'dardier', 'dauchez', 'de bodman', 'de briey', 'de marignan', 'de pimodan', 'de roquefeuil', 'de royer', 'de sousa', 'de sousa', 'deffrennes', 'deleris', 'deleris', 'dembele', 'demri', 'demri', 'dernoncourt', 'des gachons', 'desmaison', 'deville', 'diguet', 'dubreuil', 'dubreuil', 'duguet', 'duperthuy', 'durieux', 'duriez', 'duriez', 'duval', 'désigaud', 'désigaud', 'escoubes', 'eve', 'forest', 'fox', 'françois', 'gabadou santiago', 'gaboriau', 'garnier-nguyen', 'gautier', 'gille', 'gilles', 'gombert', 'goujon', 'gresset', 'grunelius', 'guimas', 'hanson', 'haro', 'jachiet', 'jaillot', 'japiot', 'kergall', 'kergall', 'kleck casalegno', 'kumpf', 'l.', 'l.', 'lacot', 'lage', 'larroque', 'lavayssière', 'le botlan', 'le masne', 'le roux', 'le roux', 'lecourtois', 'legros', 'legros', 'lenoir', 'lenoir', 'levoir', 'levoir', 'liot', 'mabi', 'marchandise ', 'mateus', 'mcgrath-dehecq', 'medrinal', 'meiss', 'miailhe', 'monclaire', 'noury', 'pahud', 'paret', 'patte', 'pelissard', 'piekarski', 'pignal 🌍', 'pleurmeau', 'pons', 'pouyé', 'pulicani', 'pène', 'reboux', 'richard', 'richer', 'rosado', 'roudaut', 'rozier', 'santiso', 'schlumberger', 'schwab', 'snow', 'sotiropoulou', 'stefani', 'teulié', 'trèves', 'trèves', 'van brussel', 'vanneroy', 'vaturi', 'vignolles', 'walbaum', 'zylberberg']

# %%
(data.loc[(data.lastName.str.lower()=="auclair")|(data.lastName.str.lower()=="behar")|(data.lastName.str.lower()=="bertrand")|(data.lastName.str.lower()=="besson")|(data.lastName.str.lower()=="colas")|(data.lastName.str.lower()=="coutant")|(data.lastName.str.lower()=="daniel")|(data.lastName.str.lower()=="de sousa")|(data.lastName.str.lower()=="deleris")|(data.lastName.str.lower()=="demri")|(data.lastName.str.lower()=="dubreuil")|(data.lastName.str.lower()=="duriez")|(data.lastName.str.lower()=="désigaud")|(data.lastName.str.lower()=="kergall")|(data.lastName.str.lower()=="l.")|(data.lastName.str.lower()=="le roux")|(data.lastName.str.lower()=="legros")|(data.lastName.str.lower()=="lenoir")|(data.lastName.str.lower()=="levoir")|(data.lastName.str.lower()=="trèves")])[["firstName", "lastName"]].sort_values(by="firstName")
data.drop(labels=[69, 121, 161, 82, 84, 93, 116,147,153,106,64,113,166,128,124,50,67,163, 150,157], axis=0, inplace=True)

# %% [markdown]
# ### Dropping columns with too many missing values

# %%
a= list(data.columns)
a.sort()
data= data[a]

# %%
nullvalues=pd.DataFrame(data.isna().sum().sort_values(ascending=False))

# %%
print(list(nullvalues.index)[0:50])
# Out:
# ['cert_10', 'cert_60', 'proj_40', 'proj_50', 'exp_20', 'proj_60', 'exp_10', 'proj_70', 'ed_30', 'cert_100', 'ed_20', 'pub_10', 'pub_100', 'pub_20', 'pub_30', 'pub_40', 'ed_10', 'cert_90', 'cert_80', 'proj_30', 'proj_20', 'proj_10', 'exp_50', 'hon_30', 'hon_40', 'hon_20', 'hon_50', 'hon_10', 'hon_60', 'hon_70', 'lang_10', 'exp_30', 'lang_20', 'lang_30', 'exp_40', 'lang_40', 'lang_50', 'lang_60', 'lang_70', 'cert_70', 'proj_80', 'cert_40', 'pub_70', 'vol_30', 'vol_20', 'pub_90', 'pub_80', 'cert_20', 'vol_10', 'cert_50']

# %%
data.shape
# Out:
# (148, 395)

# %%
data.reset_index(inplace=True)
data.set_index("index")
# Out:
#        cert_10  cert_100 cert_10authority cert_10company cert_10displaySource  \
# index
# 0          NaN       NaN              NaN            NaN                  NaN
# 1          NaN       NaN              NaN            NaN                  NaN
# 2          NaN       NaN              NaN            NaN                  NaN
# 3          NaN       NaN              NaN            NaN                  NaN
# 4          NaN       NaN              NaN            NaN                  NaN
# ...        ...       ...              ...            ...                  ...
# 160        NaN       NaN              NaN            NaN                  NaN
# 162        NaN       NaN              NaN            NaN                  NaN
# 164        NaN       NaN              NaN            NaN                  NaN
# 165        NaN       NaN              NaN            NaN                  NaN
# 167        NaN       NaN              NaN            NaN                  NaN
#
#       cert_10licenseNumber cert_10name cert_10timePeriod cert_10url  \
# index
# 0                      NaN         NaN               NaN        NaN
# 1                      NaN         NaN               NaN        NaN
# 2                      NaN         NaN               NaN        NaN
# 3                      NaN         NaN               NaN        NaN
# 4                      NaN         NaN               NaN        NaN
# ...                    ...         ...               ...        ...
# 160                    NaN         NaN               NaN        NaN
# 162                    NaN         NaN               NaN        NaN
# 164                    NaN         NaN               NaN        NaN
# 165                    NaN         NaN               NaN        NaN
# 167                    NaN         NaN               NaN        NaN
#
#                                  cert_1authority  ...  \
# index                                             ...
# 0                                            NaN  ...
# 1                                            NaN  ...
# 2                                            NaN  ...
# 3                                            NaN  ...
# 4                                            NaN  ...
# ...                                          ...  ...
# 160                                          NaN  ...
# 162    Ministère chargé de l'Éducation nationale  ...
# 164                                          NaN  ...
# 165                                          NaN  ...
# 167                                          NaN  ...
#
#                                         vol_2description  \
# index
# 0                                                    NaN
# 1                                                    NaN
# 2      Empow’her supports  women entrepreneurs so the...
# 3                                                    NaN
# 4      Électeurs en herbe est un programme d'éducatio...
# ...                                                  ...
# 160                                                  NaN
# 162                                                  NaN
# 164                                                  NaN
# 165                                                  NaN
# 167    La mission de DemocracyOS France :\n- Accompag...
#
#                    vol_2role  \
# index
# 0                        NaN
# 1                        NaN
# 2               Board Member
# 3                        NaN
# 4      Présidente-fondatrice
# ...                      ...
# 160     Animateur d’ateliers
# 162                      NaN
# 164                      NaN
# 165                      NaN
# 167     Membre et trésorière
#
#                                          vol_2timePeriod vol_30 vol_3cause  \
# index
# 0                                                    NaN    NaN        NaN
# 1                                                    NaN    NaN        NaN
# 2      {'endDate': {'month': 3, 'year': 2021}, 'start...    NaN        NaN
# 3                                                    NaN    NaN        NaN
# 4              {'startDate': {'month': 7, 'year': 2016}}    NaN        NaN
# ...                                                  ...    ...        ...
# 160            {'startDate': {'month': 9, 'year': 2018}}    NaN  EDUCATION
# 162                                                  NaN    NaN        NaN
# 164                                                  NaN    NaN        NaN
# 165                                                  NaN    NaN        NaN
# 167    {'endDate': {'month': 2, 'year': 2020}, 'start...    NaN        NaN
#
#                                             vol_3company  \
# index
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4      {'miniCompany': {'objectUrn': 'urn:li:company:...
# ...                                                  ...
# 160    {'miniCompany': {'objectUrn': 'urn:li:company:...
# 162                                                  NaN
# 164                                                  NaN
# 165                                                  NaN
# 167                                                  NaN
#
#              vol_3companyName  \
# index
# 0                         NaN
# 1                         NaN
# 2      Rencontre des Justices
# 3                         NaN
# 4           Viking Club Paris
# ...                       ...
# 160               Toi Aussi !
# 162                       NaN
# 164                       NaN
# 165                       NaN
# 167                       NaN
#
#                                         vol_3description  \
# index
# 0                                                    NaN
# 1                                                    NaN
# 2      Rencontre des Justices is a grassroots movemen...
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 160                                                  NaN
# 162                                                  NaN
# 164                                                  NaN
# 165                                                  NaN
# 167                                                  NaN
#
#                                                vol_3role  \
# index
# 0                                                    NaN
# 1                                                    NaN
# 2                                             Co-founder
# 3                                                    NaN
# 4      Dirigeante - Coach de l'équipe féminine U11 - U13
# ...                                                  ...
# 160                            Animateur d’interventions
# 162                                                  NaN
# 164                                                  NaN
# 165                                                  NaN
# 167                                                  NaN
#
#                                          vol_3timePeriod
# index
# 0                                                    NaN
# 1                                                    NaN
# 2      {'endDate': {'month': 7, 'year': 2020}, 'start...
# 3                                                    NaN
# 4      {'endDate': {'month': 6, 'year': 2021}, 'start...
# ...                                                  ...
# 160                                                  NaN
# 162                                                  NaN
# 164                                                  NaN
# 165                                                  NaN
# 167                                                  NaN
#
# [148 rows x 395 columns]

# %%
columns= data.columns
columnstodrop=[i for i in data.columns if (data[i].isna().sum() > len(data)/2+10) or (i=="index")]
#data.drop(columns=columnstodrop, inplace=True)
print(columnstodrop)

add_data=data[["index", "lastName", "firstName"]]
add_data=add_data.merge(data[columnstodrop], how='left', on="index")
add_data.head()
# Out:
# ['index', 'cert_10', 'cert_100', 'cert_10authority', 'cert_10company', 'cert_10displaySource', 'cert_10licenseNumber', 'cert_10name', 'cert_10timePeriod', 'cert_10url', 'cert_1authority', 'cert_1company', 'cert_1displaySource', 'cert_1licenseNumber', 'cert_1name', 'cert_1timePeriod', 'cert_1url', 'cert_20', 'cert_2authority', 'cert_2company', 'cert_2displaySource', 'cert_2licenseNumber', 'cert_2name', 'cert_2timePeriod', 'cert_2url', 'cert_30', 'cert_3authority', 'cert_3company', 'cert_3displaySource', 'cert_3licenseNumber', 'cert_3name', 'cert_3timePeriod', 'cert_3url', 'cert_40', 'cert_4authority', 'cert_4company', 'cert_4displaySource', 'cert_4licenseNumber', 'cert_4name', 'cert_4timePeriod', 'cert_4url', 'cert_50', 'cert_5authority', 'cert_5company', 'cert_5displaySource', 'cert_5licenseNumber', 'cert_5name', 'cert_5timePeriod', 'cert_5url', 'cert_60', 'cert_6authority', 'cert_6company', 'cert_6displaySource', 'cert_6licenseNumber', 'cert_6name', 'cert_6timePeriod', 'cert_6url', 'cert_70', 'cert_7authority', 'cert_7company', 'cert_7displaySource', 'cert_7licenseNumber', 'cert_7name', 'cert_7timePeriod', 'cert_7url', 'cert_80', 'cert_8authority', 'cert_8company', 'cert_8displaySource', 'cert_8licenseNumber', 'cert_8name', 'cert_8timePeriod', 'cert_8url', 'cert_90', 'cert_9authority', 'cert_9company', 'cert_9displaySource', 'cert_9licenseNumber', 'cert_9name', 'cert_9timePeriod', 'cert_9url', 'ed_10', 'ed_1activities', 'ed_1courses', 'ed_1description', 'ed_1grade', 'ed_1honors', 'ed_1projects', 'ed_20', 'ed_2activities', 'ed_2courses', 'ed_2description', 'ed_2grade', 'ed_2honors', 'ed_2projects', 'ed_30', 'ed_3activities', 'ed_3courses', 'ed_3description', 'ed_3grade', 'ed_3honors', 'ed_3projects', 'exp_10', 'exp_1courses', 'exp_1honors', 'exp_1organizations', 'exp_1projects', 'exp_20', 'exp_2courses', 'exp_2honors', 'exp_2organizations', 'exp_2projects', 'exp_30', 'exp_3courses', 'exp_3honors', 'exp_3projects', 'exp_40', 'exp_4courses', 'exp_4honors', 'exp_4projects', 'exp_4region', 'exp_50', 'exp_5courses', 'exp_5honors', 'exp_5organizations', 'exp_5projects', 'hon_10', 'hon_1description', 'hon_1issueDate', 'hon_1issuer', 'hon_1occupation', 'hon_1title', 'hon_20', 'hon_2description', 'hon_2issueDate', 'hon_2issuer', 'hon_2occupation', 'hon_2title', 'hon_30', 'hon_3description', 'hon_3issueDate', 'hon_3issuer', 'hon_3occupation', 'hon_3title', 'hon_40', 'hon_4description', 'hon_4issueDate', 'hon_4issuer', 'hon_4occupation', 'hon_4title', 'hon_50', 'hon_5description', 'hon_5issueDate', 'hon_5issuer', 'hon_5occupation', 'hon_5title', 'hon_60', 'hon_6description', 'hon_6issueDate', 'hon_6issuer', 'hon_6occupation', 'hon_6title', 'hon_70', 'hon_7description', 'hon_7issueDate', 'hon_7issuer', 'hon_7occupation', 'hon_7title', 'lang_10', 'lang_20', 'lang_30', 'lang_40', 'lang_4name', 'lang_4proficiency', 'lang_50', 'lang_5name', 'lang_5proficiency', 'lang_60', 'lang_6name', 'lang_6proficiency', 'lang_70', 'lang_7name', 'lang_7proficiency', 'proj_10', 'proj_1description', 'proj_1members', 'proj_1occupation', 'proj_1timePeriod', 'proj_1title', 'proj_1url', 'proj_20', 'proj_2description', 'proj_2members', 'proj_2occupation', 'proj_2timePeriod', 'proj_2title', 'proj_2url', 'proj_30', 'proj_3description', 'proj_3members', 'proj_3occupation', 'proj_3timePeriod', 'proj_3title', 'proj_3url', 'proj_40', 'proj_4description', 'proj_4members', 'proj_4occupation', 'proj_4timePeriod', 'proj_4title', 'proj_4url', 'proj_50', 'proj_5description', 'proj_5members', 'proj_5occupation', 'proj_5timePeriod', 'proj_5title', 'proj_5url', 'proj_60', 'proj_6description', 'proj_6members', 'proj_6occupation', 'proj_6timePeriod', 'proj_6title', 'proj_6url', 'proj_70', 'proj_7description', 'proj_7members', 'proj_7occupation', 'proj_7timePeriod', 'proj_7title', 'proj_7url', 'proj_80', 'proj_8description', 'proj_8members', 'proj_8occupation', 'proj_8timePeriod', 'proj_8title', 'proj_8url', 'pub_10', 'pub_100', 'pub_10authors', 'pub_10date', 'pub_10description', ' ...
#    index  lastName firstName  cert_10  cert_100 cert_10authority  \
# 0      0   Brachet   Antoine      NaN       NaN              NaN
# 1      1     Demri     Bobby      NaN       NaN              NaN
# 2      2   Durieux     Sarah      NaN       NaN              NaN
# 3      3   Jaillot   Bastien      NaN       NaN              NaN
# 4      4  Vanneroy    Coline      NaN       NaN              NaN
#
#   cert_10company cert_10displaySource cert_10licenseNumber cert_10name  ...  \
# 0            NaN                  NaN                  NaN         NaN  ...
# 1            NaN                  NaN                  NaN         NaN  ...
# 2            NaN                  NaN                  NaN         NaN  ...
# 3            NaN                  NaN                  NaN         NaN  ...
# 4            NaN                  NaN                  NaN         NaN  ...
#
#                                     vol_2description              vol_2role  \
# 0                                                NaN                    NaN
# 1                                                NaN                    NaN
# 2  Empow’her supports  women entrepreneurs so the...           Board Member
# 3                                                NaN                    NaN
# 4  Électeurs en herbe est un programme d'éducatio...  Présidente-fondatrice
#
#                                      vol_2timePeriod vol_30 vol_3cause  \
# 0                                                NaN    NaN        NaN
# 1                                                NaN    NaN        NaN
# 2  {'endDate': {'month': 3, 'year': 2021}, 'start...    NaN        NaN
# 3                                                NaN    NaN        NaN
# 4          {'startDate': {'month': 7, 'year': 2016}}    NaN        NaN
#
#                                         vol_3company        vol_3companyName  \
# 0                                                NaN                     NaN
# 1                                                NaN                     NaN
# 2                                                NaN  Rencontre des Justices
# 3                                                NaN                     NaN
# 4  {'miniCompany': {'objectUrn': 'urn:li:company:...       Viking Club Paris
#
#                                     vol_3description  \
# 0                                                NaN
# 1                                                NaN
# 2  Rencontre des Justices is a grassroots movemen...
# 3                                                NaN
# 4                                                NaN
#
#                                            vol_3role  \
# 0                                                NaN
# 1                                                NaN
# 2                                         Co-founder
# 3                                                NaN
# 4  Dirigeante - Coach de l'équipe féminine U11 - U13
#
#                                      vol_3timePeriod
# 0                                                NaN
# 1                                                NaN
# 2  {'endDate': {'month': 7, 'year': 2020}, 'start...
# 3                                                NaN
# 4  {'endDate': {'month': 6, 'year': 2021}, 'start...
#
# [5 rows x 329 columns]

# %%
add_data.to_csv("additional_data_low_response.csv", sep=';', index=True)

# %%
nullvalues=pd.DataFrame(data.isna().sum().sort_values(ascending=False))
nullvalues.head()
# Out:
#                    0
# exp_2region       94
# vol_1role         93
# exp_3region       93
# vol_1companyName  93
# exp_1region       83

# %% [markdown]
# ### Other recoding - could be improved

# %%
data.drop(columns=['ed_1school', 'ed_2school','ed_3school'], inplace=True)

# %% [markdown]
# #### Time columns could be split

# %%
timecols= [i for i in data.columns if "time" in i]
timecols
# Out:
# ['ed_1timePeriod',
#  'ed_2timePeriod',
#  'ed_3timePeriod',
#  'exp_1timePeriod',
#  'exp_2timePeriod',
#  'exp_3timePeriod',
#  'exp_4timePeriod',
#  'exp_5timePeriod']

# %%
#data.isna().sum()
data.fillna("[]", inplace=True)
# we are filling na with [] because special characters will be removed later on.

# %%
data.head(10)
# Out:
#                                       ed_1degreeName  \
# 0                                Master informatique
# 1                                           Master 2
# 2  Master's 2 Degree  Marketing & Strategy - Inte...
# 3                                     Masters Degree
# 4  Master of management, organisations and govern...
# 5                                                MBA
# 6                                           Master 2
# 7                                            Masters
# 8                                            Dut SRC
# 9                                 Start-up Launchpad
#
#                      ed_1fieldOfStudy  \
# 0  Architecture logicielle distribuée
# 1                 Sciences politiques
# 2                                  []
# 3    Written & Audiovisual Journalism
# 4                                  []
# 5                            Strategy
# 6  Management des Ressources Humaines
# 7              International Politics
# 8                                  []
# 9          Master of Digital Business
#
#                                       ed_1schoolName  \
# 0                              Université Bordeaux I
# 1               Université Paris 1 Panthéon-Sorbonne
# 2                          Université Paris Dauphine
# 3                      Université libre de Bruxelles
# 4  The London School of Economics and Political S...
# 5                      ESSEC - ESSEC Business School
# 6                   Pantheon ASSAS University, Paris
# 7                               Sciences Po Bordeaux
# 8                 Université de Caen Basse Normandie
# 9                                          HEC Paris
#
#                                       ed_1timePeriod  \
# 0  {'endDate': {'year': 2009}, 'startDate': {'yea...
# 1  {'endDate': {'year': 2007}, 'startDate': {'yea...
# 2  {'endDate': {'year': 2015}, 'startDate': {'yea...
# 3  {'endDate': {'year': 2006}, 'startDate': {'yea...
# 4  {'endDate': {'year': 2009}, 'startDate': {'yea...
# 5  {'endDate': {'year': 2006}, 'startDate': {'yea...
# 6  {'endDate': {'year': 2005}, 'startDate': {'yea...
# 7  {'endDate': {'year': 2010}, 'startDate': {'yea...
# 8                                                 []
# 9  {'endDate': {'year': 2017}, 'startDate': {'yea...
#
#                                       ed_2degreeName  \
# 0                                                 []
# 1                                            Licence
# 2  Postgraduate master’s degree in Information an...
# 3                   Creating Collaborative Solutions
# 4                                                 []
# 5            Master of Business Administration (MBA)
# 6                                                 []
# 7            Social entrepreneurship summer training
# 8                                                 []
# 9                                    Master's degree
#
#                                   ed_2fieldOfStudy  \
# 0                                               []
# 1                                            Droit
# 2                                               []
# 3                 Political Science and Government
# 4                                               []
# 5                        Strategy and organisation
# 6                                               []
# 7  Business Administration and Management, General
# 8                                               []
# 9                    Public affairs and management
#
#                                       ed_2schoolName  \
# 0                                                 []
# 1                  Université Lille 2 Droit et Santé
# 2           Université Sorbonne Nouvelle (Paris III)
# 3                             Harvard Kennedy School
# 4  Institut National des Etudes Territoriales (INET)
# 5                      ESSEC - ESSEC Business School
# 6                                                 []
# 7                            University of Cambridge
# 8                  Université du Maine-Le Mans-Laval
# 9                                  Sciences Po Lille
#
#                                       ed_2timePeriod  \
# 0                                                 []
# 1  {'endDate': {'year': 2005}, 'startDate': {'yea...
# 2  {'endDate': {'year': 2013}, 'startDate': {'yea...
# 3  {'endDate': {'year': 2017}, 'startDate': {'yea...
# 4  {'endDate': {'year': 2011}, 'startDate': {'yea...
# 5  {'endDate': {'year': 2006}, 'startDate': {'yea...
# 6                                                 []
# 7  {'endDate': {'year': 2015}, 'startDate': {'yea...
# 8                                                 []
# 9  {'endDate': {'year': 2016}, 'startDate': {'yea...
#
#                             ed_3degreeName  \
# 0                                       []
# 1                                       []
# 2                        Bachelor's degree
# 3              9 weeks full stack bootcamp
# 4                Master Affaires Publiques
# 5  Master of Business Administration - MBA
# 6                                       []
# 7                             Licenciatura
# 8                                       []
# 9                                 Bachelor
#
#                             ed_3fieldOfStudy  ...  \
# 0                                         []  ...
# 1                                         []  ...
# 2     Communication, rédaction et multimédia  ...
# 3                           Computer Science  ...
# 4                                         []  ...
# 5                                         []  ...
# 6                                         []  ...
# 7  Ciencias Politicas y de la Administracion  ...
# 8                                         []  ...
# 9                                        Law  ...
#
#                                             headline lang_1name  \
# 0                           Web expert chez Jolicode    Anglais
# 1       Directrice des opérations chez Cap Collectif         []
# 2  Regional Director (France, Italy, Russia and S...    Anglais
# 3  Co-founder & CEO @Fluicity 💡 Co-founder Associ...     Arabic
# 4             Directrice générale adjointe chez Adie    Anglais
# 5  Directeur Associé - Chief Revenue Officer (CRO...         []
# 6     CEO & Co-founder at Civocracy\n!We are hiring!    Chinese
# 7  #onrecrute - CEO de Voxe média-école d'empower...    English
# 8  Directeur Technique chez Monsieur SLOOP, ABCDE...         []
# 9  Belgium France @Sdui | Tech-For-Good Leader & ...         []
#
#       lang_1proficiency lang_2name    lang_2proficiency lang_3name  \
# 0                    []         []                   []         []
# 1                    []         []                   []         []
# 2     FULL_PROFESSIONAL   Espagnol      LIMITED_WORKING   Français
# 3       LIMITED_WORKING    English                   []     French
# 4  PROFESSIONAL_WORKING   Français  NATIVE_OR_BILINGUAL         []
# 5                    []         []                   []         []
# 6  PROFESSIONAL_WORKING    English    FULL_PROFESSIONAL     French
# 7   NATIVE_OR_BILINGUAL     French  NATIVE_OR_BILINGUAL    Spanish
# 8                    []         []                   []         []
# 9                    []         []                   []         []
#
#      lang_3proficiency                                            summary  \
# 0                   []  IT Consultant, Technical Expert, Lead develope...
# 1                   []                                                 []
# 2  NATIVE_OR_BILINGUAL                                       People Power
# 3  NATIVE_OR_BILINGUAL  16+ years of experience driving change in the ...
# 4                   []                                                 []
# 5                   []  17 ans d'expérience, intelligence collective, ...
# 6  NATIVE_OR_BILINGUAL  After eight years of social entrepreneurship i...
# 7  NATIVE_OR_BILINGUAL  Experienced Chief Executive Officer with a dem...
# 8                   []                                                 []
# 9                   []  Drawing on 7 years of experience as a Team Lea...
#
#        vol_1companyName                      vol_1role
# 0                    []                             []
# 1  La Cravate Solidaire                Administratrice
# 2  Samu Social de Paris                      Volunteer
# 3            BeCode.org                   Board Member
# 4                    []                             []
# 5                    []                             []
# 6                    []                             []
# 7             Empow'Her  Mentor du programme Woman'Act
# 8                    []                             []
# 9                Anacej                 Vice-Président
#
# [10 rows x 62 columns]

# %%
data.shape
# Out:
# (168, 62)

# %% [markdown]
# ### Make dataframe with described dataset (modes, counts...) - not interesting if the dataframe is at this level of transformation

# %%
#data.describe().T
#general_pop_data= pd.DataFrame(data.describe(include="O").T)
#general_pop_data.to_csv("general_pop_data.csv", sep=';')

# %%
pd.options.display.max_rows = 100
data.head(5).T
# Out:
#                                                                       0  \
# ed_1degreeName                                      Master informatique
# ed_1fieldOfStudy                     Architecture logicielle distribuée
# ed_1schoolName                                    Université Bordeaux I
# ed_1timePeriod        {'endDate': {'year': 2009}, 'startDate': {'yea...
# ed_2degreeName                                                       []
# ed_2fieldOfStudy                                                     []
# ed_2schoolName                                                       []
# ed_2timePeriod                                                       []
# ed_3degreeName                                                       []
# ed_3fieldOfStudy                                                     []
# ed_3schoolName                                                       []
# ed_3timePeriod                                                       []
# exp_1company                                                         []
# exp_1companyName                                               Jolicode
# exp_1description      I co-created JoliCode in march 2012 in order t...
# exp_1geoLocationName                                                 []
# exp_1locationName                                                    []
# exp_1region                                                          []
# exp_1timePeriod               {'startDate': {'month': 3, 'year': 2012}}
# exp_1title                                                   Web expert
# exp_2company          {'employeeCountRange': {'start': 201, 'end': 5...
# exp_2companyName                                             Clever Age
# exp_2description      Expert PHP : audit, performance, méthodologie ...
# exp_2geoLocationName                                                 []
# exp_2locationName                                                    []
# exp_2region                                                          []
# exp_2timePeriod       {'endDate': {'month': 1, 'year': 2012}, 'start...
# exp_2title                                        Consultant Expert PHP
# exp_3company                                                         []
# exp_3companyName                                   Solution Interactive
# exp_3description                                                     []
# exp_3geoLocationName                                                 []
# exp_3locationName                                                    []
# exp_3region                                                          []
# exp_3timePeriod       {'endDate': {'month': 9, 'year': 2009}, 'start...
# exp_3title                                               Lead developer
# exp_4company                                                         []
# exp_4companyName                                                     []
# exp_4description                                                     []
# exp_4geoLocationName                                                 []
# exp_4locationName                                                    []
# exp_4timePeriod                                                      []
# exp_4title                                                           []
# exp_5company                                                         []
# exp_5companyName                                                     []
# exp_5description                                                     []
# exp_5geoLocationName                                                 []
# exp_5locationName                                                    []
# exp_5timePeriod                                                      []
# exp_5title                                                           []
# geoCountryName                                                   France
# geoLocationName                       Greater Paris Metropolitan Region
# headline                                       Web expert chez Jolicode
# lang_1name                                                      Anglais
# lang_1proficiency                                                    []
# lang_2name                                                           []
# lang_2proficiency                                                    []
# lang_3name                                                           []
# lang_3proficiency                                                    []
# summary               IT Consultant, Technical Expert, Lead develope...
# vol_1companyName                                                     []
# vol_1role                                                            []
#
#                                                                       1  \
# ed_1degreeName                                                 Master 2
# ed_1fieldOfStudy                                    Sciences politiques
# ed_1schoolName                     Université Paris 1 Panthéon-Sorbonne
# ed_1timePeriod        {'endDate': {'year': 2007}, 'startDate': {'yea...
# ed_2degreeName                                                  Licence
# ed_2fieldOfStudy                                                  Droit
# ed_2schoolName                        Université Lille 2 Droit et Santé
# ed_2timePeriod        {'endDate': {'year': 2005}, 'startDate': {'yea...
# ed_3degreeName                                                       []
# ed_3fieldOfStudy                                                     []
# ed_3schoolName                                                       []
# ed_3timePeriod                                                       []
# exp_1company          {'employeeCountRange': {'start': 11, 'end': 50...
# exp_1companyName                                          Cap Collectif
# exp_1description      Pilotage des activités des pôles conseil, comm...
# exp_1geoLocationName                                                 []
# exp_1locationName                                                    []
# exp_1region                                                          []
# exp_1timePeriod               {'startDate': {'month': 3, 'year': 2022}}
# exp_1title                                    Directrice des opérations
# exp_2company          {'employeeCountRange': {'start': 11, 'end': 50...
# exp_2companyName                                          Cap Collectif
# exp_2description      Key figures : 250 clients / 2,5 M€ CA / 30 ETP...
# exp_2geoLocationName                                                 []
# exp_2locationName                                                    []
# exp_2region                                                          []
# exp_2timePeriod       {'endDate': {'month': 3, 'year': 2022}, 'start...
# exp_2title                      Directrice du développement commercial
# exp_3company          {'employeeCountRange': {'start': 11, 'end': 50...
# exp_3companyName                                               Animafac
# exp_3description      Pilotage du projet associatif et des plaidoyer...
# exp_3geoLocationName                                              Paris
# exp_3locationName                                                 Paris
# exp_3region                                                          []
# exp_3timePeriod       {'endDate': {'month': 1, 'year': 2017}, 'start...
# exp_3title                                            Déléguée générale
# exp_4company          {'employeeCountRange': {'start': 11, 'end': 50...
# exp_4companyName                                               Animafac
# exp_4description                                                     []
# exp_4geoLocationName                                              Paris
# exp_4locationName                                                 Paris
# exp_4timePeriod       {'endDate': {'month': 9, 'year': 2012}, 'start...
# exp_4title                      Directrice administrative et financière
# exp_5company          {'employeeCountRange': {'start': 10001}, 'indu...
# exp_5companyName                                        Mairie de Paris
# exp_5description                                                     []
# exp_5geoLocationName                                                 []
# exp_5locationName                                                    []
# exp_5timePeriod       {'endDate': {'year': 2009}, 'startDate': {'yea...
# exp_5title            Chargée de mission auprès du chef de cabinet d...
# geoCountryName                                                   France
# geoLocationName                       Greater Paris Metropolitan Region
# headline                   Directrice des opérations chez Cap Collectif
# lang_1name                                                           []
# lang_1proficiency                                                    []
# lang_2name                                                           []
# lang_2proficiency                                                    []
# lang_3name                                                           []
# lang_3proficiency                                                    []
# summary                                                              []
# vol_1companyName                                   La Cravate Solidaire
# vol_1role                                               Administratrice
#
#                                                                       2  \
# ed_1degreeName        Master's 2 Degree  Marketing & Strategy - Inte...
# ed_1fieldOfStudy                                                     []
# ed_1schoolName                                Université Paris Dauphine
# ed_1timePeriod        {'endDate': {'year': 2015}, 'startDate': {'yea...
# ed_2degreeName        Postgraduate master’s degree in Information an...
# ed_2fieldOfStudy                                                     []
# ed_2schoolName                 Université Sorbonne Nouvelle (Paris III)
# ed_2timePeriod        {'endDate': {'year': 2013}, 'startDate': {'yea...
# ed_3degreeName                                        Bachelor's degree
# ed_3fieldOfStudy                 Communication, rédaction et multimédia
# ed_3schoolName         Université de Sherbrooke / Sherbrooke University
# ed_3timePeriod        {'endDate': {'year': 2012}, 'startDate': {'yea...
# exp_1company          {'employeeCountRange': {'start': 201, 'end': 5...
# exp_1companyName                                             Change.org
# exp_1description                                                     []
# exp_1geoLocationName                       Paris, Île-de-France, France
# exp_1locationName                          Paris, Île-de-France, France
# exp_1region                                     urn:li:fs_region:(fr,0)
# exp_1timePeriod               {'startDate': {'month': 9, 'year': 2022}}
# exp_1title             Regional Director( France, Italy, Russia, Spain)
# exp_2company          {'employeeCountRange': {'start': 0, 'end': 1},...
# exp_2companyName                                       Maison Bonnemuse
# exp_2description      Sustainable and inclusive jumpsuits that tell ...
# exp_2geoLocationName                       Paris, Île-de-France, France
# exp_2locationName                          Paris, Île-de-France, France
# exp_2region                                     urn:li:fs_region:(fr,0)
# exp_2timePeriod              {'startDate': {'month': 10, 'year': 2020}}
# exp_2title                                                      Founder
# exp_3company          {'employeeCountRange': {'start': 201, 'end': 5...
# exp_3companyName                                             Change.org
# exp_3description                                                     []
# exp_3geoLocationName                       Paris, Île-de-France, France
# exp_3locationName                          Paris, Île-de-France, France
# exp_3region                                     urn:li:fs_region:(fr,0)
# exp_3timePeriod       {'endDate': {'month': 10, 'year': 2022}, 'star...
# exp_3title                      Director, France and Campaigns Support
# exp_4company          {'employeeCountRange': {'start': 201, 'end': 5...
# exp_4companyName                                             Change.org
# exp_4description      Senior campaigner in charge of looking ahead a...
# exp_4geoLocationName                                 Paris Area, France
# exp_4locationName                                    Paris Area, France
# exp_4timePeriod       {'endDate': {'month': 12, 'year': 2020}, 'star...
# exp_4title                                            Senior Campaigner
# exp_5company          {'employeeCountRange': {'start': 201, 'end': 5...
# exp_5companyName                                             Change.org
# exp_5description                                                     []
# exp_5geoLocationName                                 Paris Area, France
# exp_5locationName                                    Paris Area, France
# exp_5timePeriod       {'endDate': {'month': 5, 'year': 2018}, 'start...
# exp_5title                                                   Campaigner
# geoCountryName                                                   France
# geoLocationName                                    Paris, Île-de-France
# headline              Regional Director (France, Italy, Russia and S...
# lang_1name                                                      Anglais
# lang_1proficiency                                     FULL_PROFESSIONAL
# lang_2name                                                     Espagnol
# lang_2proficiency                                       LIMITED_WORKING
# lang_3name                                                     Français
# lang_3proficiency                                   NATIVE_OR_BILINGUAL
# summary                                                    People Power
# vol_1companyName                                   Samu Social de Paris
# vol_1role                                                     Volunteer
#
#                                                                       3  \
# ed_1degreeName                                           Masters Degree
# ed_1fieldOfStudy                       Written & Audiovisual Journalism
# ed_1schoolName                            Université libre de Bruxelles
# ed_1timePeriod        {'endDate': {'year': 2006}, 'startDate': {'yea...
# ed_2degreeName                         Creating Collaborative Solutions
# ed_2fieldOfStudy                       Political Science and Government
# ed_2schoolName                                   Harvard Kennedy School
# ed_2timePeriod        {'endDate': {'year': 2017}, 'startDate': {'yea...
# ed_3degreeName                              9 weeks full stack bootcamp
# ed_3fieldOfStudy                                       Computer Science
# ed_3schoolName                                                 Le Wagon
# ed_3timePeriod        {'endDate': {'year': 2014}, 'startDate': {'yea...
# exp_1company          {'employeeCountRange': {'start': 2, 'end': 10}...
# exp_1companyName                                               Fluicity
# exp_1description      Fluicity provides government agencies with col...
# exp_1geoLocationName                                 Paris Area, France
# exp_1locationName                                    Paris Area, France
# exp_1region                                  urn:li:fs_region:(fr,5227)
# exp_1timePeriod               {'startDate': {'month': 1, 'year': 2015}}
# exp_1title                                             Co-Founder & CEO
# exp_2company          {'employeeCountRange': {'start': 10001}, 'indu...
# exp_2companyName                                                 Google
# exp_2description      Responsibilities:\n- Drive platforms revenue g...
# exp_2geoLocationName                                    Istanbul, Dubai
# exp_2locationName                                       Istanbul, Dubai
# exp_2region                                                          []
# exp_2timePeriod       {'endDate': {'month': 7, 'year': 2015}, 'start...
# exp_2title            Regional Sales Manager, Media Platforms, MENA ...
# exp_3company          {'employeeCountRange': {'start': 10001}, 'indu...
# exp_3companyName                                                 Google
# exp_3description      Responsibilities:\n- Build and execute market ...
# exp_3geoLocationName  Paris, Emerging markets (covering AE, IL, PL, ...
# exp_3locationName     Paris, Emerging markets (covering AE, IL, PL, ...
# exp_3region                                                          []
# exp_3timePeriod       {'endDate': {'month': 12, 'year': 2012}, 'star...
# exp_3title            Senior Sales Manager, Media Platforms, Emergin...
# exp_4company          {'employeeCountRange': {'start': 2, 'end': 10}...
# exp_4companyName                                        Unfair magazine
# exp_4description      Launched and established the first Abu Dhabi b...
# exp_4geoLocationName                    Abu Dhabi, United Arab Emirates
# exp_4locationName                       Abu Dhabi, United Arab Emirates
# exp_4timePeriod       {'endDate': {'month': 9, 'year': 2010}, 'start...
# exp_4title                                            Managing Director
# exp_5company          {'employeeCountRange': {'start': 10001}, 'indu...
# exp_5companyName                                               BBC News
# exp_5description      Responsibilities:\n- Produce Middle East Busin...
# exp_5geoLocationName                        Dubai, United Arab Emirates
# exp_5locationName                           Dubai, United Arab Emirates
# exp_5timePeriod       {'endDate': {'month': 12, 'year': 2008}, 'star...
# exp_5title                                                     Producer
# geoCountryName                                                   France
# geoLocationName                                    Paris, Île-de-France
# headline              Co-founder & CEO @Fluicity 💡 Co-founder Associ...
# lang_1name                                                       Arabic
# lang_1proficiency                                       LIMITED_WORKING
# lang_2name                                                      English
# lang_2proficiency                                                    []
# lang_3name                                                       French
# lang_3proficiency                                   NATIVE_OR_BILINGUAL
# summary               16+ years of experience driving change in the ...
# vol_1companyName                                             BeCode.org
# vol_1role                                                  Board Member
#
#                                                                       4
# ed_1degreeName        Master of management, organisations and govern...
# ed_1fieldOfStudy                                                     []
# ed_1schoolName        The London School of Economics and Political S...
# ed_1timePeriod        {'endDate': {'year': 2009}, 'startDate': {'yea...
# ed_2degreeName                                                       []
# ed_2fieldOfStudy                                                     []
# ed_2schoolName        Institut National des Etudes Territoriales (INET)
# ed_2timePeriod        {'endDate': {'year': 2011}, 'startDate': {'yea...
# ed_3degreeName                                Master Affaires Publiques
# ed_3fieldOfStudy                                                     []
# ed_3schoolName                                              Sciences Po
# ed_3timePeriod        {'endDate': {'year': 2008}, 'startDate': {'yea...
# exp_1company          {'employeeCountRange': {'start': 501, 'end': 1...
# exp_1companyName                                                   Adie
# exp_1description                                                     []
# exp_1geoLocationName                                                 []
# exp_1locationName                                                    []
# exp_1region                                                          []
# exp_1timePeriod               {'startDate': {'month': 9, 'year': 2020}}
# exp_1title                                 Directrice générale adjointe
# exp_2company          {'employeeCountRange': {'start': 501, 'end': 1...
# exp_2companyName                                                   Adie
# exp_2description                                                     []
# exp_2geoLocationName                            Région de Paris, France
# exp_2locationName                               Région de Paris, France
# exp_2region                                                          []
# exp_2timePeriod               {'startDate': {'month': 9, 'year': 2019}}
# exp_2title            Directrice des relations institutionnelles et ...
# exp_3company          {'employeeCountRange': {'start': 2, 'end': 10}...
# exp_3companyName                                               FLUICITY
# exp_3description      Start up de la Civic Tech.  Plateforme numériq...
# exp_3geoLocationName                            Région de Paris, France
# exp_3locationName                               Région de Paris, France
# exp_3region                                  urn:li:fs_region:(fr,5227)
# exp_3timePeriod       {'endDate': {'month': 5, 'year': 2019}, 'start...
# exp_3title                                 Responsable du développement
# exp_4company          {'employeeCountRange': {'start': 10001}, 'indu...
# exp_4companyName                                        Mairie de Paris
# exp_4description      Insertion sociale et professionnelle (RSA), in...
# exp_4geoLocationName                            Région de Paris, France
# exp_4locationName                               Région de Paris, France
# exp_4timePeriod       {'endDate': {'month': 12, 'year': 2016}, 'star...
# exp_4title            Adjointe de la sous directrice en charge de l'...
# exp_5company          {'employeeCountRange': {'start': 5001, 'end': ...
# exp_5companyName                                Conseil Général du Nord
# exp_5description      Mise en place d’une démarche globale de suivi ...
# exp_5geoLocationName                                                 []
# exp_5locationName                                                    []
# exp_5timePeriod       {'endDate': {'month': 10, 'year': 2014}, 'star...
# exp_5title                                       Responsable de service
# geoCountryName                                                   France
# geoLocationName                                Montreuil, Île-de-France
# headline                         Directrice générale adjointe chez Adie
# lang_1name                                                      Anglais
# lang_1proficiency                                  PROFESSIONAL_WORKING
# lang_2name                                                     Français
# lang_2proficiency                                   NATIVE_OR_BILINGUAL
# lang_3name                                                           []
# lang_3proficiency                                                    []
# summary                                                              []
# vol_1companyName                                                     []
# vol_1role                                                            []

# %% [markdown]
# ### Exporting our dataset

# %%
data.to_csv("dataset2.csv", sep=';', index=False)
