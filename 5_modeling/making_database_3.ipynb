# %% [markdown]
# ### Initializing

# %%
import pandas as pd
import json
import numpy as np
import os

# %%
def create_profile(x, url):
    with open(str(url)+str(x)) as f:
        dict1 = json.load(f)
    list_col= ['experience', 'education', 'languages','languages','publications', 'certifications','volunteer', 'honors', 'projects']
    for n in list_col:
        if n in dict1:
            for i in range(len(dict1[n])): 
                dict1[str(n+str(i+1))]= dict1[n][i]
    data = pd.DataFrame.from_dict(dict1, orient='index').T
    return data

# %%
file_list = [f for f in os.listdir('../data/jsons') if f.endswith(".json")]
len(file_list)
# Out:
# 49

# %%
initial_profile=create_profile('brachetantoine.json', '../data/jsons/')

# %%
profiles = initial_profile
for i in file_list:
    a= create_profile(i, '../data/jsons/')
    profiles= pd.concat((profiles,a),axis=0)

# %%
file_list2 = [f for f in os.listdir('../data/jsons2') if f.endswith(".json")]
len(file_list2)
# Out:
# 124

# %%
profiles2 = initial_profile
for i in file_list2:
    a= create_profile(i,'../data/jsons2/')
    profiles2= pd.concat((profiles2,a),axis=0)

# %%
data=pd.concat([profiles, profiles2]).reset_index(drop=True)
data.head(2)
# Out:
#                                              summary  \
# 0  Antoine croit à l’intelligence de tous et à la...
# 1  French Entrepreneur - Founder and Managing Par...
#
#                                     industryName lastName student  \
# 0                  IT Services and IT Consulting  Brachet   False
# 1  Venture Capital and Private Equity Principals    Demri   False
#
#   geoCountryName            geoCountryUrn geoLocationBackfilled    elt  \
# 0         France  urn:li:fs_geo:105015875                 False  False
# 1         France  urn:li:fs_geo:105015875                 False  False
#
#               industryUrn firstName  ... publications9 publications10  \
# 0   urn:li:fs_industry:96   Antoine  ...           NaN            NaN
# 1  urn:li:fs_industry:106     Bobby  ...           NaN            NaN
#
#   maidenName projects8 certifications5 certifications6 certifications7  \
# 0        NaN       NaN             NaN             NaN             NaN
# 1        NaN       NaN             NaN             NaN             NaN
#
#   certifications8 certifications9 certifications10
# 0             NaN             NaN              NaN
# 1             NaN             NaN              NaN
#
# [2 rows x 89 columns]

# %% [markdown]
# ### Initial dataset cleaning

# %%
data.shape
# Out:
# (173, 89)

# %%
print(list(data.columns))
# Out:
# ['summary', 'industryName', 'lastName', 'student', 'geoCountryName', 'geoCountryUrn', 'geoLocationBackfilled', 'elt', 'industryUrn', 'firstName', 'entityUrn', 'geoLocation', 'geoLocationName', 'location', 'headline', 'displayPictureUrl', 'img_100_100', 'img_200_200', 'img_400_400', 'img_800_800', 'profile_id', 'profile_urn', 'member_urn', 'public_id', 'experience', 'education', 'languages', 'publications', 'certifications', 'volunteer', 'honors', 'projects', 'experience1', 'experience2', 'experience3', 'experience4', 'experience5', 'education1', 'education2', 'education3', 'languages1', 'languages2', 'languages3', 'publications1', 'publications2', 'publications3', 'publications4', 'publications5', 'publications6', 'publications7', 'publications8', 'locationName', 'honors1', 'honors2', 'honors3', 'honors4', 'honors5', 'honors6', 'honors7', 'volunteer1', 'volunteer2', 'volunteer3', 'projects1', 'projects2', 'projects3', 'birthDate', 'languages4', 'projects4', 'projects5', 'address', 'languages5', 'languages6', 'certifications1', 'projects6', 'projects7', 'certifications2', 'certifications3', 'certifications4', 'languages7', 'publications9', 'publications10', 'maidenName', 'projects8', 'certifications5', 'certifications6', 'certifications7', 'certifications8', 'certifications9', 'certifications10']

# %% [markdown]
# ### Drop duplicates in rows

# %%
mask = data.duplicated(subset=['headline', 'firstName', 'lastName'], keep='first')
dropped = data.loc[mask]
dropped
# Out:
#                                               summary  \
# 3   Antoine croit à l’intelligence de tous et à la...
# 48  Antoine croit à l’intelligence de tous et à la...
# 50  French Entrepreneur - Founder and Managing Par...
# 51  Inspired by the power we can build to change t...
# 84                                                NaN
#
#                                      industryName lastName student  \
# 3                   IT Services and IT Consulting  Brachet   False
# 48                  IT Services and IT Consulting  Brachet   False
# 50  Venture Capital and Private Equity Principals    Demri   False
# 51                 Civic and Social Organizations  Durieux   False
# 84                                       Internet    Paret   False
#
#    geoCountryName            geoCountryUrn geoLocationBackfilled    elt  \
# 3          France  urn:li:fs_geo:105015875                 False  False
# 48         France  urn:li:fs_geo:105015875                 False  False
# 50         France  urn:li:fs_geo:105015875                 False  False
# 51         France  urn:li:fs_geo:105015875                 False  False
# 84         France  urn:li:fs_geo:105015875                 False   True
#
#                industryUrn firstName  ... publications9 publications10  \
# 3    urn:li:fs_industry:96   Antoine  ...           NaN            NaN
# 48   urn:li:fs_industry:96   Antoine  ...           NaN            NaN
# 50  urn:li:fs_industry:106     Bobby  ...           NaN            NaN
# 51   urn:li:fs_industry:90     Sarah  ...           NaN            NaN
# 84    urn:li:fs_industry:6   Jeremie  ...           NaN            NaN
#
#    maidenName projects8 certifications5 certifications6 certifications7  \
# 3         NaN       NaN             NaN             NaN             NaN
# 48        NaN       NaN             NaN             NaN             NaN
# 50        NaN       NaN             NaN             NaN             NaN
# 51        NaN       NaN             NaN             NaN             NaN
# 84        NaN       NaN             NaN             NaN             NaN
#
#    certifications8 certifications9 certifications10
# 3              NaN             NaN              NaN
# 48             NaN             NaN              NaN
# 50             NaN             NaN              NaN
# 51             NaN             NaN              NaN
# 84             NaN             NaN              NaN
#
# [5 rows x 89 columns]

# %%
data.drop_duplicates(subset=['headline', 'firstName', 'lastName'], keep='first', inplace=True)

# %%
print(sorted(list(data.lastName.str.lower())))
# Out:
# ['albet', 'alemanno', 'ami', 'andré', 'arrouard', 'auclair', 'auclair', 'baillot', 'banzet', 'barbaut', 'barbero', 'barbier', 'barre', 'bauquet', 'behar', 'behar', 'benkirane', 'bensa', 'berenguer-moncada', 'bertrand', 'bertrand', 'bessoles', 'besson', 'besson', 'bianchin-fabre', 'bloch', 'bouché', 'boudehen', 'bourlitio', 'brachet', 'briante guillemont', 'buchotte', 'bézard', 'canivet', 'chadenet', 'chaput', 'chatellier', 'chaygneaud-dupuy', 'chevallereau', 'choisne', 'claret', 'cochin', 'colas', 'colas', 'colombe', 'combaz', 'coudard', 'coutant', 'coutant', 'd', 'd.', 'daniel', 'daniel', 'dardier', 'dauchez', 'de bodman', 'de briey', 'de marignan', 'de pimodan', 'de roquefeuil', 'de royer', 'de sousa', 'de sousa', 'deffrennes', 'deleris', 'deleris', 'dembele', 'demri', 'demri', 'dernoncourt', 'des gachons', 'desmaison', 'deville', 'diguet', 'dubreuil', 'dubreuil', 'duguet', 'duperthuy', 'durieux', 'duriez', 'duriez', 'duval', 'désigaud', 'désigaud', 'escoubes', 'eve', 'forest', 'fox', 'françois', 'gabadou santiago', 'gaboriau', 'garnier-nguyen', 'gautier', 'gille', 'gilles', 'gombert', 'goujon', 'gresset', 'grunelius', 'guimas', 'hanson', 'haro', 'jachiet', 'jaillot', 'japiot', 'kergall', 'kergall', 'kleck casalegno', 'kumpf', 'l.', 'l.', 'lacot', 'lage', 'larroque', 'lavayssière', 'le botlan', 'le masne', 'le roux', 'le roux', 'lecourtois', 'legros', 'legros', 'lenoir', 'lenoir', 'levoir', 'levoir', 'liot', 'mabi', 'marchandise ', 'mateus', 'mcgrath-dehecq', 'medrinal', 'meiss', 'miailhe', 'monclaire', 'noury', 'pahud', 'paret', 'patte', 'pelissard', 'piekarski', 'pignal 🌍', 'pleurmeau', 'pons', 'pouyé', 'pulicani', 'pène', 'reboux', 'richard', 'richer', 'rosado', 'roudaut', 'rozier', 'santiso', 'schlumberger', 'schwab', 'snow', 'sotiropoulou', 'stefani', 'teulié', 'trèves', 'trèves', 'van brussel', 'vanneroy', 'vaturi', 'vignolles', 'walbaum', 'zylberberg']

# %%
dups=(data.loc[(data.lastName.str.lower()=="auclair")|(data.lastName.str.lower()=="behar")|(data.lastName.str.lower()=="bertrand")|(data.lastName.str.lower()=="besson")|(data.lastName.str.lower()=="colas")|(data.lastName.str.lower()=="coutant")|(data.lastName.str.lower()=="daniel")|(data.lastName.str.lower()=="de sousa")|(data.lastName.str.lower()=="deleris")|(data.lastName.str.lower()=="demri")|(data.lastName.str.lower()=="dubreuil")|(data.lastName.str.lower()=="duriez")|(data.lastName.str.lower()=="désigaud")|(data.lastName.str.lower()=="kergall")|(data.lastName.str.lower()=="l.")|(data.lastName.str.lower()=="le roux")|(data.lastName.str.lower()=="legros")|(data.lastName.str.lower()=="lenoir")|(data.lastName.str.lower()=="levoir")|(data.lastName.str.lower()=="trèves")])[["firstName", "lastName"]].sort_values(by="lastName")
print(list(dups.index)[0::2])
data.drop(labels=list(dups.index)[0::2], axis=0, inplace=True)
# Out:
# [155, 152, 114, 130, 111, 147, 89, 54, 125, 126, 127, 69, 162, 65, 59, 87, 64, 133, 168, 74]

# %% [markdown]
# ### Dropping unnecessary columns (specific to LIn, personal information, etc.)

# %%
pd.options.display.max_rows = 100

# %%
todrop=['industryName', 'experience', 'education', 'languages','languages','publications', 
        'certifications','volunteer', 'honors', 'projects', 
        'displayPictureUrl', 'img_100_100', 'img_200_200', 'img_400_400', 
        'img_800_800', 'student', 'maidenName', 'birthDate', 
        'address','geoCountryUrn', 'geoLocationBackfilled', 'elt', 'industryUrn',
        'entityUrn', 'geoLocation', 'location', 'locationName', 
        'profile_id', 'profile_urn', 'member_urn', 'public_id']
data.drop(columns=todrop, inplace=True)

# %%
data.describe().T.sort_index()
# Out:
#                  count unique  \
# certifications1     39     39
# certifications10     1      1
# certifications2     18     18
# certifications3      9      9
# certifications4      4      4
# certifications5      3      3
# certifications6      3      3
# certifications7      3      3
# certifications8      1      1
# certifications9      1      1
# education1         143    143
# education2         130    130
# education3         107    107
# experience1        147    147
# experience2        144    144
# experience3        143    143
# experience4        140    140
# experience5        135    135
# firstName          148    118
# geoCountryName     146      3
# geoLocationName    124     30
# headline           147    147
# honors1             29     29
# honors2             19     19
# honors3             10     10
# honors4              9      9
# honors5              7      7
# honors6              6      6
# honors7              2      2
# languages1         107     29
# languages2          99     32
# languages3          86     41
# languages4          46     32
# languages5          19     15
# languages6           7      7
# languages7           2      2
# lastName           148    148
# projects1           45     45
# projects2           28     28
# projects3           18     18
# projects4           13     13
# projects5           10     10
# projects6            4      4
# projects7            4      4
# projects8            1      1
# publications1       61     61
# publications10      13     13
# publications2       44     44
# publications3       36     36
# publications4       35     35
# publications5       27     27
# publications6       24     24
# publications7       21     21
# publications8       18     18
# publications9       16     16
# summary             94     94
# volunteer1          69     69
# volunteer2          58     58
# volunteer3          40     40
#
#                                                                 top freq
# certifications1                              {'name': 'Psychology'}    1
# certifications10  {'authority': 'The London School of Economics ...    1
# certifications2   {'authority': 'OpenClassrooms', 'name': 'Learn...    1
# certifications3   {'authority': 'COLIBRIS', 'name': 'Quelle démo...    1
# certifications4   {'authority': 'A Cloud Guru', 'name': 'Introdu...    1
# certifications5   {'authority': 'Google', 'name': 'Google Ads Ce...    1
# certifications6   {'authority': 'Google', 'name': 'Certification...    1
# certifications7   {'authority': 'HubSpot', 'name': 'Hubspot Inbo...    1
# certifications8   {'authority': 'ANSSI - Agence nationale de la ...    1
# certifications9   {'authority': 'Institut français', 'name': 'Cu...    1
# education1        {'entityUrn': 'urn:li:fs_education:(ACoAAAA615...    1
# education2        {'entityUrn': 'urn:li:fs_education:(ACoAAAA615...    1
# education3        {'entityUrn': 'urn:li:fs_education:(ACoAAAA615...    1
# experience1       {'locationName': 'Paris Area, France', 'entity...    1
# experience2       {'entityUrn': 'urn:li:fs_position:(ACoAAAA615E...    1
# experience3       {'locationName': 'Paris', 'entityUrn': 'urn:li...    1
# experience4       {'locationName': 'Paris Area, France', 'entity...    1
# experience5       {'locationName': 'Paris', 'entityUrn': 'urn:li...    1
# firstName                                                   Nicolas    6
# geoCountryName                                               France  139
# geoLocationName                                Paris, Île-de-France   54
# headline          Directeur associé de bluenove, initiateur du m...    1
# honors1           {'description': 'THE WEBBY AWARDS IS THE LEADI...    1
# honors2           {'description': 'The leading international awa...    1
# honors3           {'description': 'Eurobest is the world's pre-e...    1
# honors4           {'description': 'The London International Awar...    1
# honors5           {'description': 'Le Grand Prix de l’Innovation...    1
# honors6           {'description': 'The Cannes Lions Internationa...    1
# honors7           {'description': 'The Cannes Lions Internationa...    1
# languages1        {'name': 'Anglais', 'proficiency': 'FULL_PROFE...   18
# languages2        {'name': 'French', 'proficiency': 'NATIVE_OR_B...   24
# languages3        {'name': 'Français', 'proficiency': 'NATIVE_OR...   29
# languages4        {'name': 'Français', 'proficiency': 'NATIVE_OR...    8
# languages5        {'name': 'Espagnol', 'proficiency': 'FULL_PROF...    2
# languages6         {'name': 'Spanish', 'proficiency': 'ELEMENTARY'}    1
# languages7         {'name': 'Italien', 'proficiency': 'ELEMENTARY'}    1
# lastName                                                    Brachet    1
# projects1         {'members': [{'member': {'firstName': 'Bastien...    1
# projects2         {'members': [{'member': {'firstName': 'Bastien...    1
# projects3         {'members': [{'member': {'firstName': 'Coline'...    1
# projects4         {'occupation': 'urn:li:fs_position:(ACoAAABaH0...    1
# projects5         {'occupation': 'urn:li:fs_position:(ACoAAABaH0...    1
# projects6         {'occupation': 'urn:li:fs_position:(ACoAAAfEoR...    1
# projects7         {'occupation': 'urn:li:fs_position:(ACoAAAfEoR...    1
# projects8         {'occupation': 'urn:li:fs_position:(ACoAAAMqDL...    1
# publications1     {'date': {'month': 9, 'year': 2017, 'day': 1},...    1
# publications10    {'date': {'year': 2012}, 'name': '"Les Politiq...    1
# publications2     {'date': {'month': 3, 'year': 2016, 'day': 1},...    1
# publications3     {'date': {'month': 6, 'year': 2014, 'day': 30}...    1
# publications4     {'date': {'month': 6, 'year': 2014, 'day': 11}...    1
# publications5     {'date': {'month': 4, 'year': 2014, 'day': 22}...    1
# publications6     {'date': {'month': 9, 'year': 2006, 'day': 25}...    1
# publications7     {'name': 'Mes Contributions dans le Huffington...    1
# publications8     {'name': 'Mes contributions dans lePlus de l'O...    1
# publications9     {'date': {'year': 2013}, 'name': 'Qué Politica...    1
# summary           Antoine croit à l’intelligence de tous et à la...    1
# volunteer1        {'role': 'Co-Founder', 'companyName': 'Collect...    1
# volunteer2        {'role': 'Board Member', 'companyName': 'Empow...    1
# volunteer3        {'role': 'Co-founder', 'companyName': 'Rencont...    1

# %% [markdown]
# ### Check who responded to what

# %%
data.isna().sum().sort_values(ascending=False)
# Out:
# certifications10    147
# certifications9     147
# certifications8     147
# projects8           147
# languages7          146
# honors7             146
# certifications7     145
# certifications6     145
# certifications5     145
# certifications4     144
# projects7           144
# projects6           144
# honors6             142
# languages6          141
# honors5             141
# certifications3     139
# honors4             139
# projects5           138
# honors3             138
# publications10      135
# projects4           135
# publications9       132
# publications8       130
# projects3           130
# certifications2     130
# languages5          129
# honors2             129
# publications7       127
# publications6       124
# publications5       121
# projects2           120
# honors1             119
# publications4       113
# publications3       112
# certifications1     109
# volunteer3          108
# publications2       104
# projects1           103
# languages4          102
# volunteer2           90
# publications1        87
# volunteer1           79
# languages3           62
# summary              54
# languages2           49
# education3           41
# languages1           41
# geoLocationName      24
# education2           18
# experience5          13
# experience4           8
# education1            5
# experience3           5
# experience2           4
# geoCountryName        2
# experience1           1
# headline              1
# lastName              0
# firstName             0
# dtype: int64

# %%
data["lang_stated"]=1
data["honors_stated"]=1
data["pubs_stated"]=1
data["projects_stated"]=1
data["certif_stated"]=1
data.head(1)
# Out:
#                                              summary lastName geoCountryName  \
# 0  Antoine croit à l’intelligence de tous et à la...  Brachet         France
#
#   firstName                    geoLocationName  \
# 0   Antoine  Greater Paris Metropolitan Region
#
#                                             headline  \
# 0  Directeur associé de bluenove, initiateur du m...
#
#                                          experience1  \
# 0  {'locationName': 'Paris Area, France', 'entity...
#
#                                          experience2  \
# 0  {'entityUrn': 'urn:li:fs_position:(ACoAAAA615E...
#
#                                          experience3  \
# 0  {'locationName': 'Paris', 'entityUrn': 'urn:li...
#
#                                          experience4  ... certifications6  \
# 0  {'locationName': 'Paris Area, France', 'entity...  ...             NaN
#
#   certifications7 certifications8 certifications9 certifications10  \
# 0             NaN             NaN             NaN              NaN
#
#   lang_stated honors_stated pubs_stated projects_stated certif_stated
# 0           1             1           1               1             1
#
# [1 rows x 64 columns]

# %%
data.loc[data["languages1"].isna(), "lang_stated"]=0
data.loc[data["honors1"].isna(), "honors_stated"]=0
data.loc[data["projects1"].isna(), "projects_stated"]=0
data.loc[data["certifications1"].isna(), "certif_stated"]=0
data.loc[data["publications1"].isna(), "pubs_stated"]=0

# %%
print(sum(data["lang_stated"]))
print(sum(data["honors_stated"]))
print(sum(data["projects_stated"]))
print(sum(data["certif_stated"]))
print(sum(data["pubs_stated"]))
# Out:
# 107
# 29
# 45
# 39
# 61

# %%
data["over_2_lang"]=1

# %%
data.loc[data["languages3"].isna(), "over_2_lang"]=0
print(sum(data["over_2_lang"]))
# Out:
# 86

# %%
data["lin_details_remplis"]=0

# %%
details_col_list= [i for i in data.columns if "stated" in i]
details_col_list
# Out:
# ['lang_stated',
#  'honors_stated',
#  'pubs_stated',
#  'projects_stated',
#  'certif_stated']

# %%
data["lin_details_remplis"]= data["lang_stated"]+data["honors_stated"]+data["pubs_stated"]+data["projects_stated"]+data["certif_stated"]
print(list(data["lin_details_remplis"]))
# Out:
# [2, 1, 2, 3, 1, 2, 3, 1, 3, 3, 2, 4, 0, 2, 5, 0, 3, 3, 1, 4, 1, 1, 1, 1, 1, 1, 2, 3, 1, 2, 0, 2, 1, 0, 2, 2, 2, 1, 0, 5, 5, 1, 2, 2, 3, 2, 0, 1, 1, 3, 5, 3, 0, 2, 0, 3, 3, 2, 3, 3, 0, 4, 2, 2, 0, 0, 3, 1, 2, 2, 0, 3, 1, 0, 2, 2, 2, 1, 1, 2, 2, 3, 0, 3, 0, 0, 0, 4, 2, 4, 2, 2, 3, 3, 3, 2, 2, 3, 1, 1, 0, 3, 3, 0, 3, 0, 0, 1, 4, 3, 4, 2, 3, 2, 1, 2, 3, 0, 1, 2, 2, 2, 2, 1, 1, 2, 2, 5, 3, 4, 2, 2, 1, 2, 1, 3, 2, 2, 1, 0, 2, 2, 1, 2, 2, 2, 3, 2]

# %% [markdown]
# ### Exploding columns

# %%
print(list(data.columns))
# Out:
# ['summary', 'lastName', 'geoCountryName', 'firstName', 'geoLocationName', 'headline', 'experience1', 'experience2', 'experience3', 'experience4', 'experience5', 'education1', 'education2', 'education3', 'languages1', 'languages2', 'languages3', 'publications1', 'publications2', 'publications3', 'publications4', 'publications5', 'publications6', 'publications7', 'publications8', 'honors1', 'honors2', 'honors3', 'honors4', 'honors5', 'honors6', 'honors7', 'volunteer1', 'volunteer2', 'volunteer3', 'projects1', 'projects2', 'projects3', 'languages4', 'projects4', 'projects5', 'languages5', 'languages6', 'certifications1', 'projects6', 'projects7', 'certifications2', 'certifications3', 'certifications4', 'languages7', 'publications9', 'publications10', 'projects8', 'certifications5', 'certifications6', 'certifications7', 'certifications8', 'certifications9', 'certifications10', 'lang_stated', 'honors_stated', 'pubs_stated', 'projects_stated', 'certif_stated', 'over_2_lang', 'lin_details_remplis']

# %%
for i in range (1,4): 
    data=pd.concat([data, 
    pd.DataFrame(data['education'+str(i)].apply(pd.Series)).add_prefix('ed_'+str(i)), 
    pd.DataFrame(data['volunteer'+str(i)].apply(pd.Series)).add_prefix('vol_'+str(i))], 
    axis=1).reset_index(drop=True)
    data.drop(columns=['education'+str(i),'volunteer'+str(i)], inplace=True)

# %%
for i in range (1,6): 
    data=pd.concat([data, 
    pd.DataFrame(data['experience'+str(i)].apply(pd.Series)).add_prefix('exp_'+str(i))], 
    axis=1).reset_index(drop=True)
    data.drop(columns='experience'+str(i), inplace=True)

# %%
for i in range (1,8): 
    data=pd.concat([data, 
    pd.DataFrame(data['honors'+str(i)].apply(pd.Series)).add_prefix('hon_'+str(i)), 
    pd.DataFrame(data['languages'+str(i)].apply(pd.Series)).add_prefix('lang_'+str(i))], 
    axis=1).reset_index(drop=True)
    data.drop(columns=['honors'+str(i),'languages'+str(i)], inplace=True)

# %%
for i in range (1,9): 
    data=pd.concat([data, 
    pd.DataFrame(data['projects'+str(i)].apply(pd.Series)).add_prefix('proj_'+str(i))], 
    axis=1).reset_index(drop=True)
    data.drop(columns='projects'+str(i), inplace=True)

# %%
for i in range (1,11): 
    data=pd.concat([data, 
    pd.DataFrame(data['certifications'+str(i)].apply(pd.Series)).add_prefix('cert_'+str(i)), 
    pd.DataFrame(data['publications'+str(i)].apply(pd.Series)).add_prefix('pub_'+str(i))], 
    axis=1).reset_index(drop=True)
    data.drop(columns=['certifications'+str(i),'publications'+str(i)], inplace=True)

# %%
list_columns=[i for i in data.columns if ("Urn" in i or "Logo" in i or "_region" in i or '_abuse' in i or '_geo' in i or '_proj' in i or '_organi' in i or '_0' in i)]
#to check before dropping 
data[list_columns].T
data.drop(columns=list_columns, inplace=True)

# %%
reg_columns=[i for i in data.columns if "region" in i]
reg_columns
data.drop(columns=reg_columns, inplace=True)

# %% [markdown]
# ### Dropping columns with too many missing values

# %%
data.shape
# Out:
# (148, 383)

# %%
print(list(data.columns))
# Out:
# ['summary', 'lastName', 'geoCountryName', 'firstName', 'geoLocationName', 'headline', 'lang_stated', 'honors_stated', 'pubs_stated', 'projects_stated', 'certif_stated', 'over_2_lang', 'lin_details_remplis', 'ed_1school', 'ed_1timePeriod', 'ed_1degreeName', 'ed_1schoolName', 'ed_1fieldOfStudy', 'ed_1activities', 'ed_1description', 'ed_1grade', 'ed_1courses', 'ed_10', 'ed_1projects', 'ed_1honors', 'vol_10', 'vol_1role', 'vol_1companyName', 'vol_1timePeriod', 'vol_1cause', 'vol_1description', 'vol_1company', 'ed_2timePeriod', 'ed_2schoolName', 'ed_2school', 'ed_2fieldOfStudy', 'ed_2degreeName', 'ed_20', 'ed_2activities', 'ed_2grade', 'ed_2description', 'ed_2projects', 'ed_2honors', 'ed_2courses', 'vol_20', 'vol_2role', 'vol_2companyName', 'vol_2timePeriod', 'vol_2cause', 'vol_2description', 'vol_2company', 'ed_3grade', 'ed_3timePeriod', 'ed_3degreeName', 'ed_3schoolName', 'ed_3fieldOfStudy', 'ed_3school', 'ed_3description', 'ed_30', 'ed_3activities', 'ed_3courses', 'ed_3honors', 'ed_3projects', 'vol_30', 'vol_3role', 'vol_3companyName', 'vol_3timePeriod', 'vol_3description', 'vol_3company', 'vol_3cause', 'exp_1locationName', 'exp_1geoLocationName', 'exp_1companyName', 'exp_1timePeriod', 'exp_1description', 'exp_1company', 'exp_1title', 'exp_1honors', 'exp_1organizations', 'exp_10', 'exp_1courses', 'exp_2companyName', 'exp_2timePeriod', 'exp_2company', 'exp_2title', 'exp_2locationName', 'exp_2geoLocationName', 'exp_2description', 'exp_2organizations', 'exp_2projects', 'exp_2honors', 'exp_20', 'exp_2courses', 'exp_3locationName', 'exp_3geoLocationName', 'exp_3companyName', 'exp_3timePeriod', 'exp_3company', 'exp_3title', 'exp_3description', 'exp_3projects', 'exp_30', 'exp_3courses', 'exp_3honors', 'exp_4locationName', 'exp_4geoLocationName', 'exp_4companyName', 'exp_4timePeriod', 'exp_4description', 'exp_4company', 'exp_4title', 'exp_40', 'exp_4projects', 'exp_4honors', 'exp_4courses', 'exp_5locationName', 'exp_5geoLocationName', 'exp_5companyName', 'exp_5timePeriod', 'exp_5description', 'exp_5company', 'exp_5title', 'exp_5honors', 'exp_50', 'exp_5projects', 'exp_5organizations', 'exp_5courses', 'hon_10', 'hon_1description', 'hon_1occupation', 'hon_1title', 'hon_1issueDate', 'hon_1issuer', 'lang_1name', 'lang_1proficiency', 'lang_10', 'hon_20', 'hon_2description', 'hon_2occupation', 'hon_2title', 'hon_2issueDate', 'hon_2issuer', 'lang_2name', 'lang_2proficiency', 'lang_20', 'hon_30', 'hon_3description', 'hon_3occupation', 'hon_3title', 'hon_3issueDate', 'hon_3issuer', 'lang_3name', 'lang_3proficiency', 'lang_30', 'hon_40', 'hon_4description', 'hon_4occupation', 'hon_4title', 'hon_4issueDate', 'hon_4issuer', 'lang_40', 'lang_4name', 'lang_4proficiency', 'hon_50', 'hon_5description', 'hon_5occupation', 'hon_5title', 'hon_5issueDate', 'hon_5issuer', 'lang_50', 'lang_5name', 'lang_5proficiency', 'hon_60', 'hon_6description', 'hon_6occupation', 'hon_6title', 'hon_6issueDate', 'hon_6issuer', 'lang_60', 'lang_6name', 'lang_6proficiency', 'hon_70', 'hon_7description', 'hon_7occupation', 'hon_7title', 'hon_7issueDate', 'hon_7issuer', 'lang_70', 'lang_7name', 'lang_7proficiency', 'proj_10', 'proj_1members', 'proj_1timePeriod', 'proj_1description', 'proj_1title', 'proj_1url', 'proj_1occupation', 'proj_20', 'proj_2members', 'proj_2timePeriod', 'proj_2description', 'proj_2title', 'proj_2url', 'proj_2occupation', 'proj_30', 'proj_3members', 'proj_3timePeriod', 'proj_3description', 'proj_3title', 'proj_3url', 'proj_3occupation', 'proj_40', 'proj_4occupation', 'proj_4members', 'proj_4timePeriod', 'proj_4description', 'proj_4title', 'proj_4url', 'proj_50', 'proj_5occupation', 'proj_5members', 'proj_5timePeriod', 'proj_5description', 'proj_5title', 'proj_5url', 'proj_60', 'proj_6occupation', 'proj_6members', 'proj_6timePeriod', 'proj_6description', 'proj_6title', 'proj_6url', 'proj_70', 'proj_7occupation', 'proj_7members', 'proj_7timePeriod', 'proj_7description', 'proj_7title', 'proj_7url', 'proj_80', 'proj_8occupation', 'proj_8members', 'proj_8time ...

# %%
full_null=[i for i in data.columns if data[i].isna().sum()>147]
data.drop(columns=full_null, inplace=True)

# %%
data.shape
# Out:
# (148, 330)

# %%
nullvalues=pd.DataFrame(data.isna().sum().sort_values(ascending=False))
print(list(nullvalues.index)[0:50])
# Out:
# ['hon_7description', 'proj_8title', 'exp_1courses', 'cert_7url', 'cert_9company', 'cert_9timePeriod', 'cert_9name', 'cert_9authority', 'proj_8description', 'proj_8timePeriod', 'proj_8members', 'proj_6occupation', 'proj_8occupation', 'cert_7displaySource', 'cert_8company', 'exp_2courses', 'cert_6licenseNumber', 'cert_6url', 'cert_7licenseNumber', 'cert_8authority', 'exp_2honors', 'cert_9displaySource', 'proj_8url', 'cert_4displaySource', 'cert_4url', 'cert_2licenseNumber', 'cert_6displaySource', 'exp_2organizations', 'cert_10company', 'cert_10timePeriod', 'cert_10name', 'cert_10authority', 'ed_3projects', 'exp_5courses', 'cert_3displaySource', 'cert_3url', 'cert_9url', 'cert_8name', 'ed_3honors', 'exp_2projects', 'proj_6url', 'exp_5honors', 'lang_7name', 'exp_3projects', 'exp_5organizations', 'hon_7occupation', 'hon_7title', 'exp_4courses', 'exp_1organizations', 'lang_7proficiency']

# %%
data.reset_index(inplace=True)
data.set_index("index")
# Out:
#                                                  summary            lastName  \
# index
# 0      Antoine croit à l’intelligence de tous et à la...             Brachet
# 1      French Entrepreneur - Founder and Managing Par...               Demri
# 2      Inspired by the power we can build to change t...             Durieux
# 3      IT Consultant, Technical Expert, Lead develope...             Jaillot
# 4                                                    NaN            Vanneroy
# ...                                                  ...                 ...
# 143    Mes projets du moment : \n- Le pilotage de la ...             Gresset
# 144                                                  NaN  Briante Guillemont
# 145                                                  NaN    Gabadou Santiago
# 146    Telecom & Environment engineer, I enjoy to con...             Coutant
# 147                                                  NaN             Coudard
#
#       geoCountryName firstName                    geoLocationName  \
# index
# 0             France   Antoine  Greater Paris Metropolitan Region
# 1             France     Bobby               Paris, Île-de-France
# 2             France     Sarah               Paris, Île-de-France
# 3             France   Bastien  Greater Paris Metropolitan Region
# 4             France    Coline  Greater Paris Metropolitan Region
# ...              ...       ...                                ...
# 143           France     Sarah                                NaN
# 144           France    Sophie  Greater Paris Metropolitan Region
# 145           France    Eloïse                                NaN
# 146           France   Ludovic  Greater Paris Metropolitan Region
# 147           France   Estelle  Greater Paris Metropolitan Region
#
#                                                 headline  lang_stated  \
# index
# 0      Directeur associé de bluenove, initiateur du m...            1
# 1            Founder & Managing Partner at ROCH Ventures            0
# 2      Co-director Multitudes Foundation - Activist a...            1
# 3                               Web expert chez Jolicode            1
# 4           Directrice des opérations chez Cap Collectif            0
# ...                                                  ...          ...
# 143                             Directrice de projets RH            1
# 144                                    Political adviser            1
# 145                             Democracy and Innovation            1
# 146    Engineer specialized in the digital & energy t...            1
# 147    Directrice des Affaires Publiques et Relations...            1
#
#        honors_stated  pubs_stated  projects_stated  ...  cert_10authority  \
# index                                               ...
# 0                  0            1                0  ...               NaN
# 1                  1            0                0  ...               NaN
# 2                  0            1                0  ...               NaN
# 3                  0            1                1  ...               NaN
# 4                  0            0                1  ...               NaN
# ...              ...          ...              ...  ...               ...
# 143                0            0                0  ...               NaN
# 144                0            1                0  ...               NaN
# 145                0            0                1  ...               NaN
# 146                0            1                1  ...               NaN
# 147                1            0                0  ...               NaN
#
#        cert_10name  cert_10timePeriod cert_10company pub_10date pub_10name  \
# index
# 0              NaN                NaN            NaN        NaN        NaN
# 1              NaN                NaN            NaN        NaN        NaN
# 2              NaN                NaN            NaN        NaN        NaN
# 3              NaN                NaN            NaN        NaN        NaN
# 4              NaN                NaN            NaN        NaN        NaN
# ...            ...                ...            ...        ...        ...
# 143            NaN                NaN            NaN        NaN        NaN
# 144            NaN                NaN            NaN        NaN        NaN
# 145            NaN                NaN            NaN        NaN        NaN
# 146            NaN                NaN            NaN        NaN        NaN
# 147            NaN                NaN            NaN        NaN        NaN
#
#       pub_10publisher pub_10description pub_10url pub_10authors
# index
# 0                 NaN               NaN       NaN           NaN
# 1                 NaN               NaN       NaN           NaN
# 2                 NaN               NaN       NaN           NaN
# 3                 NaN               NaN       NaN           NaN
# 4                 NaN               NaN       NaN           NaN
# ...               ...               ...       ...           ...
# 143               NaN               NaN       NaN           NaN
# 144               NaN               NaN       NaN           NaN
# 145               NaN               NaN       NaN           NaN
# 146               NaN               NaN       NaN           NaN
# 147               NaN               NaN       NaN           NaN
#
# [148 rows x 330 columns]

# %%
columns= data.columns
columnstodrop=[i for i in data.columns if (data[i].isna().sum() > len(data)/2+10) or (i=="index")]
print(columnstodrop)

add_data=data[["index", "lastName", "firstName"]]
add_data=add_data.merge(data[columnstodrop], how='left', on="index")
add_data.head()
# Out:
# ['index', 'ed_1activities', 'ed_1description', 'ed_1grade', 'ed_1courses', 'ed_1projects', 'ed_1honors', 'vol_1cause', 'vol_1description', 'vol_1company', 'ed_2activities', 'ed_2grade', 'ed_2description', 'ed_2projects', 'ed_2honors', 'ed_2courses', 'vol_2role', 'vol_2companyName', 'vol_2timePeriod', 'vol_2cause', 'vol_2description', 'vol_2company', 'ed_3grade', 'ed_3description', 'ed_3activities', 'ed_3courses', 'ed_3honors', 'ed_3projects', 'vol_3role', 'vol_3companyName', 'vol_3timePeriod', 'vol_3description', 'vol_3company', 'vol_3cause', 'exp_1honors', 'exp_1organizations', 'exp_1courses', 'exp_2organizations', 'exp_2projects', 'exp_2honors', 'exp_2courses', 'exp_3projects', 'exp_3courses', 'exp_3honors', 'exp_4projects', 'exp_4honors', 'exp_4courses', 'exp_5honors', 'exp_5projects', 'exp_5organizations', 'exp_5courses', 'hon_1description', 'hon_1occupation', 'hon_1title', 'hon_1issueDate', 'hon_1issuer', 'hon_2description', 'hon_2occupation', 'hon_2title', 'hon_2issueDate', 'hon_2issuer', 'hon_3description', 'hon_3occupation', 'hon_3title', 'hon_3issueDate', 'hon_3issuer', 'hon_4description', 'hon_4occupation', 'hon_4title', 'hon_4issueDate', 'hon_4issuer', 'lang_4name', 'lang_4proficiency', 'hon_5description', 'hon_5occupation', 'hon_5title', 'hon_5issueDate', 'hon_5issuer', 'lang_5name', 'lang_5proficiency', 'hon_6description', 'hon_6occupation', 'hon_6title', 'hon_6issueDate', 'hon_6issuer', 'lang_6name', 'lang_6proficiency', 'hon_7description', 'hon_7occupation', 'hon_7title', 'hon_7issueDate', 'hon_7issuer', 'lang_7name', 'lang_7proficiency', 'proj_1members', 'proj_1timePeriod', 'proj_1description', 'proj_1title', 'proj_1url', 'proj_1occupation', 'proj_2members', 'proj_2timePeriod', 'proj_2description', 'proj_2title', 'proj_2url', 'proj_2occupation', 'proj_3members', 'proj_3timePeriod', 'proj_3description', 'proj_3title', 'proj_3url', 'proj_3occupation', 'proj_4occupation', 'proj_4members', 'proj_4timePeriod', 'proj_4description', 'proj_4title', 'proj_4url', 'proj_5occupation', 'proj_5members', 'proj_5timePeriod', 'proj_5description', 'proj_5title', 'proj_5url', 'proj_6occupation', 'proj_6members', 'proj_6timePeriod', 'proj_6description', 'proj_6title', 'proj_6url', 'proj_7occupation', 'proj_7members', 'proj_7timePeriod', 'proj_7description', 'proj_7title', 'proj_7url', 'proj_8occupation', 'proj_8members', 'proj_8timePeriod', 'proj_8description', 'proj_8title', 'proj_8url', 'cert_1name', 'cert_1authority', 'cert_1licenseNumber', 'cert_1company', 'cert_1displaySource', 'cert_1url', 'cert_1timePeriod', 'pub_1date', 'pub_1name', 'pub_1publisher', 'pub_1description', 'pub_1url', 'pub_1authors', 'cert_2authority', 'cert_2name', 'cert_2company', 'cert_2timePeriod', 'cert_2displaySource', 'cert_2url', 'cert_2licenseNumber', 'pub_2date', 'pub_2name', 'pub_2publisher', 'pub_2description', 'pub_2url', 'pub_2authors', 'cert_3authority', 'cert_3name', 'cert_3company', 'cert_3timePeriod', 'cert_3displaySource', 'cert_3url', 'pub_3date', 'pub_3name', 'pub_3publisher', 'pub_3description', 'pub_3url', 'pub_3authors', 'cert_4authority', 'cert_4name', 'cert_4company', 'cert_4timePeriod', 'cert_4displaySource', 'cert_4url', 'pub_4date', 'pub_4name', 'pub_4publisher', 'pub_4url', 'pub_4authors', 'pub_4description', 'cert_5authority', 'cert_5name', 'cert_5timePeriod', 'cert_5company', 'pub_5date', 'pub_5name', 'pub_5publisher', 'pub_5url', 'pub_5authors', 'pub_5description', 'cert_6authority', 'cert_6name', 'cert_6timePeriod', 'cert_6company', 'cert_6licenseNumber', 'cert_6displaySource', 'cert_6url', 'pub_6date', 'pub_6name', 'pub_6publisher', 'pub_6description', 'pub_6url', 'pub_6authors', 'cert_7authority', 'cert_7name', 'cert_7timePeriod', 'cert_7company', 'cert_7licenseNumber', 'cert_7displaySource', 'cert_7url', 'pub_7name', 'pub_7publisher', 'pub_7url', 'pub_7authors', 'pub_7date', 'pub_7description', 'cert_8authority', 'cert_8name', 'cert_8company', 'pub_8name', 'pub_8publisher', 'pub_8description', 'pub_8url', 'pub_8authors', ' ...
#    index  lastName firstName                                ed_1activities  \
# 0      0   Brachet   Antoine                                           NaN
# 1      1     Demri     Bobby  Junior Entreprise. Département Moyen-Orient.
# 2      2   Durieux     Sarah                                           NaN
# 3      3   Jaillot   Bastien                                           NaN
# 4      4  Vanneroy    Coline                                           NaN
#
#                                      ed_1description ed_1grade ed_1courses  \
# 0                                                NaN       NaN         NaN
# 1                                                NaN       NaN         NaN
# 2  The journey to transformative change in our so...       NaN         NaN
# 3                                                NaN       NaN         NaN
# 4  Mémoire : "Les conceptions ordinaires de l'Eur...       NaN         NaN
#
#   ed_1projects ed_1honors vol_1cause  ... cert_10authority cert_10name  \
# 0          NaN        NaN        NaN  ...              NaN         NaN
# 1          NaN        NaN        NaN  ...              NaN         NaN
# 2          NaN        NaN   POLITICS  ...              NaN         NaN
# 3          NaN        NaN        NaN  ...              NaN         NaN
# 4          NaN        NaN        NaN  ...              NaN         NaN
#
#   cert_10timePeriod cert_10company pub_10date pub_10name pub_10publisher  \
# 0               NaN            NaN        NaN        NaN             NaN
# 1               NaN            NaN        NaN        NaN             NaN
# 2               NaN            NaN        NaN        NaN             NaN
# 3               NaN            NaN        NaN        NaN             NaN
# 4               NaN            NaN        NaN        NaN             NaN
#
#   pub_10description pub_10url pub_10authors
# 0               NaN       NaN           NaN
# 1               NaN       NaN           NaN
# 2               NaN       NaN           NaN
# 3               NaN       NaN           NaN
# 4               NaN       NaN           NaN
#
# [5 rows x 261 columns]

# %%
add_data.to_csv("//Users/tatianadeferaudy/Desktop/bacasable/marche_CT/additional_data_low_response.csv", sep=';', index=True)

# %%
data.drop(columns=columnstodrop, inplace=True)

# %%
data.shape
# Out:
# (148, 72)

# %%
nullvalues=pd.DataFrame(data.isna().sum().sort_values(ascending=False))
nullvalues.head()
# Out:
#                     0
# vol_1timePeriod    83
# vol_1role          79
# vol_1companyName   79
# ed_3fieldOfStudy   69
# lang_3proficiency  67

# %% [markdown]
# ### Cleaning time, industry and company columns

# %%
print(data.columns)
# Out:
# Index(['summary', 'lastName', 'geoCountryName', 'firstName', 'geoLocationName',
#        'headline', 'lang_stated', 'honors_stated', 'pubs_stated',
#        'projects_stated', 'certif_stated', 'over_2_lang',
#        'lin_details_remplis', 'ed_1school', 'ed_1timePeriod', 'ed_1degreeName',
#        'ed_1schoolName', 'ed_1fieldOfStudy', 'vol_1role', 'vol_1companyName',
#        'vol_1timePeriod', 'ed_2timePeriod', 'ed_2schoolName', 'ed_2school',
#        'ed_2fieldOfStudy', 'ed_2degreeName', 'ed_3timePeriod',
#        'ed_3degreeName', 'ed_3schoolName', 'ed_3fieldOfStudy', 'ed_3school',
#        'exp_1locationName', 'exp_1geoLocationName', 'exp_1companyName',
#        'exp_1timePeriod', 'exp_1description', 'exp_1company', 'exp_1title',
#        'exp_2companyName', 'exp_2timePeriod', 'exp_2company', 'exp_2title',
#        'exp_2locationName', 'exp_2geoLocationName', 'exp_2description',
#        'exp_3locationName', 'exp_3geoLocationName', 'exp_3companyName',
#        'exp_3timePeriod', 'exp_3company', 'exp_3title', 'exp_3description',
#        'exp_4locationName', 'exp_4geoLocationName', 'exp_4companyName',
#        'exp_4timePeriod', 'exp_4description', 'exp_4company', 'exp_4title',
#        'exp_5locationName', 'exp_5geoLocationName', 'exp_5companyName',
#        'exp_5timePeriod', 'exp_5description', 'exp_5company', 'exp_5title',
#        'lang_1name', 'lang_1proficiency', 'lang_2name', 'lang_2proficiency',
#        'lang_3name', 'lang_3proficiency'],
#       dtype='object')

# %%
for i in range (1,6):
    data['exp_'+str(i)+'startDate_month']= (pd.DataFrame(data['exp_'+str(i)+'timePeriod'].apply(pd.Series))['startDate']).apply(pd.Series)['month']
    data['exp_'+str(i)+'startDate_year']= (pd.DataFrame(data['exp_'+str(i)+'timePeriod'].apply(pd.Series))['startDate']).apply(pd.Series)['year']
    data['exp_'+str(i)+'endDate_month']= (pd.DataFrame(data['exp_'+str(i)+'timePeriod'].apply(pd.Series))['endDate']).apply(pd.Series)['month']
    data['exp_'+str(i)+'endDate_year']= (pd.DataFrame(data['exp_'+str(i)+'timePeriod'].apply(pd.Series))['endDate']).apply(pd.Series)['year']
    data['exp_'+str(i)+'industry']= (pd.DataFrame(data['exp_'+str(i)+'company'].apply(pd.Series))['industries'])
    data['exp_'+str(i)+'company_empl_low']= (pd.DataFrame(data['exp_'+str(i)+'company'].apply(pd.Series))['employeeCountRange']).apply(pd.Series)['start']
    data['exp_'+str(i)+'company_empl_high']= (pd.DataFrame(data['exp_'+str(i)+'company'].apply(pd.Series))['employeeCountRange']).apply(pd.Series)['end']
# Out:
# /var/folders/5g/jskfzb8j377fh7wl3_rxvkrc0000gn/T/ipykernel_2817/4086720059.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   data['exp_'+str(i)+'industry']= (pd.DataFrame(data['exp_'+str(i)+'company'].apply(pd.Series))['industries'])
# /var/folders/5g/jskfzb8j377fh7wl3_rxvkrc0000gn/T/ipykernel_2817/4086720059.py:7: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   data['exp_'+str(i)+'company_empl_low']= (pd.DataFrame(data['exp_'+str(i)+'company'].apply(pd.Series))['employeeCountRange']).apply(pd.Series)['start']
# /var/folders/5g/jskfzb8j377fh7wl3_rxvkrc0000gn/T/ipykernel_2817/4086720059.py:8: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   data['exp_'+str(i)+'company_empl_high']= (pd.DataFrame(data['exp_'+str(i)+'company'].apply(pd.Series))['employeeCountRange']).apply(pd.Series)['end']

# %%
for i in range (1,4):
    data['ed_'+str(i)+'startDate_month']= (pd.DataFrame(data['ed_'+str(i)+'timePeriod'].apply(pd.Series))['startDate']).apply(pd.Series)['month']
    data['ed_'+str(i)+'startDate_year']= (pd.DataFrame(data['ed_'+str(i)+'timePeriod'].apply(pd.Series))['startDate']).apply(pd.Series)['year']

# %%
print(list(data.columns))
# Out:
# ['summary', 'lastName', 'geoCountryName', 'firstName', 'geoLocationName', 'headline', 'lang_stated', 'honors_stated', 'pubs_stated', 'projects_stated', 'certif_stated', 'over_2_lang', 'lin_details_remplis', 'ed_1school', 'ed_1timePeriod', 'ed_1degreeName', 'ed_1schoolName', 'ed_1fieldOfStudy', 'vol_1role', 'vol_1companyName', 'vol_1timePeriod', 'ed_2timePeriod', 'ed_2schoolName', 'ed_2school', 'ed_2fieldOfStudy', 'ed_2degreeName', 'ed_3timePeriod', 'ed_3degreeName', 'ed_3schoolName', 'ed_3fieldOfStudy', 'ed_3school', 'exp_1locationName', 'exp_1geoLocationName', 'exp_1companyName', 'exp_1timePeriod', 'exp_1description', 'exp_1company', 'exp_1title', 'exp_2companyName', 'exp_2timePeriod', 'exp_2company', 'exp_2title', 'exp_2locationName', 'exp_2geoLocationName', 'exp_2description', 'exp_3locationName', 'exp_3geoLocationName', 'exp_3companyName', 'exp_3timePeriod', 'exp_3company', 'exp_3title', 'exp_3description', 'exp_4locationName', 'exp_4geoLocationName', 'exp_4companyName', 'exp_4timePeriod', 'exp_4description', 'exp_4company', 'exp_4title', 'exp_5locationName', 'exp_5geoLocationName', 'exp_5companyName', 'exp_5timePeriod', 'exp_5description', 'exp_5company', 'exp_5title', 'lang_1name', 'lang_1proficiency', 'lang_2name', 'lang_2proficiency', 'lang_3name', 'lang_3proficiency', 'exp_1startDate_month', 'exp_1startDate_year', 'exp_1endDate_month', 'exp_1endDate_year', 'exp_1industry', 'exp_1company_empl_low', 'exp_1company_empl_high', 'exp_2startDate_month', 'exp_2startDate_year', 'exp_2endDate_month', 'exp_2endDate_year', 'exp_2industry', 'exp_2company_empl_low', 'exp_2company_empl_high', 'exp_3startDate_month', 'exp_3startDate_year', 'exp_3endDate_month', 'exp_3endDate_year', 'exp_3industry', 'exp_3company_empl_low', 'exp_3company_empl_high', 'exp_4startDate_month', 'exp_4startDate_year', 'exp_4endDate_month', 'exp_4endDate_year', 'exp_4industry', 'exp_4company_empl_low', 'exp_4company_empl_high', 'exp_5startDate_month', 'exp_5startDate_year', 'exp_5endDate_month', 'exp_5endDate_year', 'exp_5industry', 'exp_5company_empl_low', 'exp_5company_empl_high', 'ed_1startDate_month', 'ed_1startDate_year', 'ed_2startDate_month', 'ed_2startDate_year', 'ed_3startDate_month', 'ed_3startDate_year']

# %%
for i in range (1,2): 
    data=pd.concat([data, 
    pd.DataFrame(data['vol_'+str(i)+'timePeriod'].apply(pd.Series)).add_prefix('vol_'+str(i))], 
    axis=1).reset_index(drop=True)
    data.drop(columns=['vol_'+str(i)+'timePeriod'], inplace=True)

# %%
data.shape
# Out:
# (148, 115)

# %%
columns=(data.columns.sort_values())
data=data[columns]

# %%
timecols= [i for i in data.columns if "time" in i]
data.drop(columns=timecols, inplace=True)

# %%
data.isna().sum().sort_values(ascending=False)[0:14]
data.drop(columns="vol_10", inplace=True)
#data.fillna("[]", inplace=True)
# we are filling na with [] because special characters will be removed later on.

# %%
data.drop(columns=["ed_1school", "ed_2school", "ed_3school"], inplace=True)

# %%
pd.options.display.max_rows = 115
data.head().T
# Out:
#                                                                         0  \
# certif_stated                                                           0
# ed_1degreeName                                                     Master
# ed_1fieldOfStudy                            Business/Managerial Economics
# ed_1schoolName                                                ESCP Europe
# ed_1startDate_month                                                   NaN
# ed_1startDate_year                                                 1998.0
# ed_2degreeName                                                        NaN
# ed_2fieldOfStudy                                                      NaN
# ed_2schoolName                                  Prépa Saint Jean de Douai
# ed_2startDate_month                                                   NaN
# ed_2startDate_year                                                 1996.0
# ed_3degreeName                                               Baccalauréat
# ed_3fieldOfStudy                                                Economics
# ed_3schoolName                                             Lycée Kernanec
# ed_3startDate_month                                                   NaN
# ed_3startDate_year                                                 1993.0
# exp_1companyName                                                 bluenove
# exp_1company_empl_high                                               50.0
# exp_1company_empl_low                                                11.0
# exp_1description        Bluenove accompagne la transformation positive...
# exp_1endDate_month                                                    NaN
# exp_1endDate_year                                                     NaN
# exp_1geoLocationName                                   Paris Area, France
# exp_1industry                                     [Management Consulting]
# exp_1locationName                                      Paris Area, France
# exp_1startDate_month                                                 11.0
# exp_1startDate_year                                                2017.0
# exp_1title                                              Directeur associé
# exp_2companyName                                       Démocratie Ouverte
# exp_2company_empl_high                                               10.0
# exp_2company_empl_low                                                 2.0
# exp_2description                                                      NaN
# exp_2endDate_month                                                    NaN
# exp_2endDate_year                                                     NaN
# exp_2geoLocationName                                                  NaN
# exp_2industry                         [Nonprofit Organization Management]
# exp_2locationName                                                     NaN
# exp_2startDate_month                                                  7.0
# exp_2startDate_year                                                2021.0
# exp_2title                     Membre du Comité d'Orientation Stratégique
# exp_3companyName                  APM - Association Progrès du Management
# exp_3company_empl_high                                            10000.0
# exp_3company_empl_low                                              5001.0
# exp_3description                                                      NaN
# exp_3endDate_month                                                    NaN
# exp_3endDate_year                                                     NaN
# exp_3geoLocationName                                                Paris
# exp_3industry                          [Professional Training & Coaching]
# exp_3locationName                                                   Paris
# exp_3startDate_month                                                  1.0
# exp_3startDate_year                                                2017.0
# exp_3title                                                         Expert
# exp_4companyName                                       Démocratie Ouverte
# exp_4company_empl_high                                               10.0
# exp_4company_empl_low                                                 2.0
# exp_4description        Démocratie Ouverte est un collectif citoyen in...
# exp_4endDate_month                                                    5.0
# exp_4endDate_year                                                  2020.0
# exp_4geoLocationName                                   Paris Area, France
# exp_4industry                         [Nonprofit Organization Management]
# exp_4locationName                                      Paris Area, France
# exp_4startDate_month                                                  1.0
# exp_4startDate_year                                                2018.0
# exp_4title                                                   Co-Président
# exp_5companyName                                        Dassault Systèmes
# exp_5company_empl_high                                                NaN
# exp_5company_empl_low                                             10001.0
# exp_5description        Netvibes provides Dashboard Intelligence ~ tra...
# exp_5endDate_month                                                   10.0
# exp_5endDate_year                                                  2017.0
# exp_5geoLocationName                                                Paris
# exp_5industry                                         [Computer Software]
# exp_5locationName                                                   Paris
# exp_5startDate_month                                                  2.0
# exp_5startDate_year                                                2013.0
# exp_5title               Senior Director, Strategic Business Development
# firstName                                                         Antoine
# geoCountryName                                                     France
# geoLocationName                         Greater Paris Metropolitan Region
# headline                Directeur associé de bluenove, initiateur du m...
# honors_stated                                                           0
# lang_1name                                                        English
# lang_1proficiency                                       FULL_PROFESSIONAL
# lang_2name                                                         French
# lang_2proficiency                                     NATIVE_OR_BILINGUAL
# lang_3name                                                         German
# lang_3proficiency                                              ELEMENTARY
# lang_stated                                                             1
# lastName                                                          Brachet
# lin_details_remplis                                                     2
# over_2_lang                                                             1
# projects_stated                                                         0
# pubs_stated                                                             1
# summary                 Antoine croit à l’intelligence de tous et à la...
# vol_1companyName                                                      NaN
# vol_1endDate                                                          NaN
# vol_1role                                                             NaN
# vol_1startDate                                                        NaN
#
#                                                                         1  \
# certif_stated                                                           0
# ed_1degreeName                                                        NaN
# ed_1fieldOfStudy         Relations Internationales et Sciences Politiques
# ed_1schoolName                         Ecole des Hautes Etudes Politiques
# ed_1startDate_month                                                   NaN
# ed_1startDate_year                                                 2006.0
# ed_2degreeName                                                        NaN
# ed_2fieldOfStudy                    Relations et affaires internationales
# ed_2schoolName                                      The Hebrew University
# ed_2startDate_month                                                   NaN
# ed_2startDate_year                                                 2005.0
# ed_3degreeName                                               Baccalauréat
# ed_3fieldOfStudy          Sciences Economiques et Sociales Option Anglais
# ed_3schoolName                                     Lycée Janson-de-Sailly
# ed_3startDate_month                                                   NaN
# ed_3startDate_year                                                 1998.0
# exp_1companyName                                            ROCH Ventures
# exp_1company_empl_high                                               10.0
# exp_1company_empl_low                                                 2.0
# exp_1description        ROCH Ventures is a Luxembourg based VC fund pr...
# exp_1endDate_month                                                    NaN
# exp_1endDate_year                                                     NaN
# exp_1geoLocationName                                                  NaN
# exp_1industry                          [Venture Capital & Private Equity]
# exp_1locationName                                                     NaN
# exp_1startDate_month                                                  1.0
# exp_1startDate_year                                                2022.0
# exp_1title                                     Founder & Managing Partner
# exp_2companyName                            Boston Consulting Group (BCG)
# exp_2company_empl_high                                                NaN
# exp_2company_empl_low                                             10001.0
# exp_2description        Oversee product innovation at BCG (inclusive o...
# exp_2endDate_month                                                    1.0
# exp_2endDate_year                                                  2022.0
# exp_2geoLocationName                              Région de Paris, France
# exp_2industry                                     [Management Consulting]
# exp_2locationName                                 Région de Paris, France
# exp_2startDate_month                                                  1.0
# exp_2startDate_year                                                2020.0
# exp_2title                                         Director of Innovation
# exp_3companyName                                 Orange Business Services
# exp_3company_empl_high                                                NaN
# exp_3company_empl_low                                             10001.0
# exp_3description        Orange Business Services provides communicatio...
# exp_3endDate_month                                                    6.0
# exp_3endDate_year                                                  2021.0
# exp_3geoLocationName                              Région de Paris, France
# exp_3industry                       [Information Technology and Services]
# exp_3locationName                                 Région de Paris, France
# exp_3startDate_month                                                  9.0
# exp_3startDate_year                                                2016.0
# exp_3title                                          Advisory Board Member
# exp_4companyName                            Boston Consulting Group (BCG)
# exp_4company_empl_high                                                NaN
# exp_4company_empl_low                                             10001.0
# exp_4description        Head of TUNED by BCG.\nBCG change management a...
# exp_4endDate_month                                                    1.0
# exp_4endDate_year                                                  2020.0
# exp_4geoLocationName                              Région de Paris, France
# exp_4industry                                     [Management Consulting]
# exp_4locationName                                 Région de Paris, France
# exp_4startDate_month                                                 11.0
# exp_4startDate_year                                                2017.0
# exp_4title                                                       Director
# exp_5companyName                           GOV " La Météo de l'Opinion ".
# exp_5company_empl_high                                               50.0
# exp_5company_empl_low                                                11.0
# exp_5description        Founded in 2014, GOV rapidly achieved populari...
# exp_5endDate_month                                                   11.0
# exp_5endDate_year                                                  2017.0
# exp_5geoLocationName                              Région de Paris, France
# exp_5industry                                                  [Internet]
# exp_5locationName                                 Région de Paris, France
# exp_5startDate_month                                                  4.0
# exp_5startDate_year                                                2014.0
# exp_5title                                        Co-Founder GOV (exited)
# firstName                                                           Bobby
# geoCountryName                                                     France
# geoLocationName                                      Paris, Île-de-France
# headline                      Founder & Managing Partner at ROCH Ventures
# honors_stated                                                           1
# lang_1name                                                            NaN
# lang_1proficiency                                                     NaN
# lang_2name                                                            NaN
# lang_2proficiency                                                     NaN
# lang_3name                                                            NaN
# lang_3proficiency                                                     NaN
# lang_stated                                                             0
# lastName                                                            Demri
# lin_details_remplis                                                     1
# over_2_lang                                                             0
# projects_stated                                                         0
# pubs_stated                                                             0
# summary                 French Entrepreneur - Founder and Managing Par...
# vol_1companyName                                                      NaN
# vol_1endDate                                                          NaN
# vol_1role                                                             NaN
# vol_1startDate                                                        NaN
#
#                                                                         2  \
# certif_stated                                                           0
# ed_1degreeName                                          Global messaging
# ed_1fieldOfStudy                        Communication orale et rhétorique
# ed_1schoolName          ASO communications / New Economy Organizers Ne...
# ed_1startDate_month                                                   3.0
# ed_1startDate_year                                                 2022.0
# ed_2degreeName          Training program to prepare women to political...
# ed_2fieldOfStudy                        Political sciences and government
# ed_2schoolName                                                  Investies
# ed_2startDate_month                                                   9.0
# ed_2startDate_year                                                 2020.0
# ed_3degreeName                                          Public narrative
# ed_3fieldOfStudy                               Leadership organisationnel
# ed_3schoolName                    Leading change network - Marshall Ganz
# ed_3startDate_month                                                   9.0
# ed_3startDate_year                                                 2020.0
# exp_1companyName                                    Multitudes Foundation
# exp_1company_empl_high                                               10.0
# exp_1company_empl_low                                                 2.0
# exp_1description        Multitudes supports people across Europe to re...
# exp_1endDate_month                                                    NaN
# exp_1endDate_year                                                     NaN
# exp_1geoLocationName                                                  NaN
# exp_1industry                         [Nonprofit Organization Management]
# exp_1locationName                                                     NaN
# exp_1startDate_month                                                  9.0
# exp_1startDate_year                                                2022.0
# exp_1title                                                  Co-directrice
# exp_2companyName                                  SD Conseil et formation
# exp_2company_empl_high                                                NaN
# exp_2company_empl_low                                                 NaN
# exp_2description        I equip and support those who want to make the...
# exp_2endDate_month                                                    NaN
# exp_2endDate_year                                                     NaN
# exp_2geoLocationName                                                  NaN
# exp_2industry                                                         NaN
# exp_2locationName                                                     NaN
# exp_2startDate_month                                                  9.0
# exp_2startDate_year                                                2021.0
# exp_2title              Consultant, trainer and organizer in activism ...
# exp_3companyName                      ECS (European Communication School)
# exp_3company_empl_high                                              200.0
# exp_3company_empl_low                                                51.0
# exp_3description                                                      NaN
# exp_3endDate_month                                                    9.0
# exp_3endDate_year                                                  2022.0
# exp_3geoLocationName                                                Paris
# exp_3industry                                          [Higher Education]
# exp_3locationName                                                   Paris
# exp_3startDate_month                                                 10.0
# exp_3startDate_year                                                2021.0
# exp_3title                       Teacher "New activism, digital advocacy"
# exp_4companyName        EFAP - Ecole des nouveaux métiers de la commun...
# exp_4company_empl_high                                              200.0
# exp_4company_empl_low                                                51.0
# exp_4description                                                      NaN
# exp_4endDate_month                                                    9.0
# exp_4endDate_year                                                  2022.0
# exp_4geoLocationName                                                Paris
# exp_4industry                                          [Higher Education]
# exp_4locationName                                                   Paris
# exp_4startDate_month                                                  9.0
# exp_4startDate_year                                                2021.0
# exp_4title                               Teacher "Influence and lobbying"
# exp_5companyName                                               Change.org
# exp_5company_empl_high                                              500.0
# exp_5company_empl_low                                               201.0
# exp_5description        My team and I, we give people the power to cre...
# exp_5endDate_month                                                   10.0
# exp_5endDate_year                                                  2021.0
# exp_5geoLocationName                                   Paris Area, France
# exp_5industry                                                  [Internet]
# exp_5locationName                                      Paris Area, France
# exp_5startDate_month                                                  2.0
# exp_5startDate_year                                                2018.0
# exp_5title                                             Executive Director
# firstName                                                           Sarah
# geoCountryName                                                     France
# geoLocationName                                      Paris, Île-de-France
# headline                Co-director Multitudes Foundation - Activist a...
# honors_stated                                                           0
# lang_1name                                                        Anglais
# lang_1proficiency                                     NATIVE_OR_BILINGUAL
# lang_2name                                                       Espagnol
# lang_2proficiency                                                     NaN
# lang_3name                                                        Italien
# lang_3proficiency                                                     NaN
# lang_stated                                                             1
# lastName                                                          Durieux
# lin_details_remplis                                                     2
# over_2_lang                                                             1
# projects_stated                                                         0
# pubs_stated                                                             1
# summary                 Inspired by the power we can build to change t...
# vol_1companyName                               Collectif Quartier Général
# vol_1endDate                                   {'month': 1, 'year': 2022}
# vol_1role                                                      Co-Founder
# vol_1startDate                                 {'month': 1, 'year': 2022}
#
#                                                                         3  \
# certif_stated                                                           0
# ed_1degreeName                                        Master informatique
# ed_1fieldOfStudy                       Architecture logicielle distribuée
# ed_1schoolName                                      Université Bordeaux I
# ed_1startDate_month                                                   NaN
# ed_1startDate_year                                                 2004.0
# ed_2degreeName                                                        NaN
# ed_2fieldOfStudy                                                      NaN
# ed_2schoolName                                                        NaN
# ed_2startDate_month                                                   NaN
# ed_2startDate_year                                                    NaN
# ed_3degreeName                                                        NaN
# ed_3fieldOfStudy                                                      NaN
# ed_3schoolName                                                        NaN
# ed_3startDate_month                                                   NaN
# ed_3startDate_year                                                    NaN
# exp_1companyName                                                 Jolicode
# exp_1company_empl_high                                                NaN
# exp_1company_empl_low                                                 NaN
# exp_1description        I co-created JoliCode in march 2012 in order t...
# exp_1endDate_month                                                    NaN
# exp_1endDate_year                                                     NaN
# exp_1geoLocationName                                                  NaN
# exp_1industry                                                         NaN
# exp_1locationName                                                     NaN
# exp_1startDate_month                                                  3.0
# exp_1startDate_year                                                2012.0
# exp_1title                                                     Web expert
# exp_2companyName                                               Clever Age
# exp_2company_empl_high                                              500.0
# exp_2company_empl_low                                               201.0
# exp_2description        Expert PHP : audit, performance, méthodologie ...
# exp_2endDate_month                                                    1.0
# exp_2endDate_year                                                  2012.0
# exp_2geoLocationName                                                  NaN
# exp_2industry                       [Information Technology and Services]
# exp_2locationName                                                     NaN
# exp_2startDate_month                                                  9.0
# exp_2startDate_year                                                2009.0
# exp_2title                                          Consultant Expert PHP
# exp_3companyName                                     Solution Interactive
# exp_3company_empl_high                                                NaN
# exp_3company_empl_low                                                 NaN
# exp_3description                                                      NaN
# exp_3endDate_month                                                    9.0
# exp_3endDate_year                                                  2009.0
# exp_3geoLocationName                                                  NaN
# exp_3industry                                                         NaN
# exp_3locationName                                                     NaN
# exp_3startDate_month                                                  6.0
# exp_3startDate_year                                                2006.0
# exp_3title                                                 Lead developer
# exp_4companyName                                                      NaN
# exp_4company_empl_high                                                NaN
# exp_4company_empl_low                                                 NaN
# exp_4description                                                      NaN
# exp_4endDate_month                                                    NaN
# exp_4endDate_year                                                     NaN
# exp_4geoLocationName                                                  NaN
# exp_4industry                                                         NaN
# exp_4locationName                                                     NaN
# exp_4startDate_month                                                  NaN
# exp_4startDate_year                                                   NaN
# exp_4title                                                            NaN
# exp_5companyName                                                      NaN
# exp_5company_empl_high                                                NaN
# exp_5company_empl_low                                                 NaN
# exp_5description                                                      NaN
# exp_5endDate_month                                                    NaN
# exp_5endDate_year                                                     NaN
# exp_5geoLocationName                                                  NaN
# exp_5industry                                                         NaN
# exp_5locationName                                                     NaN
# exp_5startDate_month                                                  NaN
# exp_5startDate_year                                                   NaN
# exp_5title                                                            NaN
# firstName                                                         Bastien
# geoCountryName                                                     France
# geoLocationName                         Greater Paris Metropolitan Region
# headline                                         Web expert chez Jolicode
# honors_stated                                                           0
# lang_1name                                                        Anglais
# lang_1proficiency                                                     NaN
# lang_2name                                                            NaN
# lang_2proficiency                                                     NaN
# lang_3name                                                            NaN
# lang_3proficiency                                                     NaN
# lang_stated                                                             1
# lastName                                                          Jaillot
# lin_details_remplis                                                     3
# over_2_lang                                                             0
# projects_stated                                                         1
# pubs_stated                                                             1
# summary                 IT Consultant, Technical Expert, Lead develope...
# vol_1companyName                                                      NaN
# vol_1endDate                                                          NaN
# vol_1role                                                             NaN
# vol_1startDate                                                        NaN
#
#                                                                         4
# certif_stated                                                           0
# ed_1degreeName                                                   Master 2
# ed_1fieldOfStudy                                      Sciences politiques
# ed_1schoolName                       Université Paris 1 Panthéon-Sorbonne
# ed_1startDate_month                                                   NaN
# ed_1startDate_year                                                 2005.0
# ed_2degreeName                                                    Licence
# ed_2fieldOfStudy                                                    Droit
# ed_2schoolName                          Université Lille 2 Droit et Santé
# ed_2startDate_month                                                   NaN
# ed_2startDate_year                                                 2002.0
# ed_3degreeName                                                        NaN
# ed_3fieldOfStudy                                                      NaN
# ed_3schoolName                                                        NaN
# ed_3startDate_month                                                   NaN
# ed_3startDate_year                                                    NaN
# exp_1companyName                                            Cap Collectif
# exp_1company_empl_high                                               50.0
# exp_1company_empl_low                                                11.0
# exp_1description        Pilotage des activités des pôles conseil, comm...
# exp_1endDate_month                                                    NaN
# exp_1endDate_year                                                     NaN
# exp_1geoLocationName                                                  NaN
# exp_1industry                                         [Computer Software]
# exp_1locationName                                                     NaN
# exp_1startDate_month                                                  3.0
# exp_1startDate_year                                                2022.0
# exp_1title                                      Directrice des opérations
# exp_2companyName                                            Cap Collectif
# exp_2company_empl_high                                               50.0
# exp_2company_empl_low                                                11.0
# exp_2description        Key figures : 250 clients / 2,5 M€ CA / 30 ETP...
# exp_2endDate_month                                                    3.0
# exp_2endDate_year                                                  2022.0
# exp_2geoLocationName                                                  NaN
# exp_2industry                                         [Computer Software]
# exp_2locationName                                                     NaN
# exp_2startDate_month                                                  2.0
# exp_2startDate_year                                                2017.0
# exp_2title                        Directrice du développement commercial
# exp_3companyName                                                 Animafac
# exp_3company_empl_high                                               50.0
# exp_3company_empl_low                                                11.0
# exp_3description        Pilotage du projet associatif et des plaidoyer...
# exp_3endDate_month                                                    1.0
# exp_3endDate_year                                                  2017.0
# exp_3geoLocationName                                                Paris
# exp_3industry                               [Civic & Social Organization]
# exp_3locationName                                                   Paris
# exp_3startDate_month                                                  9.0
# exp_3startDate_year                                                2012.0
# exp_3title                                              Déléguée générale
# exp_4companyName                                                 Animafac
# exp_4company_empl_high                                               50.0
# exp_4company_empl_low                                                11.0
# exp_4description                                                      NaN
# exp_4endDate_month                                                    9.0
# exp_4endDate_year                                                  2012.0
# exp_4geoLocationName                                                Paris
# exp_4industry                               [Civic & Social Organization]
# exp_4locationName                                                   Paris
# exp_4startDate_month                                                 10.0
# exp_4startDate_year                                                2009.0
# exp_4title                        Directrice administrative et financière
# exp_5companyName                                          Mairie de Paris
# exp_5company_empl_high                                                NaN
# exp_5company_empl_low                                             10001.0
# exp_5description                                                      NaN
# exp_5endDate_month                                                    NaN
# exp_5endDate_year                                                  2009.0
# exp_5geoLocationName                                                  NaN
# exp_5industry                                 [Government Administration]
# exp_5locationName                                                     NaN
# exp_5startDate_month                                                  NaN
# exp_5startDate_year                                                2008.0
# exp_5title              Chargée de mission auprès du chef de cabinet d...
# firstName                                                          Coline
# geoCountryName                                                     France
# geoLocationName                         Greater Paris Metropolitan Region
# headline                     Directrice des opérations chez Cap Collectif
# honors_stated                                                           0
# lang_1name                                                            NaN
# lang_1proficiency                                                     NaN
# lang_2name                                                            NaN
# lang_2proficiency                                                     NaN
# lang_3name                                                            NaN
# lang_3proficiency                                                     NaN
# lang_stated                                                             0
# lastName                                                         Vanneroy
# lin_details_remplis                                                     1
# over_2_lang                                                             0
# projects_stated                                                         1
# pubs_stated                                                             0
# summary                                                               NaN
# vol_1companyName                                     La Cravate Solidaire
# vol_1endDate                                   {'month': 6, 'year': 2021}
# vol_1role                                                 Administratrice
# vol_1startDate                                 {'month': 9, 'year': 2016}

# %%
data.shape
# Out:
# (148, 98)

# %% [markdown]
# ### Export dataset and description dataframe

# %%
data.to_csv("//Users/tatianadeferaudy/Desktop/Bacasable/marche_CT/dataset3.csv", sep=';', index=False)

# %%
data.describe(include='O').T
general_pop_data= pd.DataFrame(data.describe(include="O").T)
general_pop_data.to_csv("//Users/tatianadeferaudy/Desktop/Bacasable/marche_CT/general_pop_data3.csv", sep=';')

# %% [markdown]
# ### Making a copy

# %%
data2=data.copy()

# %%
pd.options.display.max_rows = 105
data.head(5).T
# Out:
#                                                                         0  \
# certif_stated                                                           0
# ed_1degreeName                                                     Master
# ed_1fieldOfStudy                            Business/Managerial Economics
# ed_1schoolName                                                ESCP Europe
# ed_1startDate_month                                                   NaN
# ed_1startDate_year                                                 1998.0
# ed_2degreeName                                                        NaN
# ed_2fieldOfStudy                                                      NaN
# ed_2schoolName                                  Prépa Saint Jean de Douai
# ed_2startDate_month                                                   NaN
# ed_2startDate_year                                                 1996.0
# ed_3degreeName                                               Baccalauréat
# ed_3fieldOfStudy                                                Economics
# ed_3schoolName                                             Lycée Kernanec
# ed_3startDate_month                                                   NaN
# ed_3startDate_year                                                 1993.0
# exp_1companyName                                                 bluenove
# exp_1company_empl_high                                               50.0
# exp_1company_empl_low                                                11.0
# exp_1description        Bluenove accompagne la transformation positive...
# exp_1endDate_month                                                    NaN
# exp_1endDate_year                                                     NaN
# exp_1geoLocationName                                   Paris Area, France
# exp_1industry                                     [Management Consulting]
# exp_1locationName                                      Paris Area, France
# exp_1startDate_month                                                 11.0
# exp_1startDate_year                                                2017.0
# exp_1title                                              Directeur associé
# exp_2companyName                                       Démocratie Ouverte
# exp_2company_empl_high                                               10.0
# exp_2company_empl_low                                                 2.0
# exp_2description                                                      NaN
# exp_2endDate_month                                                    NaN
# exp_2endDate_year                                                     NaN
# exp_2geoLocationName                                                  NaN
# exp_2industry                         [Nonprofit Organization Management]
# exp_2locationName                                                     NaN
# exp_2startDate_month                                                  7.0
# exp_2startDate_year                                                2021.0
# exp_2title                     Membre du Comité d'Orientation Stratégique
# exp_3companyName                  APM - Association Progrès du Management
# exp_3company_empl_high                                            10000.0
# exp_3company_empl_low                                              5001.0
# exp_3description                                                      NaN
# exp_3endDate_month                                                    NaN
# exp_3endDate_year                                                     NaN
# exp_3geoLocationName                                                Paris
# exp_3industry                          [Professional Training & Coaching]
# exp_3locationName                                                   Paris
# exp_3startDate_month                                                  1.0
# exp_3startDate_year                                                2017.0
# exp_3title                                                         Expert
# exp_4companyName                                       Démocratie Ouverte
# exp_4company_empl_high                                               10.0
# exp_4company_empl_low                                                 2.0
# exp_4description        Démocratie Ouverte est un collectif citoyen in...
# exp_4endDate_month                                                    5.0
# exp_4endDate_year                                                  2020.0
# exp_4geoLocationName                                   Paris Area, France
# exp_4industry                         [Nonprofit Organization Management]
# exp_4locationName                                      Paris Area, France
# exp_4startDate_month                                                  1.0
# exp_4startDate_year                                                2018.0
# exp_4title                                                   Co-Président
# exp_5companyName                                        Dassault Systèmes
# exp_5company_empl_high                                                NaN
# exp_5company_empl_low                                             10001.0
# exp_5description        Netvibes provides Dashboard Intelligence ~ tra...
# exp_5endDate_month                                                   10.0
# exp_5endDate_year                                                  2017.0
# exp_5geoLocationName                                                Paris
# exp_5industry                                         [Computer Software]
# exp_5locationName                                                   Paris
# exp_5startDate_month                                                  2.0
# exp_5startDate_year                                                2013.0
# exp_5title               Senior Director, Strategic Business Development
# firstName                                                         Antoine
# geoCountryName                                                     France
# geoLocationName                         Greater Paris Metropolitan Region
# headline                Directeur associé de bluenove, initiateur du m...
# honors_stated                                                           0
# lang_1name                                                        English
# lang_1proficiency                                       FULL_PROFESSIONAL
# lang_2name                                                         French
# lang_2proficiency                                     NATIVE_OR_BILINGUAL
# lang_3name                                                         German
# lang_3proficiency                                              ELEMENTARY
# lang_stated                                                             1
# lastName                                                          Brachet
# lin_details_remplis                                                     2
# over_2_lang                                                             1
# projects_stated                                                         0
# pubs_stated                                                             1
# summary                 Antoine croit à l’intelligence de tous et à la...
# vol_1companyName                                                      NaN
# vol_1endDate                                                          NaN
# vol_1role                                                             NaN
# vol_1startDate                                                        NaN
#
#                                                                         1  \
# certif_stated                                                           0
# ed_1degreeName                                                        NaN
# ed_1fieldOfStudy         Relations Internationales et Sciences Politiques
# ed_1schoolName                         Ecole des Hautes Etudes Politiques
# ed_1startDate_month                                                   NaN
# ed_1startDate_year                                                 2006.0
# ed_2degreeName                                                        NaN
# ed_2fieldOfStudy                    Relations et affaires internationales
# ed_2schoolName                                      The Hebrew University
# ed_2startDate_month                                                   NaN
# ed_2startDate_year                                                 2005.0
# ed_3degreeName                                               Baccalauréat
# ed_3fieldOfStudy          Sciences Economiques et Sociales Option Anglais
# ed_3schoolName                                     Lycée Janson-de-Sailly
# ed_3startDate_month                                                   NaN
# ed_3startDate_year                                                 1998.0
# exp_1companyName                                            ROCH Ventures
# exp_1company_empl_high                                               10.0
# exp_1company_empl_low                                                 2.0
# exp_1description        ROCH Ventures is a Luxembourg based VC fund pr...
# exp_1endDate_month                                                    NaN
# exp_1endDate_year                                                     NaN
# exp_1geoLocationName                                                  NaN
# exp_1industry                          [Venture Capital & Private Equity]
# exp_1locationName                                                     NaN
# exp_1startDate_month                                                  1.0
# exp_1startDate_year                                                2022.0
# exp_1title                                     Founder & Managing Partner
# exp_2companyName                            Boston Consulting Group (BCG)
# exp_2company_empl_high                                                NaN
# exp_2company_empl_low                                             10001.0
# exp_2description        Oversee product innovation at BCG (inclusive o...
# exp_2endDate_month                                                    1.0
# exp_2endDate_year                                                  2022.0
# exp_2geoLocationName                              Région de Paris, France
# exp_2industry                                     [Management Consulting]
# exp_2locationName                                 Région de Paris, France
# exp_2startDate_month                                                  1.0
# exp_2startDate_year                                                2020.0
# exp_2title                                         Director of Innovation
# exp_3companyName                                 Orange Business Services
# exp_3company_empl_high                                                NaN
# exp_3company_empl_low                                             10001.0
# exp_3description        Orange Business Services provides communicatio...
# exp_3endDate_month                                                    6.0
# exp_3endDate_year                                                  2021.0
# exp_3geoLocationName                              Région de Paris, France
# exp_3industry                       [Information Technology and Services]
# exp_3locationName                                 Région de Paris, France
# exp_3startDate_month                                                  9.0
# exp_3startDate_year                                                2016.0
# exp_3title                                          Advisory Board Member
# exp_4companyName                            Boston Consulting Group (BCG)
# exp_4company_empl_high                                                NaN
# exp_4company_empl_low                                             10001.0
# exp_4description        Head of TUNED by BCG.\nBCG change management a...
# exp_4endDate_month                                                    1.0
# exp_4endDate_year                                                  2020.0
# exp_4geoLocationName                              Région de Paris, France
# exp_4industry                                     [Management Consulting]
# exp_4locationName                                 Région de Paris, France
# exp_4startDate_month                                                 11.0
# exp_4startDate_year                                                2017.0
# exp_4title                                                       Director
# exp_5companyName                           GOV " La Météo de l'Opinion ".
# exp_5company_empl_high                                               50.0
# exp_5company_empl_low                                                11.0
# exp_5description        Founded in 2014, GOV rapidly achieved populari...
# exp_5endDate_month                                                   11.0
# exp_5endDate_year                                                  2017.0
# exp_5geoLocationName                              Région de Paris, France
# exp_5industry                                                  [Internet]
# exp_5locationName                                 Région de Paris, France
# exp_5startDate_month                                                  4.0
# exp_5startDate_year                                                2014.0
# exp_5title                                        Co-Founder GOV (exited)
# firstName                                                           Bobby
# geoCountryName                                                     France
# geoLocationName                                      Paris, Île-de-France
# headline                      Founder & Managing Partner at ROCH Ventures
# honors_stated                                                           1
# lang_1name                                                            NaN
# lang_1proficiency                                                     NaN
# lang_2name                                                            NaN
# lang_2proficiency                                                     NaN
# lang_3name                                                            NaN
# lang_3proficiency                                                     NaN
# lang_stated                                                             0
# lastName                                                            Demri
# lin_details_remplis                                                     1
# over_2_lang                                                             0
# projects_stated                                                         0
# pubs_stated                                                             0
# summary                 French Entrepreneur - Founder and Managing Par...
# vol_1companyName                                                      NaN
# vol_1endDate                                                          NaN
# vol_1role                                                             NaN
# vol_1startDate                                                        NaN
#
#                                                                         2  \
# certif_stated                                                           0
# ed_1degreeName                                          Global messaging
# ed_1fieldOfStudy                        Communication orale et rhétorique
# ed_1schoolName          ASO communications / New Economy Organizers Ne...
# ed_1startDate_month                                                   3.0
# ed_1startDate_year                                                 2022.0
# ed_2degreeName          Training program to prepare women to political...
# ed_2fieldOfStudy                        Political sciences and government
# ed_2schoolName                                                  Investies
# ed_2startDate_month                                                   9.0
# ed_2startDate_year                                                 2020.0
# ed_3degreeName                                          Public narrative
# ed_3fieldOfStudy                               Leadership organisationnel
# ed_3schoolName                    Leading change network - Marshall Ganz
# ed_3startDate_month                                                   9.0
# ed_3startDate_year                                                 2020.0
# exp_1companyName                                    Multitudes Foundation
# exp_1company_empl_high                                               10.0
# exp_1company_empl_low                                                 2.0
# exp_1description        Multitudes supports people across Europe to re...
# exp_1endDate_month                                                    NaN
# exp_1endDate_year                                                     NaN
# exp_1geoLocationName                                                  NaN
# exp_1industry                         [Nonprofit Organization Management]
# exp_1locationName                                                     NaN
# exp_1startDate_month                                                  9.0
# exp_1startDate_year                                                2022.0
# exp_1title                                                  Co-directrice
# exp_2companyName                                  SD Conseil et formation
# exp_2company_empl_high                                                NaN
# exp_2company_empl_low                                                 NaN
# exp_2description        I equip and support those who want to make the...
# exp_2endDate_month                                                    NaN
# exp_2endDate_year                                                     NaN
# exp_2geoLocationName                                                  NaN
# exp_2industry                                                         NaN
# exp_2locationName                                                     NaN
# exp_2startDate_month                                                  9.0
# exp_2startDate_year                                                2021.0
# exp_2title              Consultant, trainer and organizer in activism ...
# exp_3companyName                      ECS (European Communication School)
# exp_3company_empl_high                                              200.0
# exp_3company_empl_low                                                51.0
# exp_3description                                                      NaN
# exp_3endDate_month                                                    9.0
# exp_3endDate_year                                                  2022.0
# exp_3geoLocationName                                                Paris
# exp_3industry                                          [Higher Education]
# exp_3locationName                                                   Paris
# exp_3startDate_month                                                 10.0
# exp_3startDate_year                                                2021.0
# exp_3title                       Teacher "New activism, digital advocacy"
# exp_4companyName        EFAP - Ecole des nouveaux métiers de la commun...
# exp_4company_empl_high                                              200.0
# exp_4company_empl_low                                                51.0
# exp_4description                                                      NaN
# exp_4endDate_month                                                    9.0
# exp_4endDate_year                                                  2022.0
# exp_4geoLocationName                                                Paris
# exp_4industry                                          [Higher Education]
# exp_4locationName                                                   Paris
# exp_4startDate_month                                                  9.0
# exp_4startDate_year                                                2021.0
# exp_4title                               Teacher "Influence and lobbying"
# exp_5companyName                                               Change.org
# exp_5company_empl_high                                              500.0
# exp_5company_empl_low                                               201.0
# exp_5description        My team and I, we give people the power to cre...
# exp_5endDate_month                                                   10.0
# exp_5endDate_year                                                  2021.0
# exp_5geoLocationName                                   Paris Area, France
# exp_5industry                                                  [Internet]
# exp_5locationName                                      Paris Area, France
# exp_5startDate_month                                                  2.0
# exp_5startDate_year                                                2018.0
# exp_5title                                             Executive Director
# firstName                                                           Sarah
# geoCountryName                                                     France
# geoLocationName                                      Paris, Île-de-France
# headline                Co-director Multitudes Foundation - Activist a...
# honors_stated                                                           0
# lang_1name                                                        Anglais
# lang_1proficiency                                     NATIVE_OR_BILINGUAL
# lang_2name                                                       Espagnol
# lang_2proficiency                                                     NaN
# lang_3name                                                        Italien
# lang_3proficiency                                                     NaN
# lang_stated                                                             1
# lastName                                                          Durieux
# lin_details_remplis                                                     2
# over_2_lang                                                             1
# projects_stated                                                         0
# pubs_stated                                                             1
# summary                 Inspired by the power we can build to change t...
# vol_1companyName                               Collectif Quartier Général
# vol_1endDate                                   {'month': 1, 'year': 2022}
# vol_1role                                                      Co-Founder
# vol_1startDate                                 {'month': 1, 'year': 2022}
#
#                                                                         3  \
# certif_stated                                                           0
# ed_1degreeName                                        Master informatique
# ed_1fieldOfStudy                       Architecture logicielle distribuée
# ed_1schoolName                                      Université Bordeaux I
# ed_1startDate_month                                                   NaN
# ed_1startDate_year                                                 2004.0
# ed_2degreeName                                                        NaN
# ed_2fieldOfStudy                                                      NaN
# ed_2schoolName                                                        NaN
# ed_2startDate_month                                                   NaN
# ed_2startDate_year                                                    NaN
# ed_3degreeName                                                        NaN
# ed_3fieldOfStudy                                                      NaN
# ed_3schoolName                                                        NaN
# ed_3startDate_month                                                   NaN
# ed_3startDate_year                                                    NaN
# exp_1companyName                                                 Jolicode
# exp_1company_empl_high                                                NaN
# exp_1company_empl_low                                                 NaN
# exp_1description        I co-created JoliCode in march 2012 in order t...
# exp_1endDate_month                                                    NaN
# exp_1endDate_year                                                     NaN
# exp_1geoLocationName                                                  NaN
# exp_1industry                                                         NaN
# exp_1locationName                                                     NaN
# exp_1startDate_month                                                  3.0
# exp_1startDate_year                                                2012.0
# exp_1title                                                     Web expert
# exp_2companyName                                               Clever Age
# exp_2company_empl_high                                              500.0
# exp_2company_empl_low                                               201.0
# exp_2description        Expert PHP : audit, performance, méthodologie ...
# exp_2endDate_month                                                    1.0
# exp_2endDate_year                                                  2012.0
# exp_2geoLocationName                                                  NaN
# exp_2industry                       [Information Technology and Services]
# exp_2locationName                                                     NaN
# exp_2startDate_month                                                  9.0
# exp_2startDate_year                                                2009.0
# exp_2title                                          Consultant Expert PHP
# exp_3companyName                                     Solution Interactive
# exp_3company_empl_high                                                NaN
# exp_3company_empl_low                                                 NaN
# exp_3description                                                      NaN
# exp_3endDate_month                                                    9.0
# exp_3endDate_year                                                  2009.0
# exp_3geoLocationName                                                  NaN
# exp_3industry                                                         NaN
# exp_3locationName                                                     NaN
# exp_3startDate_month                                                  6.0
# exp_3startDate_year                                                2006.0
# exp_3title                                                 Lead developer
# exp_4companyName                                                      NaN
# exp_4company_empl_high                                                NaN
# exp_4company_empl_low                                                 NaN
# exp_4description                                                      NaN
# exp_4endDate_month                                                    NaN
# exp_4endDate_year                                                     NaN
# exp_4geoLocationName                                                  NaN
# exp_4industry                                                         NaN
# exp_4locationName                                                     NaN
# exp_4startDate_month                                                  NaN
# exp_4startDate_year                                                   NaN
# exp_4title                                                            NaN
# exp_5companyName                                                      NaN
# exp_5company_empl_high                                                NaN
# exp_5company_empl_low                                                 NaN
# exp_5description                                                      NaN
# exp_5endDate_month                                                    NaN
# exp_5endDate_year                                                     NaN
# exp_5geoLocationName                                                  NaN
# exp_5industry                                                         NaN
# exp_5locationName                                                     NaN
# exp_5startDate_month                                                  NaN
# exp_5startDate_year                                                   NaN
# exp_5title                                                            NaN
# firstName                                                         Bastien
# geoCountryName                                                     France
# geoLocationName                         Greater Paris Metropolitan Region
# headline                                         Web expert chez Jolicode
# honors_stated                                                           0
# lang_1name                                                        Anglais
# lang_1proficiency                                                     NaN
# lang_2name                                                            NaN
# lang_2proficiency                                                     NaN
# lang_3name                                                            NaN
# lang_3proficiency                                                     NaN
# lang_stated                                                             1
# lastName                                                          Jaillot
# lin_details_remplis                                                     3
# over_2_lang                                                             0
# projects_stated                                                         1
# pubs_stated                                                             1
# summary                 IT Consultant, Technical Expert, Lead develope...
# vol_1companyName                                                      NaN
# vol_1endDate                                                          NaN
# vol_1role                                                             NaN
# vol_1startDate                                                        NaN
#
#                                                                         4
# certif_stated                                                           0
# ed_1degreeName                                                   Master 2
# ed_1fieldOfStudy                                      Sciences politiques
# ed_1schoolName                       Université Paris 1 Panthéon-Sorbonne
# ed_1startDate_month                                                   NaN
# ed_1startDate_year                                                 2005.0
# ed_2degreeName                                                    Licence
# ed_2fieldOfStudy                                                    Droit
# ed_2schoolName                          Université Lille 2 Droit et Santé
# ed_2startDate_month                                                   NaN
# ed_2startDate_year                                                 2002.0
# ed_3degreeName                                                        NaN
# ed_3fieldOfStudy                                                      NaN
# ed_3schoolName                                                        NaN
# ed_3startDate_month                                                   NaN
# ed_3startDate_year                                                    NaN
# exp_1companyName                                            Cap Collectif
# exp_1company_empl_high                                               50.0
# exp_1company_empl_low                                                11.0
# exp_1description        Pilotage des activités des pôles conseil, comm...
# exp_1endDate_month                                                    NaN
# exp_1endDate_year                                                     NaN
# exp_1geoLocationName                                                  NaN
# exp_1industry                                         [Computer Software]
# exp_1locationName                                                     NaN
# exp_1startDate_month                                                  3.0
# exp_1startDate_year                                                2022.0
# exp_1title                                      Directrice des opérations
# exp_2companyName                                            Cap Collectif
# exp_2company_empl_high                                               50.0
# exp_2company_empl_low                                                11.0
# exp_2description        Key figures : 250 clients / 2,5 M€ CA / 30 ETP...
# exp_2endDate_month                                                    3.0
# exp_2endDate_year                                                  2022.0
# exp_2geoLocationName                                                  NaN
# exp_2industry                                         [Computer Software]
# exp_2locationName                                                     NaN
# exp_2startDate_month                                                  2.0
# exp_2startDate_year                                                2017.0
# exp_2title                        Directrice du développement commercial
# exp_3companyName                                                 Animafac
# exp_3company_empl_high                                               50.0
# exp_3company_empl_low                                                11.0
# exp_3description        Pilotage du projet associatif et des plaidoyer...
# exp_3endDate_month                                                    1.0
# exp_3endDate_year                                                  2017.0
# exp_3geoLocationName                                                Paris
# exp_3industry                               [Civic & Social Organization]
# exp_3locationName                                                   Paris
# exp_3startDate_month                                                  9.0
# exp_3startDate_year                                                2012.0
# exp_3title                                              Déléguée générale
# exp_4companyName                                                 Animafac
# exp_4company_empl_high                                               50.0
# exp_4company_empl_low                                                11.0
# exp_4description                                                      NaN
# exp_4endDate_month                                                    9.0
# exp_4endDate_year                                                  2012.0
# exp_4geoLocationName                                                Paris
# exp_4industry                               [Civic & Social Organization]
# exp_4locationName                                                   Paris
# exp_4startDate_month                                                 10.0
# exp_4startDate_year                                                2009.0
# exp_4title                        Directrice administrative et financière
# exp_5companyName                                          Mairie de Paris
# exp_5company_empl_high                                                NaN
# exp_5company_empl_low                                             10001.0
# exp_5description                                                      NaN
# exp_5endDate_month                                                    NaN
# exp_5endDate_year                                                  2009.0
# exp_5geoLocationName                                                  NaN
# exp_5industry                                 [Government Administration]
# exp_5locationName                                                     NaN
# exp_5startDate_month                                                  NaN
# exp_5startDate_year                                                2008.0
# exp_5title              Chargée de mission auprès du chef de cabinet d...
# firstName                                                          Coline
# geoCountryName                                                     France
# geoLocationName                         Greater Paris Metropolitan Region
# headline                     Directrice des opérations chez Cap Collectif
# honors_stated                                                           0
# lang_1name                                                            NaN
# lang_1proficiency                                                     NaN
# lang_2name                                                            NaN
# lang_2proficiency                                                     NaN
# lang_3name                                                            NaN
# lang_3proficiency                                                     NaN
# lang_stated                                                             0
# lastName                                                         Vanneroy
# lin_details_remplis                                                     1
# over_2_lang                                                             0
# projects_stated                                                         1
# pubs_stated                                                             0
# summary                                                               NaN
# vol_1companyName                                     La Cravate Solidaire
# vol_1endDate                                   {'month': 6, 'year': 2021}
# vol_1role                                                 Administratrice
# vol_1startDate                                 {'month': 9, 'year': 2016}

# %% [markdown]
# #### Education EDA

# %%
ed_columns=[i for i in data.columns if "ed_" in i]
print(ed_columns)
# Out:
# ['ed_1degreeName', 'ed_1fieldOfStudy', 'ed_1schoolName', 'ed_1startDate_month', 'ed_1startDate_year', 'ed_2degreeName', 'ed_2fieldOfStudy', 'ed_2schoolName', 'ed_2startDate_month', 'ed_2startDate_year', 'ed_3degreeName', 'ed_3fieldOfStudy', 'ed_3schoolName', 'ed_3startDate_month', 'ed_3startDate_year']

# %%
data[ed_columns].describe()
# Out:
#        ed_1startDate_month  ed_1startDate_year  ed_2startDate_month  \
# count            11.000000          138.000000             5.000000
# mean              6.181818         2008.478261             7.000000
# std               3.970345            9.334980             3.082207
# min               1.000000         1968.000000             2.000000
# 25%               3.000000         2003.000000             6.000000
# 50%               9.000000         2010.000000             9.000000
# 75%               9.000000         2015.000000             9.000000
# max              12.000000         2023.000000             9.000000
#
#        ed_2startDate_year  ed_3startDate_month  ed_3startDate_year
# count          123.000000             3.000000           99.000000
# mean          2008.512195             6.000000         2006.474747
# std              8.165668             3.605551            8.700626
# min           1983.000000             2.000000         1982.000000
# 25%           2003.000000             4.500000         2002.000000
# 50%           2010.000000             7.000000         2009.000000
# 75%           2015.000000             8.000000         2013.000000
# max           2022.000000             9.000000         2023.000000

# %%
data[ed_columns].describe(include='O')
# Out:
#          ed_1degreeName ed_1fieldOfStudy ed_1schoolName ed_2degreeName  \
# count               130              114            143            110
# unique              108              105            103             94
# top     Master's degree        Marketing    Sciences Po         Master
# freq                 10                3             10              7
#
#                                        ed_2fieldOfStudy ed_2schoolName  \
# count                                               104            130
# unique                                               97            107
# top     Business Administration and Management, General    Sciences Po
# freq                                                  3              7
#
#        ed_3degreeName   ed_3fieldOfStudy ed_3schoolName
# count              92                 79            107
# unique             73                 75             96
# top      Baccalauréat  Science politique    Sciences Po
# freq                6                  2              6

# %%
# Education info : 
# education start dates are around 2007 (2009, 2009, 2006), with an std of 8 to 9. 
# these people were in university mainly between 1998 and 2016 
# although there are some that state education in 1968 (min), and the max is 2023 as a start date
# most frequent degree is master's, and most frequent school is Sciences Po. 
# most frequent fields of study, however, are business administration and management and marketing.

# %%
from unidecode import unidecode 

def recoding_degree(x):
    x=str(x).lower()
    x=unidecode(x)
    if ("master" in x) or ("msc" in x) or ("m.sc" in x) or ("maitrise" in x) or ('m1' in x) or ('m2' in x) or ("diplome d" in x) or ("polytechnique" in x) or ('sciences po' in x):
        return 'master'
    elif ("baccalaureat" in x): 
        return 'baccalaureat'
    elif ("bachelor" in x) or ("licence" in x) or ("deug" in x) :
        return 'licence'
    elif ("phd" in x) or ("dea" in x) or ("dess" in x) or ("doctorat" in x) or ("ph.d" in x):
        return 'dea_dess_phd'
    elif ("prepa" in x) or ("hypokhagne" in x): 
        return 'prepa'
    elif ("mba" in x) or ("executive education" in x) : 
        return 'mba'
    elif ("bac" in x): 
        return 'baccalaureat'
    elif ("bts" in x) or  ("dut" in x): 
        return 'bts_dut'
    else:
        return x

# %%
data['recoded_degree_1']="NA"
data['recoded_degree_2']="NA"
data['recoded_degree_3']="NA"
data["recoded_degree_1"]= data["ed_1degreeName"].apply(recoding_degree)
data["recoded_degree_2"]= data["ed_2degreeName"].apply(recoding_degree)
data["recoded_degree_3"]= data["ed_3degreeName"].apply(recoding_degree)

# %% [markdown]
# #### Total degrees table

# %%
degree1=pd.DataFrame(data['recoded_degree_1'].value_counts().reset_index())
degree1.columns=["degree", "count"]

# %%
degree2= pd.DataFrame(data['recoded_degree_2'].value_counts().reset_index())
degree2.columns=["degree", "count"]

# %%
degree3=pd.DataFrame(data['recoded_degree_3'].value_counts().reset_index())
degree3.columns=["degree", "count"]

# %%
degree2.head()
# Out:
#          degree  count
# 0        master     54
# 1           nan     38
# 2       licence     10
# 3  dea_dess_phd      8
# 4  baccalaureat      4

# %%
total_degrees= degree1.merge(degree2, how='outer', on="degree").merge(degree3, how="outer", on="degree")

# %%
total_degrees["total"]=0
total_degrees.fillna(0, inplace=True)
total_degrees["total"]= total_degrees["count_x"]+total_degrees["count_y"]+total_degrees["count"]
(total_degrees[["degree", "total"]].sort_values(by="total", ascending=False))[0:10]
# Out:
#                 degree  total
# 0               master  168.0
# 1                  nan  112.0
# 5              licence   34.0
# 2         dea_dess_phd   20.0
# 6         baccalaureat   14.0
# 3                  mba   10.0
# 33               prepa    8.0
# 4              bts_dut    4.0
# 60    exchange program    3.0
# 34  associate's degree    3.0

# %% [markdown]
# #### degree variables

# %%
(data['recoded_degree_1'].value_counts())[0:10]
(data['recoded_degree_2'].value_counts())[0:10]
(data['recoded_degree_3'].value_counts())[0:10]
# Out:
# nan                         56
# master                      32
# licence                     21
# baccalaureat                 8
# prepa                        4
# dea_dess_phd                 3
# exchange program             3
# mba                          3
# wset certificate level 2     1
# label hf management          1
# Name: recoded_degree_3, dtype: int64

# %%
data['dea_dess_phd']=0
data['master']=0
data['mba']=0
data['licence']=0
data["prepa"]=0
data.loc[(data.recoded_degree_1 =='master')|(data.recoded_degree_2 =='master')|(data.recoded_degree_3 =='master'), 'master']=1
data.loc[(data.recoded_degree_1 =='master')|(data.recoded_degree_2 =='master')|(data.recoded_degree_3 =='master'), 'licence']=1
data['master'].sum()
# Out:
# 110

# %%
data.loc[(data.recoded_degree_1 =='dea_dess_phd')|(data.recoded_degree_2 =='dea_dess_phd')|(data.recoded_degree_3 =='dea_dess_phd'), 'dea_dess_phd']=1
data.loc[(data.recoded_degree_1 =='dea_dess_phd')|(data.recoded_degree_2 =='dea_dess_phd')|(data.recoded_degree_3 =='dea_dess_phd'), 'master']=1
data.loc[(data.recoded_degree_1 =='dea_dess_phd')|(data.recoded_degree_2 =='dea_dess_phd')|(data.recoded_degree_3 =='dea_dess_phd'), 'licence']=1
data['dea_dess_phd'].sum()
# Out:
# 19

# %%
data.loc[(data.recoded_degree_1 =='mba')|(data.recoded_degree_2 =='mba')|(data.recoded_degree_3 =='mba'), 'mba']=1
data['mba'].sum()
# Out:
# 8

# %%
data.loc[(data.recoded_degree_1 =='prepa')|(data.recoded_degree_2 =='prepa')|(data.recoded_degree_3 =='prepa'), 'prepa']=1
data['prepa'].sum()
# Out:
# 8

# %%
#Licence, bts, DUT 
data.loc[(data.recoded_degree_1 =='bts_dut')|(data.recoded_degree_2 =='bts_dut')|(data.recoded_degree_3 =='bts_dut'), 'licence']=1
data.loc[(data.recoded_degree_1 =='licence')|(data.recoded_degree_2 =='licence')|(data.recoded_degree_3 =='licence'), 'licence']=1
data['licence'].sum()
# Out:
# 126

# %% [markdown]
# #### field of study

# %%
data[["ed_1fieldOfStudy", 'ed_2fieldOfStudy', "ed_3fieldOfStudy"]].fillna('NR', inplace=True)
# NA= 34, 44, 69
# Out:
# /var/folders/5g/jskfzb8j377fh7wl3_rxvkrc0000gn/T/ipykernel_2817/2228701847.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[["ed_1fieldOfStudy", 'ed_2fieldOfStudy', "ed_3fieldOfStudy"]].fillna('NR', inplace=True)

# %%
print(list(data["ed_1fieldOfStudy"]))
print(list(data["ed_2fieldOfStudy"]))
print(list(data["ed_3fieldOfStudy"]))
# Out:
# ['Business/Managerial Economics', 'Relations Internationales et Sciences Politiques', 'Communication orale et rhétorique', 'Architecture logicielle distribuée', 'Sciences politiques', nan, 'Written & Audiovisual Journalism', nan, 'Strategy', 'Management des Ressources Humaines', 'Conception de Produits Industriels', 'International Politics', nan, 'Master of Digital Business', 'Management', 'Management', 'Focus: Democratic Innovation', 'Public Affairs', nan, 'Financial Accounting', 'Business and Marketing', 'Computer Science', 'Circular Economy', 'Etudes politiques', 'Sciences politiques', 'Relations et affaires internationales', 'Product Management', nan, 'Finance and Consulting', 'Specialization in Entrepreneurship', 'Économie', 'in Global Leadership and Public Policy for the 21st century', nan, 'Sciences Economiques', "Politiques de l'Environnement", 'Community management', nan, 'Political science', nan, 'Business School', 'Marketing', 'Relations et affaires internationales', 'Multimedia product design and management', 'Management (AMBA accreditation)', nan, 'Journalisme', 'Communication, General', nan, 'Communication & Stratégie', 'Langues étrangères et littératures, général', 'Digital Marketing', 'Political sciences & European studies', 'Musique', nan, 'Affaires publiques - Ingénierie de la concertation', 'International Business', 'Governance and International Intelligence ', 'Sciences politiques et gouvernement', 'Ecologie, biodiversité et évolution, spécialité écologie théorique et modélisation', 'Histoire européenne', 'Ingénierie', 'EU Security and Foreign Policy', 'Science et ingénierie civil', 'Public Business Law', nan, 'Chaudronnerie / chaudronnier', 'Marketing', 'Management', 'Gestion des ressources humaines  / administration du personnel, général', 'International Business', "aménagement, d'urbanisme et développement local", 'Applied Mathematics, Computer Science, Physics, Biology', nan, "Design d'interface, Design de service, Ingénierie des connaissances", 'Biologie', 'Drawing Painting Charcoal Sculpture', 'Asuntos Europeos', nan, nan, 'Sciences sociales / Marketing', 'Intelligence Economique', 'Political Science, Psychology', nan, 'Master 2 : Conseil et Expertise en Action Publique', nan, nan, 'Democratic transformation & Ecological Transitioning', 'Science and Technology Studies', nan, 'Political Science and Government', 'Business Administration and Management, General', 'Urban Design', 'Hospitality industry', nan, nan, 'Section Politique', nan, 'Mechanical Engineering - Industrial Design Engineering', 'Governing the Large Metropolis', 'EcoFi - Section Affaires Internationales', 'Hec - Entrepreneurs', 'Digital Transformation in Government ', nan, nan, 'Relations internationales, Géopolitique, Économie', nan, 'Smart cities, aménagement urbain et du territoire, ', nan, nan, 'Marketing', nan, 'Paris, France', 'Ecology, Evolution, Systematics, and Population Biology', 'Membre de la Chaire ESSEC - BNP Paribas Immobilier', 'Economie appliquée / Section Commerce International', 'Agricultural Development ', 'Coaching', 'Marketing, communication, e-business', 'Business/Commerce, General', 'Focus on cyber issues and digital trends', 'Entraînement sportif / entraîneur', 'DROIT INTERNATIONAL', 'Étude de la communication et des médias', nan, 'Business Administration and Management, General', 'Business Administration and Management, General', 'Environmental Studies', nan, 'Strategic Management', 'International Law', 'Communication publique et politique', nan, 'European Political and Governance Studies ', nan, 'Coopération et développement', 'Oxford Internet Institute (OII)', 'Urban Fesign', 'Économie internationale', 'Communication et Marketing Digital, Médias, Relations Publiques', 'Marketing Research and Strategic development', 'Ecole Supérieure de Commerce', nan, 'Histoire et gestion du patrimoine culturel', nan, 'Preparatory class to French competitive exams for high civil service', 'Political Science and Economics', 'Ing ...
# [nan, 'Relations et affaires internationales', 'Political sciences and government', nan, 'Droit', nan, 'Political Science and Government', nan, 'Strategy and organisation', nan, 'Génie Mécanique', 'Business Administration and Management, General', nan, 'Public affairs and management', 'Economics & Management', 'Marketing', 'International Political Economy, Minor: African Studies', 'Web Development Ruby on Rails', nan, 'M&A', 'International affairs and Foreign Policy', 'Informatik', 'Informations Systems & Telecommunication Networks', 'Etudes politiques', nan, nan, 'Public real estate law & public contract', 'Communication, général', 'Asian Business Environment', 'Exchange Student, 6 months', nan, nan, 'Histoire', nan, nan, nan, 'Techniques et langage des médias', 'Political Science', nan, 'Economics', 'Web3', nan, "Métiers du Multimédia et de l'Internet", 'Laws & Entrepreneurship', nan, 'Littérature', 'communication, marketing', nan, "Startégie, gestion, reprise et création d'entreprise.", "Technologies de l''information", 'Management', 'Comparative policy analysis', nan, 'Health in All Policies', 'Science politique - Relations internationales ', 'Corporate Strategy', 'Regional governance, speciality Africa and Migrations', 'Histoire, droit, économie, sociologie politique, relations internationales', 'Économie', 'Histoire', 'Ingénierie', 'Defence Policy & Foreign Relations', 'Génie civil', 'Public Administration', nan, nan, nan, 'Mathematics, Computer Science', 'Management de projet', 'International Business (Global MBA courses)', 'Aménagement du Territoire', 'Bioinformatics, Evolution, Graph Theory', 'International Business', 'Histoire des médias', nan, 'Fashion Department', 'Ciencias Políticas y de la Administración', nan, 'Psychologie du travail, des organisations et du personnel', 'Sciences economiques', 'Travail Politique et Parlementaire', 'Business Administration and Management, General', nan, 'Spécialité économique et sociale', 'Economie internationale', nan, 'Political science', nan, nan, 'Political Science', nan, 'Urban Planning', 'Wine business', 'Design collaboratif', 'Relations et affaires internationales', 'Langues Etrangères Appliquées', nan, 'Industrial Design Engineering', "Droit de l'urbanisme et de l'aménagement ", 'Chinese Studies', 'Public Administration', 'Applying Behavioral Insights to the Design of Public Policy', nan, nan, 'Géopolitique, Relations internationales', nan, 'Design Civique', 'Management - Strategy', nan, 'Marketing et innovation', 'Mandarin Chinese', nan, nan, nan, 'Section Service Public', 'Mastère en Politique et Action Publique pour le Développement Durable ', 'English Language and Literature/Letters', nan, 'Commerce international', 'Econometrics and Quantitative Economics', 'Gestion publique, conduite de changement et modernisation, évaluation des politiques publiques', 'SURETE, MANAGEMENT DU RISQUE', 'Sociologie / Sciences politiques', 'Economics', 'Business Administration and Management, General', 'International Education Policy', 'Energy, Environment, and Natural Resources Law', nan, 'Gouvernance', 'Law & Economics', 'Communication des organisations, des entreprises et des territoires', nan, 'Droit du plaidoyer et Affaires publiques ', nan, 'International Economics and International Management', 'School of Management and Innovation', 'Urban Design', nan, nan, 'Communication and marketing', 'voie commerciale, scientifique', nan, 'Muséologie / étude des musées', 'affaires publiques', 'Constitutional Law', 'Political Science and Government; Economics', 'International Environmental Management', 'Political Sciences']
# ['Economics', 'Sciences Economiques et Sociales Option Anglais', 'Leadership organisationnel', nan, nan, 'Communication, rédaction et multimédia', 'Computer Science', nan, nan, nan, nan, 'Ciencias Politicas y de la Administracion', nan, 'Law', 'Préparation aux concours des grandes écoles de commerce', nan, 'Economics, Philosophy, English Literature, ', 'Mandarin', nan, 'Programme Doctoral en Stratégie et Réseaux Décisionnels  ', nan, 'Computer Science', nan, nan, nan, 'Danse classique et contemporaine', 'Competition and market regulation', 'Sociologie et linguistique', nan, nan, nan, 'Economics and Finance - Political Science', nan, nan, nan, nan, 'Lettres modernes', 'Droit', nan, 'Economics - Mathematics', 'Finance, général', nan, nan, 'Half year exchange programme (Erasmus) in Foreign Law', nan, 'Mandarin', nan, nan, nan, nan, 'Business Administration', nan, nan, 'Collège Coopératif de Bretagne', 'Science politique', nan, 'International Relations', 'Science Politique, Sciences économiques', 'Environment', 'Histoire européenne', 'Scientifique Spécialité mathématiques', 'Management and Information Systems.', 'Génie civil', 'Mathematics and Computer Sciences', nan, 'Gymnastique Artistique Masculine', 'economic', 'Vins et spiriteux', nan, 'Histoire, Philosophie, Littérature française, anglaise et espagnole, Grec ancien, Latin', nan, 'Biodiversity, Ecology, Evolution', 'Sciences politiques et gouvernement', nan, nan, 'Business school', nan, nan, nan, 'filière économie industrielle', 'Science politique, option Travail Politique et Parlementaire', 'Media and Communications', nan, nan, nan, nan, 'Political Science, International Development and Social Entrepreneurship', 'Defense, Geostrategy and Industrial Dynamics', 'Droit public - mention Administration publique', 'International Affairs and Economics', nan, 'Urban Studies/Affairs; Development Economics', 'Philosophie', 'Science politique', 'Histoire Moderne', nan, nan, 'Mechanical Engineering', 'Urbanisme, Philosophie, Sciences Politiques.', 'Economics, Business', nan, 'Public Financial Management', nan, nan, 'Sociologie politique, Relations internationales, Histoire', nan, "Aménagements de l'espace (ITIAPE)", nan, nan, 'Film Studies', nan, 'International Relations and European Studies', nan, nan, nan, 'Dual Degree : Sciences and Environmental Policy', 'Political sciences, international relations', nan, nan, 'Computer Sciences, Economics, Mathematics', 'Sciences politiques et gouvernement', nan, 'Sciences sociales et économiques', nan, nan, 'International Education Policy', 'Management & Mixité et égalité professionnelle hommes-femmes', nan, 'Classe préparatoire HEC', nan, 'Communication and medias', nan, 'Politiques Publiques', 'Scientifique mention Très bien', 'Business', 'Faculty of Arts and Social Sciences', 'Urban Design', nan, nan, nan, 'spécialité Mathématiques', nan, "Histoire de l'art / art moderne et contemporain", 'Droit public, économie, finances publiques, gestion locale, questions européennes, culture générale', 'Constitutional law', 'Political Science and Government', 'Strategic Leadership towards Sustainability', nan]

# %%
def recoding_field_study(x):
    x=str(x).lower()
    y=[]
    x=unidecode(x)
    z='NR'
    if x=="nan":
        return z
    else:
        if ("science po" in x) or ("sciences po" in x) or ("politic" in x) or ('politique' in x) or ("gouvernement" in x) or ("government" in x):
            y.append("sciences_po")
        if ("action publique" in x) or ("affaires publiques" in x) or ("public" in x) or ("administration publique" in x) or ("gestion publique" in x) or ("policy" in x) or ("relations publiques" in x) :
            y.append("AP")
        if ("economi" in x) or ('economy' in x):
            y.append("economie")
        if ("droit" in x) or ("law" in x):
            y.append("droit")
        if ("international relations" in x) or ("relations internationales" in x) or ("affaires internationales" in x) or ("foreign" in x) or ("affaires internationales" in x):
            y.append("RI")
        if ("lettres" in x) or ("litter" in x) or ("langu" in x) or ("liter" in x):
            y.append("lettres")
        if ("business" in x) or ("commerc" in x):
            y.append("business")
        if ("manage" in x):
            y.append("management")
        if ("computer" in x) or ("informatique" in x) or ("web development" in x) or ("information" in x):
            y.append("informatique")
        if ("amenagement" in x) or ("urba" in x):
            y.append("urba_amgt")
        if ("ingenie" in x) or ("engineer" in x):
            y.append("ingenierie")
        if ("communication" in x):
            y.append("communication")
        if ("histoire" in x) or ("history" in x) or ("philosophie" in x) or ("philosophy" in x):
            y.append("hist_philo")
        if ("media" in x):
            y.append("media")
        if ("financ" in x):
            y.append("finance")  
        if 'journal' in x:
            y.append("journalisme")
        if 'strateg' in x:
            y.append("strategie")
        if ("digital" in x) or ("logiciel" in x):
            y.append("numerique")
        if ("international" in x) or ("europe" in x):
            y.append("international") 
        if ('design' in x) or ('conception' in x):
            y.append('design')
        if ("ecolog"in x) or ('environment' in x) or ("biodiv" in x) or ("environnement" in x) or ("sustain" in x) or ("durable" in x):
            y.append("environnement")
        if ("entrepr" in x):
            y.append("entrepreneuriat")
        if ('math' in x):
            y.append ("maths")
        y=' '.join(y)
        if len(y)<1:
            return 'autre'
        else:
            return y

# %%
data["fieldofstudy1"]='other'
data['fieldofstudy1']=data["ed_1fieldOfStudy"].apply(recoding_field_study)
data.fieldofstudy1.value_counts()
# Out:
# NR                                       34
# autre                                    21
# sciences_po                               8
# management                                7
# environnement                             4
# economie                                  4
# business                                  4
# RI international                          3
# urba_amgt                                 3
# AP                                        3
# business management                       3
# numerique                                 3
# sciences_po international                 3
# business international                    2
# ingenierie design                         2
# finance                                   2
# strategie                                 2
# journalisme                               2
# communication                             2
# entrepreneuriat                           2
# ingenierie                                2
# droit international                       2
# international                             2
# sciences_po numerique                     1
# sciences_po economie RI international     1
# economie business international           1
# business communication                    1
# sciences_po economie                      1
# communication media                       1
# sciences_po communication                 1
# economie international                    1
# AP communication media numerique          1
# urba_amgt design                          1
# hist_philo                                1
# ingenierie environnement                  1
# management strategie                      1
# economie business management              1
# informatique maths                        1
# AP droit business                         1
# AP RI                                     1
# hist_philo international                  1
# sciences_po RI international              1
# AP ingenierie                             1
# lettres                                   1
# communication strategie                   1
# management media design                   1
# sciences_po environnement                 1
# informatique                              1
# business numerique                        1
# design                                    1
# management international                  1
# Name: fieldofstudy1, dtype: int64

# %%
data["fieldofstudy2"]='other'
data['fieldofstudy2']=data["ed_2fieldOfStudy"].apply(recoding_field_study)
data.fieldofstudy2.value_counts()
# Out:
# NR                                                        44
# autre                                                     17
# sciences_po                                               10
# economie                                                   6
# AP                                                         5
# management                                                 4
# business management                                        3
# business international                                     3
# lettres                                                    3
# communication                                              3
# hist_philo                                                 2
# design                                                     2
# business                                                   2
# urba_amgt                                                  2
# RI international                                           2
# media                                                      2
# sciences_po RI international                               2
# strategie                                                  2
# informatique                                               2
# droit                                                      2
# AP droit                                                   2
# economie management international                          1
# communication entrepreneuriat                              1
# urba_amgt design                                           1
# economie droit                                             1
# sciences_po economie                                       1
# AP international                                           1
# sciences_po AP                                             1
# sciences_po AP environnement                               1
# management strategie                                       1
# AP design                                                  1
# droit urba_amgt                                            1
# ingenierie design                                          1
# droit environnement                                        1
# business environnement                                     1
# economie international                                     1
# hist_philo media                                           1
# AP management                                              1
# economie management                                        1
# informatique maths                                         1
# AP RI                                                      1
# ingenierie                                                 1
# sciences_po economie droit RI hist_philo international     1
# sciences_po economie international                         1
# AP RI international                                        1
# entrepreneuriat                                            1
# informatique communication                                 1
# droit entrepreneuriat                                      1
# management international environnement                     1
# Name: fieldofstudy2, dtype: int64

# %%
data["fieldofstudy3"]='other'
data['fieldofstudy3']=data["ed_3fieldOfStudy"].apply(recoding_field_study)
data.fieldofstudy3.value_counts()
# Out:
# NR                                           69
# autre                                        14
# sciences_po                                   8
# economie                                      5
# business                                      4
# communication media                           3
# droit                                         3
# hist_philo                                    3
# maths                                         2
# RI international                              2
# strategie                                     2
# informatique                                  2
# environnement                                 2
# AP management finance                         1
# economie business                             1
# urba_amgt                                     1
# sciences_po RI hist_philo international       1
# sciences_po urba_amgt hist_philo              1
# economie informatique maths                   1
# AP environnement                              1
# sciences_po RI international                  1
# AP international                              1
# management                                    1
# urba_amgt design                              1
# AP economie droit finance international       1
# ingenierie                                    1
# informatique maths                            1
# economie urba_amgt                            1
# economie international                        1
# AP droit                                      1
# sciences_po international entrepreneuriat     1
# lettres hist_philo                            1
# management informatique                       1
# hist_philo international                      1
# sciences_po economie                          1
# droit RI                                      1
# finance                                       1
# economie maths                                1
# lettres                                       1
# sciences_po economie finance                  1
# economie lettres hist_philo                   1
# strategie environnement                       1
# Name: fieldofstudy3, dtype: int64

# %%
categories=['sciences_po', 'AP', "economie", 'droit', 'RI', 'lettres', 'business', 'management', 
            'informatique', 'urba_amgt', "ingenierie", "communication", 'hist_philo', 'media', 'finance',
            'journalisme', "strategie", "numerique", "international", 'design', 'environnement', "entrepreneuriat", 'maths']

for i in categories:
    data[i]=0

# data.loc[(data.recoded_degree_1 =='master')|(data.recoded_degree_2 =='master')|(data.recoded_degree_3 =='master'), 'master']=1
# data.loc[(data.recoded_degree_1 =='master')|(data.recoded_degree_2 =='master')|(data.recoded_degree_3 =='master'), 'licence']=1
# data['master'].sum()

# %%
def field_study_coding(x, col_list):
    y=0
    for c in col_list:
        if x in data[c]:
            y=1
        if y==1:
            return y
            break

# %%
categories=['sciences_po', 'AP', "economie", 'droit', 'RI', 'lettres', 'business', 'management', 
            'informatique', 'urba_amgt', "ingenierie", "communication", 'hist_philo', 'media', 'finance',
            'journalisme', "strategie", "numerique", "international", 'design', 'environnement', "entrepreneuriat", 'maths']
cols= ["ed_1fieldOfStudy", 'ed_2fieldOfStudy', "ed_3fieldOfStudy"]
for a in categories:
    data[a]=field_study_coding(a,cols)

# %%
type(data['sciences_po'])
# Out:
# pandas.core.series.Series

# %%
for i in categories:
    for a in cols:
        if i in data[a]:
            data[i]=1
        else:
            continue

# %%
data[["finance", "journalisme", "sciences_po"]].sum()
# Out:
# finance        0
# journalisme    0
# sciences_po    0
# dtype: object

# %%
print(len(categories))
# Out:
# 23

# %%
## from previous files

# %%
# recoding location columns 
# note : this type of formatting flattens elements with different locations 
# giving priority to the french one

def recoding_location(x):
    x=str(x)
    if ("Paris" in x) or ("PAris" in x) or ("Montreuil" in x) or ("Puteaux" in x):
        return 'Paris Metropolitan Region'
    elif ("Brussels" in x) or ("Bruxelles" in x): 
         return 'Brussels Metropolitan Region'
    elif "Berlin" in x: 
         return 'Berlin Metropolitan Region'
    elif "Nantes" in x: 
         return 'Nantes Metropolitan Region'
    elif "Bordeaux" in x: 
         return 'Bordeaux Metropolitan Region'
    elif "Lyon" in x: 
         return 'Lyon Metropolitan Region'
    elif "Marseille" in x: 
         return 'Marseille Metropolitan Region'
    elif "Lille" in x: 
         return 'Lille Metropolitan Region'
    else:
        return x

# possible improvement with geopy library 

# replace " France" (if it is only the word, not Ile de France) by nothing?

# %%
for i in profiles_experience.columns:
    if ('locationName' in i) or ('LocationName' in i):
        profiles_experience[i]= profiles_experience[i].apply(recoding_location)

profiles_experience.head()

# %%
list_companies=list(profiles_experience.exp1_companyName.str.lower())+list(profiles_experience.exp2_companyName.str.lower())+list(profiles_experience.exp3_companyName.str.lower())+list(profiles_experience.exp4_companyName.str.lower())+ list(profiles_experience.exp5_companyName.str.lower())
print(len(list_companies)), print(len(set(list_companies)))
df=pd.DataFrame(set(list_companies))
df.columns=['company']
dict_companies=df.company.value_counts().sort_index().to_dict()

# %%
def recoding_company(x):
    x=str(x).lower()
    if (x=="gov") or ("la météo de l" in x):
        return 'GOV la meteo de lopinion'
    elif ("make.org" in x): 
         return 'make.org'
    elif "orange" in x: 
         return 'Orange'
    elif ("freelance" in x) or ("self-employed" in x): 
         return 'freelance'
    elif "stig" in x: 
         return 'STIG'
    elif "voxe" in x: 
         return 'VOXE'
    else:
        return x

# %%
#test with 
# profiles_experience.exp1_companyName.apply(recoding_company)
#apply: 
for i in profiles_experience.columns:
    if ('companyName' in i):
        profiles_experience[i]= profiles_experience[i].apply(recoding_company)

print(len(list_companies)), print(len(set(list_companies)))

#list(profiles_experience.exp5_companyName)

# %%
list_titles=list(profiles_experience.exp1_title.str.lower())+list(profiles_experience.exp2_title.str.lower())+list(profiles_experience.exp3_title.str.lower())+list(profiles_experience.exp4_title.str.lower())+ list(profiles_experience.exp5_title.str.lower())
print(len(list_titles)), print(len(set(list_titles)))
df=pd.DataFrame(set(list_titles))
df.columns=['title']
dict_titles=df.title.value_counts().sort_index().to_dict()

# %%
# if includes "ceo" or "coo" or "cfo" or "président" or "directeur" or "directrice" or "director" or "cto" or "cpo" or "general manager" or "president" or "head of"
# if includes "consultant" or "conseiller" or "conseillère"
# if includes "founder" or "fondateur" or "fondatrice"

# %%
def recoding_title_dir(x):
     x=str(x).lower()
     dir=["ceo", "coo", "cfo", "président", "directeur", "directrice", "director", 
          "cto", "cpo", "general manager", "president", "head of"] 
     if any([y in x for y in dir]):
          return 1
     else: 
          return 0

def recoding_title_cs(x):
     x=str(x).lower()
     cs= ["consultant", "conseiller", "conseillère"]
     if any([y in x for y in cs]):
          return 1
     else: 
          return 0

def recoding_title_fond(x): 
     x=str(x).lower()
     fond=["founder", "fondateur", "fondatrice"]
     if any([y in x for y in fond]):
         return 1
     else: 
          return 0

# %%
list_title_columns= [i for i in profiles_experience.columns if 'title' in i]
print(list_title_columns)

for i in list_title_columns:
    profiles_experience[str(i)+'_direction']=profiles_experience[i].apply(recoding_title_dir)
for i in list_title_columns:
    profiles_experience[str(i)+'consulting']=profiles_experience[i].apply(recoding_title_cs)
for i in list_title_columns:
    profiles_experience[str(i)+'founder']=profiles_experience[i].apply(recoding_title_fond)

profiles_experience.columns

# %%
profiles_experience['consulting_roles']= profiles_experience['exp1_titleconsulting']+profiles_experience['exp2_titleconsulting']+profiles_experience['exp3_titleconsulting']+profiles_experience['exp4_titleconsulting']+profiles_experience['exp5_titleconsulting']
profiles_experience['direction_roles']= profiles_experience['exp1_title_direction']+profiles_experience['exp2_title_direction']+profiles_experience['exp3_title_direction']+profiles_experience['exp4_title_direction']+profiles_experience['exp5_title_direction']
profiles_experience['founding_roles']= profiles_experience['exp1_titlefounder']+profiles_experience['exp2_titlefounder']+profiles_experience['exp3_titlefounder']+profiles_experience['exp4_titlefounder']+profiles_experience['exp5_titlefounder']
print(profiles_experience['consulting_roles'].value_counts()), print(profiles_experience['direction_roles'].value_counts()), print(profiles_experience.founding_roles.value_counts())

# %%
people_experience_db['startDate_month']=np.array(people_experience_db['startDate_month'], np.int16) 
people_experience_db['startDate_year']=np.array(people_experience_db['startDate_year'], np.int16) 
people_experience_db['endDate_month']=np.array(people_experience_db['endDate_month'], np.int16) 
people_experience_db['endDate_year']=np.array(people_experience_db['endDate_year'], np.int16) 
people_experience_db['company_empl_low']=np.array(people_experience_db['company_empl_low'], np.int16) 
people_experience_db['company_empl_high']= np.array(people_experience_db['company_empl_high'], np.int16)
