# %% [markdown]
# # Setup

# %%
import pandas as pd
import pymysql.cursors
from sqlalchemy import create_engine, MetaData
from sqlalchemy.schema import CreateTable
from sqlalchemy import text
import getpass
import os

sql_pass = getpass.getpass()
#sql_pass = os.environ['MySQLPass']
connection_string = 'mysql+pymysql://root:' + sql_pass + '@localhost:3306/'
engine = create_engine(connection_string)

# %% [markdown]
# # People

# %% [markdown]
# ### Names

# %%
names= pd.read_csv('../data/names.csv', sep=';')

# %%
names.to_sql('people_names', engine, 'civictech', if_exists='replace', index=False)
# Out:
# 47

# %% [markdown]
# ### Profiles

# %%
people=pd.read_csv('../profiles/people_main_db.csv', sep=';')
print(list(people.columns))
print(len(list(people.columns)))
# Out:
# ['ind_id', 'geoCountryName', 'geoLocationName', 'summary', 'industryName', 'headline', 'experience', 'education', 'languages', 'publications', 'certifications', 'volunteer', 'honors', 'projects', 'experience1', 'experience2', 'experience3', 'experience4', 'experience5', 'education1', 'education2', 'education3', 'languages_over2', 'honors_stated', 'publications_stated', 'volunteer_stated', 'projects_stated', 'certifications_stated', 'languages_stated', 'consulting_roles', 'direction_roles', 'founding_roles']
# 32

# %%
# We may want to drop the columns with too many missing values.
pd.DataFrame(people.isna().sum().sort_values(ascending=False)).head(15)
# Out:
#                         0
# summary                15
# education3             12
# education2              6
# geoLocationName         4
# experience5             3
# experience4             2
# geoCountryName          2
# education1              1
# honors_stated           0
# languages_over2         0
# ind_id                  0
# publications_stated     0
# projects_stated         0
# certifications_stated   0
# languages_stated        0

# %%
# and/or drop text columns 
people.dtypes.sort_values()
# Out:
# ind_id                    int64
# consulting_roles          int64
# languages_stated          int64
# certifications_stated     int64
# projects_stated           int64
# volunteer_stated          int64
# publications_stated       int64
# honors_stated             int64
# languages_over2           int64
# direction_roles           int64
# founding_roles            int64
# volunteer                object
# geoCountryName           object
# geoLocationName          object
# summary                  object
# industryName             object
# headline                 object
# experience               object
# education                object
# languages                object
# certifications           object
# education3               object
# education1               object
# experience5              object
# experience4              object
# experience3              object
# publications             object
# experience1              object
# projects                 object
# honors                   object
# education2               object
# experience2              object
# dtype: object

# %%
people.head(3).T
# Out:
#                                                                        0  \
# ind_id                                                                 0
# geoCountryName                                                    France
# geoLocationName                                Paris Metropolitan Region
# summary                Antoine croit à l’intelligence de tous et à la...
# industryName                               IT Services and IT Consulting
# headline               Directeur associé de bluenove, initiateur du m...
# experience             [{'locationName': 'Paris Area, France', 'entit...
# education              [{'entityUrn': 'urn:li:fs_education:(ACoAAAA61...
# languages              [{'name': 'English', 'proficiency': 'FULL_PROF...
# publications           [{'date': {'month': 9, 'year': 2017, 'day': 1}...
# certifications                                                        []
# volunteer                                                             []
# honors                                                                []
# projects                                                              []
# experience1            {'locationName': 'Paris Area, France', 'entity...
# experience2            {'entityUrn': 'urn:li:fs_position:(ACoAAAA615E...
# experience3            {'locationName': 'Paris', 'entityUrn': 'urn:li...
# experience4            {'locationName': 'Paris Area, France', 'entity...
# experience5            {'locationName': 'Paris', 'entityUrn': 'urn:li...
# education1             {'entityUrn': 'urn:li:fs_education:(ACoAAAA615...
# education2             {'entityUrn': 'urn:li:fs_education:(ACoAAAA615...
# education3             {'entityUrn': 'urn:li:fs_education:(ACoAAAA615...
# languages_over2                                                        1
# honors_stated                                                          0
# publications_stated                                                    1
# volunteer_stated                                                       0
# projects_stated                                                        0
# certifications_stated                                                  0
# languages_stated                                                       1
# consulting_roles                                                       0
# direction_roles                                                        3
# founding_roles                                                         0
#
#                                                                        1  \
# ind_id                                                                 1
# geoCountryName                                                    France
# geoLocationName                                Paris Metropolitan Region
# summary                French Entrepreneur - Founder and Managing Par...
# industryName               Venture Capital and Private Equity Principals
# headline                     Founder & Managing Partner at ROCH Ventures
# experience             [{'entityUrn': 'urn:li:fs_position:(ACoAAAfK9Y...
# education              [{'entityUrn': 'urn:li:fs_education:(ACoAAAfK9...
# languages                                                             []
# publications                                                          []
# certifications                                                        []
# volunteer                                                             []
# honors                 [{'description': 'THE WEBBY AWARDS IS THE LEAD...
# projects                                                              []
# experience1            {'entityUrn': 'urn:li:fs_position:(ACoAAAfK9Yw...
# experience2            {'locationName': 'Région de Paris, France', 'e...
# experience3            {'locationName': 'Région de Paris, France', 'e...
# experience4            {'locationName': 'Région de Paris, France', 'e...
# experience5            {'locationName': 'Région de Paris, France', 'g...
# education1             {'entityUrn': 'urn:li:fs_education:(ACoAAAfK9Y...
# education2             {'entityUrn': 'urn:li:fs_education:(ACoAAAfK9Y...
# education3             {'entityUrn': 'urn:li:fs_education:(ACoAAAfK9Y...
# languages_over2                                                        0
# honors_stated                                                          1
# publications_stated                                                    0
# volunteer_stated                                                       0
# projects_stated                                                        0
# certifications_stated                                                  0
# languages_stated                                                       0
# consulting_roles                                                       0
# direction_roles                                                        2
# founding_roles                                                         2
#
#                                                                        2
# ind_id                                                                 2
# geoCountryName                                                    France
# geoLocationName                                Paris Metropolitan Region
# summary                Inspired by the power we can build to change t...
# industryName                              Civic and Social Organizations
# headline               Co-director Multitudes Foundation - Activist a...
# experience             [{'entityUrn': 'urn:li:fs_position:(ACoAAAUn_5...
# education              [{'entityUrn': 'urn:li:fs_education:(ACoAAAUn_...
# languages              [{'name': 'Anglais', 'proficiency': 'NATIVE_OR...
# publications           [{'date': {'month': 1, 'year': 2021, 'day': 21...
# certifications                                                        []
# volunteer              [{'role': 'Co-Founder', 'companyName': 'Collec...
# honors                                                                []
# projects                                                              []
# experience1            {'entityUrn': 'urn:li:fs_position:(ACoAAAUn_5A...
# experience2            {'entityUrn': 'urn:li:fs_position:(ACoAAAUn_5A...
# experience3            {'locationName': 'Paris', 'entityUrn': 'urn:li...
# experience4            {'locationName': 'Paris', 'entityUrn': 'urn:li...
# experience5            {'locationName': 'Paris Area, France', 'entity...
# education1             {'entityUrn': 'urn:li:fs_education:(ACoAAAUn_5...
# education2             {'entityUrn': 'urn:li:fs_education:(ACoAAAUn_5...
# education3             {'entityUrn': 'urn:li:fs_education:(ACoAAAUn_5...
# languages_over2                                                        1
# honors_stated                                                          0
# publications_stated                                                    1
# volunteer_stated                                                       1
# projects_stated                                                        0
# certifications_stated                                                  0
# languages_stated                                                       1
# consulting_roles                                                       1
# direction_roles                                                        2
# founding_roles                                                         0

# %%
people.to_csv("people.csv", sep=";", index=False)

# %%
# for now we are keeping it as is
people.to_sql('people', engine, 'civictech', if_exists='replace', index=False)
# Out:
# 47

# %% [markdown]
# ### Experience

# %%
experience=pd.read_csv('../profiles/people_experience_db.csv', sep=';')

# %%
print(list(experience.columns))
print(len(list(experience.columns)))
print(len(experience))
# Out:
# ['index', 'ind_id', 'locationName', 'companyName', 'description', 'title', 'startDate_month', 'startDate_year', 'endDate_month', 'endDate_year', 'industry', 'company_empl_low', 'company_empl_high', 'title_direction', 'titleconsulting', 'titlefounder']
# 16
# 235

# %%
experience.isna().sum().sort_values(ascending=False)
# Out:
# locationName         62
# description          57
# industry             20
# companyName           5
# title                 5
# index                 0
# ind_id                0
# startDate_month       0
# startDate_year        0
# endDate_month         0
# endDate_year          0
# company_empl_low      0
# company_empl_high     0
# title_direction       0
# titleconsulting       0
# titlefounder          0
# dtype: int64

# %%
experience.isna().sum().sort_values(ascending=False)
# Out:
# locationName         62
# description          57
# industry             20
# companyName           5
# title                 5
# index                 0
# ind_id                0
# startDate_month       0
# startDate_year        0
# endDate_month         0
# endDate_year          0
# company_empl_low      0
# company_empl_high     0
# title_direction       0
# titleconsulting       0
# titlefounder          0
# dtype: int64

# %%
experience['startDate_year'] = experience['startDate_year'].fillna(0)
experience['startDate_month'] = experience['startDate_month'].fillna(0)
experience['endDate_year'] = experience['endDate_year'].fillna(0)
experience['endDate_month'] = experience['endDate_month'].fillna(0)
experience['company_empl_low'] = experience['company_empl_low'].fillna(999)
experience['company_empl_high'] = experience['company_empl_high'].fillna(999)

# %%
experience['startDate_year'] = experience['startDate_year'].astype(int)
experience['startDate_month'] = experience['startDate_month'].astype(int)
experience['endDate_year'] = experience['endDate_year'].astype(int)
experience['endDate_month'] = experience['endDate_month'].astype(int)
experience['company_empl_low'] = experience['company_empl_low'].astype(int)
experience['company_empl_high'] = experience['company_empl_high'].astype(int)

# %%
experience.industry[1]
# Out:
# "['Management Consulting']"

# %%
import re
def clean_industry(x):
    x=str(x)
    pattern = "[a-zA-Z]+ [a-zA-Z]+|[a-zA-Z]+"
    a= re.findall(pattern, x)
    a= ' '.join(a)
    #a= a[1:-1]
    return a

# %%
print(list(experience['industry'].apply(clean_industry)))
# Out:
# ['Management Consulting', 'Management Consulting', 'Management Consulting', 'Management Consulting', 'Management Consulting', 'Venture Capital Private Equity', 'Venture Capital Private Equity', 'Venture Capital Private Equity', 'Venture Capital Private Equity', 'Venture Capital Private Equity', 'Nonprofit Organization Management', 'Nonprofit Organization Management', 'Nonprofit Organization Management', 'Nonprofit Organization Management', 'Nonprofit Organization Management', 'nan', 'nan', 'nan', 'nan', 'nan', 'Computer Software', 'Computer Software', 'Computer Software', 'Computer Software', 'Computer Software', 'Internet', 'Internet', 'Internet', 'Internet', 'Internet', 'Information Technology and Services', 'Information Technology and Services', 'Information Technology and Services', 'Information Technology and Services', 'Information Technology and Services', 'Civic Social Organization', 'Civic Social Organization', 'Civic Social Organization', 'Civic Social Organization', 'Civic Social Organization', 'Management Consulting', 'Management Consulting', 'Management Consulting', 'Management Consulting', 'Management Consulting', 'Civic Social Organization', 'Civic Social Organization', 'Civic Social Organization', 'Civic Social Organization', 'Civic Social Organization', 'Graphic Design', 'Graphic Design', 'Graphic Design', 'Graphic Design', 'Graphic Design', 'Higher Education', 'Higher Education', 'Higher Education', 'Higher Education', 'Higher Education', 'Computer Software', 'Computer Software', 'Computer Software', 'Computer Software', 'Computer Software', 'Computer Software', 'Computer Software', 'Computer Software', 'Computer Software', 'Computer Software', 'Computer Software', 'Computer Software', 'Computer Software', 'Computer Software', 'Computer Software', 'Information Technology and Services', 'Information Technology and Services', 'Information Technology and Services', 'Information Technology and Services', 'Information Technology and Services', 'Computer Software', 'Computer Software', 'Computer Software', 'Computer Software', 'Computer Software', 'Computer Software', 'Computer Software', 'Computer Software', 'Computer Software', 'Computer Software', 'Computer Software', 'Computer Software', 'Computer Software', 'Computer Software', 'Computer Software', 'Management Consulting', 'Management Consulting', 'Management Consulting', 'Management Consulting', 'Management Consulting', 'Information Technology and Services', 'Information Technology and Services', 'Information Technology and Services', 'Information Technology and Services', 'Information Technology and Services', 'Information Technology and Services', 'Information Technology and Services', 'Information Technology and Services', 'Information Technology and Services', 'Information Technology and Services', 'Management Consulting', 'Management Consulting', 'Management Consulting', 'Management Consulting', 'Management Consulting', 'Computer Software', 'Computer Software', 'Computer Software', 'Computer Software', 'Computer Software', 'Civic Social Organization', 'Civic Social Organization', 'Civic Social Organization', 'Civic Social Organization', 'Civic Social Organization', 'Higher Education', 'Higher Education', 'Higher Education', 'Higher Education', 'Higher Education', 'Civic Social Organization', 'Civic Social Organization', 'Civic Social Organization', 'Civic Social Organization', 'Civic Social Organization', 'nan', 'nan', 'nan', 'nan', 'nan', 'Higher Education', 'Higher Education', 'Higher Education', 'Higher Education', 'Higher Education', 'Information Technology and Services', 'Information Technology and Services', 'Information Technology and Services', 'Information Technology and Services', 'Information Technology and Services', 'Information Technology and Services', 'Information Technology and Services', 'Information Technology and Services', 'Information Technology and Services', 'Information Technology and Services', 'nan', 'nan', 'nan', 'nan', 'nan', ...

# %%
experience['industry']= experience['industry'].apply(clean_industry)

# %%
experience['industry'].value_counts()
# Out:
# Computer Software                      55
# Information Technology and Services    45
# Civic Social Organization              35
# Management Consulting                  20
# nan                                    20
# Higher Education                       20
# Internet                               10
# Venture Capital Private Equity          5
# Nonprofit Organization Management       5
# Graphic Design                          5
# Performing Arts                         5
# Marketing and Advertising               5
# Research                                5
# Name: industry, dtype: int64

# %%
experience.drop(columns='index', inplace=True)
experience.head()
# Out:
#    ind_id               locationName                              companyName  \
# 0       0  Paris Metropolitan Region                                 bluenove
# 1       0  Paris Metropolitan Region                       démocratie ouverte
# 2       0  Paris Metropolitan Region  apm - association progrès du management
# 3       0                        NaN                       démocratie ouverte
# 4       0  Paris Metropolitan Region                        dassault systèmes
#
#                                          description  \
# 0  Bluenove accompagne la transformation positive...
# 1  Démocratie Ouverte est un collectif citoyen in...
# 2                                                NaN
# 3                                                NaN
# 4  Netvibes provides Dashboard Intelligence ~ tra...
#
#                                               title  startDate_month  \
# 0                                 Directeur associé               11
# 1                                      Co-Président                1
# 2                                            Expert                1
# 3        Membre du Comité d'Orientation Stratégique                7
# 4  Senior Director, Strategic Business Development                 2
#
#    startDate_year  endDate_month  endDate_year               industry  \
# 0            2017              0             0  Management Consulting
# 1            2018              5          2020  Management Consulting
# 2            2017              0             0  Management Consulting
# 3            2021              0             0  Management Consulting
# 4            2013             10          2017  Management Consulting
#
#    company_empl_low  company_empl_high  title_direction  titleconsulting  \
# 0                11                 50                1                0
# 1                11                 50                1                0
# 2                11                 50                0                0
# 3                11                 50                0                0
# 4                11                 50                1                0
#
#    titlefounder
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0

# %%
experience.reset_index(inplace=True)

# %%
experience.rename(columns={"index":"exp_id"}, inplace=True)

# %%
experience.dtypes
# Out:
# exp_id                int64
# ind_id                int64
# locationName         object
# companyName          object
# description          object
# title                object
# startDate_month       int64
# startDate_year        int64
# endDate_month         int64
# endDate_year          int64
# industry             object
# company_empl_low      int64
# company_empl_high     int64
# title_direction       int64
# titleconsulting       int64
# titlefounder          int64
# dtype: object

# %%
experience.columns
# Out:
# Index(['exp_id', 'ind_id', 'locationName', 'companyName', 'description',
#        'title', 'startDate_month', 'startDate_year', 'endDate_month',
#        'endDate_year', 'industry', 'company_empl_low', 'company_empl_high',
#        'title_direction', 'titleconsulting', 'titlefounder'],
#       dtype='object')

# %%
experience.head().T
# Out:
#                                                                    0  \
# exp_id                                                             0
# ind_id                                                             0
# locationName                               Paris Metropolitan Region
# companyName                                                 bluenove
# description        Bluenove accompagne la transformation positive...
# title                                              Directeur associé
# startDate_month                                                   11
# startDate_year                                                  2017
# endDate_month                                                      0
# endDate_year                                                       0
# industry                                       Management Consulting
# company_empl_low                                                  11
# company_empl_high                                                 50
# title_direction                                                    1
# titleconsulting                                                    0
# titlefounder                                                       0
#
#                                                                    1  \
# exp_id                                                             1
# ind_id                                                             0
# locationName                               Paris Metropolitan Region
# companyName                                       démocratie ouverte
# description        Démocratie Ouverte est un collectif citoyen in...
# title                                                   Co-Président
# startDate_month                                                    1
# startDate_year                                                  2018
# endDate_month                                                      5
# endDate_year                                                    2020
# industry                                       Management Consulting
# company_empl_low                                                  11
# company_empl_high                                                 50
# title_direction                                                    1
# titleconsulting                                                    0
# titlefounder                                                       0
#
#                                                          2  \
# exp_id                                                   2
# ind_id                                                   0
# locationName                     Paris Metropolitan Region
# companyName        apm - association progrès du management
# description                                            NaN
# title                                               Expert
# startDate_month                                          1
# startDate_year                                        2017
# endDate_month                                            0
# endDate_year                                             0
# industry                             Management Consulting
# company_empl_low                                        11
# company_empl_high                                       50
# title_direction                                          0
# titleconsulting                                          0
# titlefounder                                             0
#
#                                                             3  \
# exp_id                                                      3
# ind_id                                                      0
# locationName                                              NaN
# companyName                                démocratie ouverte
# description                                               NaN
# title              Membre du Comité d'Orientation Stratégique
# startDate_month                                             7
# startDate_year                                           2021
# endDate_month                                               0
# endDate_year                                                0
# industry                                Management Consulting
# company_empl_low                                           11
# company_empl_high                                          50
# title_direction                                             0
# titleconsulting                                             0
# titlefounder                                                0
#
#                                                                    4
# exp_id                                                             4
# ind_id                                                             0
# locationName                               Paris Metropolitan Region
# companyName                                        dassault systèmes
# description        Netvibes provides Dashboard Intelligence ~ tra...
# title               Senior Director, Strategic Business Development
# startDate_month                                                    2
# startDate_year                                                  2013
# endDate_month                                                     10
# endDate_year                                                    2017
# industry                                       Management Consulting
# company_empl_low                                                  11
# company_empl_high                                                 50
# title_direction                                                    1
# titleconsulting                                                    0
# titlefounder                                                       0

# %%
experience.to_csv("experience.csv", sep=";", index=False)

# %%
experience.to_sql('people_experience',engine, 'civictech', if_exists='replace', index=False)# dtype={'locationName': string, 'companyName':'VARCHAR(500)', 'description':'VARCHAR(600)', 'title': 'VARCHAR(700)', 'industry':'VARCHAR(500)'})
# Out:
# 235

# %% [markdown]
# ### Education

# %%
education=pd.read_csv('../profiles/people_education_db.csv', sep=';')

# %%
print(list(education.columns))
print(len(list(education.columns)))
print(len(education))
# Out:
# ['ind_id', 'school', 'degreeName', 'schoolName', 'fieldOfStudy', 'startDate_year']
# 6
# 141

# %%
education.isna().sum().sort_values(ascending=False)
# Out:
# fieldOfStudy      51
# school            46
# degreeName        44
# startDate_year    30
# schoolName        19
# ind_id             0
# dtype: int64

# %%
education.dtypes.sort_values(ascending=False)
# Out:
# school             object
# degreeName         object
# schoolName         object
# fieldOfStudy       object
# startDate_year    float64
# ind_id              int64
# dtype: object

# %%
education.startDate_year.value_counts(dropna=False)
education['startDate_year'] = education['startDate_year'].fillna(0)

# %%
education.head()
# Out:
#    ind_id                                             school    degreeName  \
# 0       0  {'objectUrn': 'urn:li:school:19908', 'entityUr...        Master
# 1       0                                                NaN           NaN
# 2       0                                                NaN  Baccalauréat
# 3       1  {'objectUrn': 'urn:li:school:12330', 'entityUr...           NaN
# 4       1  {'objectUrn': 'urn:li:school:13392', 'entityUr...           NaN
#
#                            schoolName  \
# 0                         ESCP Europe
# 1           Prépa Saint Jean de Douai
# 2                      Lycée Kernanec
# 3  Ecole des Hautes Etudes Politiques
# 4               The Hebrew University
#
#                                        fieldOfStudy  startDate_year
# 0                     Business/Managerial Economics          1998.0
# 1                                               NaN          1996.0
# 2                                         Economics          1993.0
# 3  Relations Internationales et Sciences Politiques          2006.0
# 4             Relations et affaires internationales          2005.0

# %%
education['startDate_year']= education['startDate_year'].astype(int)

# %%
education.reset_index(inplace=True)

# %%
education.head()
# Out:
#    index  ind_id                                             school  \
# 0      0       0  {'objectUrn': 'urn:li:school:19908', 'entityUr...
# 1      1       0                                                NaN
# 2      2       0                                                NaN
# 3      3       1  {'objectUrn': 'urn:li:school:12330', 'entityUr...
# 4      4       1  {'objectUrn': 'urn:li:school:13392', 'entityUr...
#
#      degreeName                          schoolName  \
# 0        Master                         ESCP Europe
# 1           NaN           Prépa Saint Jean de Douai
# 2  Baccalauréat                      Lycée Kernanec
# 3           NaN  Ecole des Hautes Etudes Politiques
# 4           NaN               The Hebrew University
#
#                                        fieldOfStudy  startDate_year
# 0                     Business/Managerial Economics            1998
# 1                                               NaN            1996
# 2                                         Economics            1993
# 3  Relations Internationales et Sciences Politiques            2006
# 4             Relations et affaires internationales            2005

# %%
education.rename(columns= {'index': "ed_id"}, inplace=True)

# %%
education.head().T
# Out:
#                                                                 0  \
# ed_id                                                           0
# ind_id                                                          0
# school          {'objectUrn': 'urn:li:school:19908', 'entityUr...
# degreeName                                                 Master
# schoolName                                            ESCP Europe
# fieldOfStudy                        Business/Managerial Economics
# startDate_year                                               1998
#
#                                         1               2  \
# ed_id                                   1               2
# ind_id                                  0               0
# school                                NaN             NaN
# degreeName                            NaN    Baccalauréat
# schoolName      Prépa Saint Jean de Douai  Lycée Kernanec
# fieldOfStudy                          NaN       Economics
# startDate_year                       1996            1993
#
#                                                                 3  \
# ed_id                                                           3
# ind_id                                                          1
# school          {'objectUrn': 'urn:li:school:12330', 'entityUr...
# degreeName                                                    NaN
# schoolName                     Ecole des Hautes Etudes Politiques
# fieldOfStudy     Relations Internationales et Sciences Politiques
# startDate_year                                               2006
#
#                                                                 4
# ed_id                                                           4
# ind_id                                                          1
# school          {'objectUrn': 'urn:li:school:13392', 'entityUr...
# degreeName                                                    NaN
# schoolName                                  The Hebrew University
# fieldOfStudy                Relations et affaires internationales
# startDate_year                                               2005

# %%
education.to_csv("education.csv", sep=";", index=False)

# %%
education.to_sql('people_education', engine, 'civictech', if_exists='replace', index=False)
# Out:
# 141

# %% [markdown]
# # Organizations

# %% [markdown]
# ## Companies finance data

# %%
companies_finance=pd.read_csv('../organizations/companies_finance_data.csv', sep=';')

# %%
companies_finance.head(20)
# Out:
#     company_year_ide     company   annee  chiffre_daffaires_e  marge_brute_e  \
# 0                  0    citility  2017.0                  0.0              0
# 1                  1    citility  2016.0              30700.0         527000
# 2                  2    voxcracy  2019.0              46300.0          46300
# 3                  3    voxcracy  2018.0              16700.0         157000
# 4                  4    voxcracy  2017.0               1740.0          75900
# 5                  5    voxcracy  2016.0                  0.0              0
# 6                  6         LLL  2020.0             473000.0         473000
# 7                  7         LLL  2019.0             462000.0         462000
# 8                  8         LLL  2018.0             300000.0         300000
# 9                  9         LLL  2017.0                  0.0              0
# 10                10    bluenove  2020.0                  0.0              0
# 11                11    bluenove  2019.0                  0.0              0
# 12                12    bluenove  2018.0                  0.0              0
# 13                13    bluenove  2016.0            3300000.0        3300000
# 14                14      vooter  2018.0             110000.0         112000
# 15                15  organigram  2020.0                  0.0              0
# 16                16  organigram  2019.0                860.0            861
# 17                17  organigram  2018.0             127000.0         128000
# 18                18  organigram  2017.0             104000.0         104000
# 19                19     forcity  2018.0            1730000.0        4110000
#
#     resultat_dexploitation_e  resultat_net_e  taux_croissance_ca_pc  \
# 0                          0         -562000                      0
# 1                    -296000         -238000                      4
# 2                     -38500          -39000                    177
# 3                    -130000         -112000                    861
# 4                     -30300          -23400                      0
# 5                      -4910           -4910                      0
# 6                     -42700          -44900                     25
# 7                      95200           62400                    539
# 8                      25900           19800                      0
# 9                          0               0                      0
# 10                         0          763000                      0
# 11                         0          534000                      0
# 12                         0           65000                      0
# 13                    125000          271000                    359
# 14                   -175000         -175000                      0
# 15                      -549            -549                      0
# 16                     -1370           -1370                   -993
# 17                    -23400          -23900                    224
# 18                     18900           16200                      0
# 19                  -5820000       -11100000                   -406
#
#     taux_marge_brute_pc  taux_marge_operationnelle_pc  ...  fonds_propres_e  \
# 0                     0                             0  ...          1380000
# 1                  1720                          -965  ...           382000
# 2                   100                          -833  ...           513000
# 3                   940                          -776  ...           552000
# 4                  4360                         -1740  ...           569000
# 5                     0                             0  ...              111
# 6                   100                            -9  ...           103000
# 7                   100                           206  ...           148000
# 8                   100                            86  ...            85300
# 9                     0                             0  ...                0
# 10                    0                             0  ...          2520000
# 11                    0                             0  ...          1760000
# 12                    0                             0  ...          1230000
# 13                  100                            38  ...           832000
# 14                  102                          -159  ...           128000
# 15                    0                             0  ...            -9490
# 16                  100                          -159  ...            -8940
# 17                  101                          -184  ...            -7570
# 18                  100                           182  ...            16400
# 19                  238                          -337  ...         -3270000
#
#     marge_nette_pc  rentabilite_sur_fonds_propres_pc  \
# 0                0                                 0
# 1             -775                              -623
# 2             -842                               -76
# 3             -668                              -202
# 4            -1350                               -41
# 5                0                             -4420
# 6              -95                              -437
# 7              135                               423
# 8               66                               232
# 9                0                                 0
# 10               0                                 0
# 11               0                                 0
# 12               0                                 0
# 13              82                               325
# 14            -159                              -137
# 15               0                                58
# 16            -159                               153
# 17            -188                               316
# 18             155                               988
# 19            -641                               339
#
#     rentabilite_economique_pc  valeur_ajoutee_e  valeur_ajoutee_sur_ca_pc  \
# 0                           0                 0                         0
# 1                        -173            351000                      1140
# 2                         -63              2170                        47
# 3                        -169            -21000                      -126
# 4                         -39             -5040                      -290
# 5                        -177              -942                         0
# 6                         -37            136000                       287
# 7                          86            292000                       632
# 8                          38            175000                       584
# 9                           0                 0                         0
# 10                          0                 0                         0
# 11                          0                 0                         0
# 12                          0                 0                         0
# 13                         94           2300000                       697
# 14                        -68            -26600                      -243
# 15                       -113              -549                         0
# 16                       -109             -1290                      -150
# 17                       -138             37000                       291
# 18                        431             69000                       663
# 19                       -206           -710000                      -411
#
#     salaires_et_charges_sociales_e  salaires_sur_ca_pc  impots_et_taxes_e  \
# 0                                0                   0                  0
# 1                           636000                2070               9160
# 2                            33600                 725                137
# 3                           101000                 602               1120
# 4                            19100                1100                329
# 5                                0                   0                140
# 6                            97100                 205              14200
# 7                           126000                 274               7350
# 8                            80200                 267               5220
# 9                                0                   0                  0
# 10                               0                   0                  0
# 11                               0                   0                  0
# 12                               0                   0                  0
# 13                         2070000                 629              65300
# 14                          146000                 133               1460
# 15                               0                   0                  0
# 16                               0                   0                 77
# 17                           60100                 472                620
# 18                           45500                 438                588
# 19                         4110000                 238              52500
#
#     chiffre_daffaires_a_lexport_e
# 0                               0
# 1                               0
# 2                               0
# 3                            5000
# 4                               0
# 5                               0
# 6                               0
# 7                               0
# 8                               0
# 9                               0
# 10                              0
# 11                              0
# 12                              0
# 13                          17500
# 14                              0
# 15                              0
# 16                              0
# 17                              0
# 18                              0
# 19                              0
#
# [20 rows x 42 columns]

# %%
companies_finance.dtypes
# Out:
# company_year_ide                         int64
# company                                 object
# annee                                  float64
# chiffre_daffaires_e                    float64
# marge_brute_e                            int64
# resultat_dexploitation_e                 int64
# resultat_net_e                           int64
# taux_croissance_ca_pc                    int64
# taux_marge_brute_pc                      int64
# taux_marge_operationnelle_pc             int64
# bfr_e                                    int64
# bfr_exploitation_e                       int64
# bfr_hors_exploitation_e                  int64
# bfr_j_ca                                 int64
# bfr_exploitation_j_ca                    int64
# bfr_hors_exploitation_j_ca               int64
# delai_paiement_clients_j                 int64
# delai_paiement_fournisseurs_j            int64
# ratio_s_stocks_sur_ca_j                  int64
# capacite_dautofinancement_e              int64
# capacite_dautofinancement_sur_ca_pc      int64
# fonds_roulement_net_global_e             int64
# couverture_bfr                           int64
# tresorerie_e                             int64
# dettes_financieres_e                     int64
# capacite_remboursement                   int64
# ratio_dendettement_gearing               int64
# autonomie_financiere_pc                  int64
# taux_levier_dfnsurebitda                 int64
# etat_surdettes_a_1_an_au_plus_e          int64
# liquidite_generale                       int64
# couverture_surdettes                     int64
# fonds_propres_e                          int64
# marge_nette_pc                           int64
# rentabilite_sur_fonds_propres_pc         int64
# rentabilite_economique_pc                int64
# valeur_ajoutee_e                         int64
# valeur_ajoutee_sur_ca_pc                 int64
# salaires_et_charges_sociales_e           int64
# salaires_sur_ca_pc                       int64
# impots_et_taxes_e                        int64
# chiffre_daffaires_a_lexport_e            int64
# dtype: object

# %%
companies_finance.to_csv("companies_finance.csv", sep=";", index=False)

# %%
companies_finance.to_sql('companies_finance', engine, 'civictech', if_exists='replace', index=False)
# Out:
# 74

# %% [markdown]
# ## Organizations

# %%
companies_info=pd.read_csv('../organizations/companies_info_data.csv', sep=';')
companies_info.head(2)
# Out:
#    company_id companyname                                          adresse  \
# 0           0    citility               5 RUE DE LA CLAIRE 69009 LYON 9EME
# 1           1     poligma  RPT BENJAMIN FRANKLIN 34960 MONTPELLIER CEDEX 2
#
#                                          activite  \
# 0                Édition de logiciels applicatifs
# 1  Conseil en systèmes et logiciels informatiques
#
#                                effectif    creation  \
# 0              0 salarié  (donnée 2019)  05/05/2014
# 1  Entre 3 et 5 salariés  (donnée 2020)  01/09/2015
#
#                           dirigeants                      forme_juridique  \
# 0  André MAY, ODICEO, Sabine SCHNECK  SAS, société par actions simplifiée
# 1                                NaN  SAS, société par actions simplifiée
#
#                                   inscription_au_rcs capital_social  \
# 0         INSCRIT (au greffe de LYON, le 12/05/2014)    39 620,00 €
# 1  INSCRIT (au greffe de MONTPELLIER, le 11/09/2015)    20 944,00 €
#
#                         activite_principale_declaree  \
# 0                  Edition de logiciels applicatifs.
# 1  Développement de services informatiques et num...
#
#                                      code_naf_ou_ape  \
# 0          58.29C (Édition de logiciels applicatifs)
# 1  62.02A (Conseil en systèmes et logiciels infor...
#
#                                    domaine_dactivite        dirigeant  \
# 0                                            Édition              NaN
# 1  Programmation, conseil et autres activités inf...  Philippe GERARD
#
#   inscription_au_rna identifiant_association objet_de_lassociation  \
# 0                NaN                     NaN                   NaN
# 1                NaN                     NaN                   NaN
#
#   statut_insee
# 0          NaN
# 1          NaN

# %%
companies_info.dtypes
# Out:
# company_id                       int64
# companyname                     object
# adresse                         object
# activite                        object
# effectif                        object
# creation                        object
# dirigeants                      object
# forme_juridique                 object
# inscription_au_rcs              object
# capital_social                  object
# activite_principale_declaree    object
# code_naf_ou_ape                 object
# domaine_dactivite               object
# dirigeant                       object
# inscription_au_rna              object
# identifiant_association         object
# objet_de_lassociation           object
# statut_insee                    object
# dtype: object

# %%
#companies_info['creation'] = pd.to_datetime(companies_info['creation'], format="%Y/%m/%d")

# %% [markdown]
# ### creating associations table

# %%
# to split companies and NGOs, just 
associations= pd.DataFrame(companies_info.loc[companies_info['activite']=="Autres organisations fonctionnant par adhésion volontaire"])

# %%
a= pd.DataFrame(associations.isna().sum().sort_values(ascending=False))
a.columns=["column"]
coltodrop= list(a.loc[a['column']>=len(associations)-1].index)
associations.drop(columns=coltodrop, inplace=True)
associations.drop(columns=['activite','forme_juridique', 'inscription_au_rcs', 'code_naf_ou_ape', 'domaine_dactivite', 'identifiant_association'], inplace=True)

# %%
associations.rename(columns={"company_id":"asso_id", "companyname":"association_name"}, inplace=True)

# %%
def clean_inscriptions(x):
    x=str(x)
    if "INSCRIT" in x:
        return 1
    else:
        return 0

# %%
associations["inscription_rna"]=associations['inscription_au_rna'].apply(clean_inscriptions)

# %%
def get_date(x):
    x=str(x)
    pattern=r"\d{1,5}/\d{2,5}/\d{2,5}"
    a= re.findall(pattern, x)
    a= ''.join(a).strip()
    return a

# %%
associations["date_inscr"]=pd.to_datetime(associations['inscription_au_rna'].apply(get_date), dayfirst=True)

# %%
associations.drop(columns="inscription_au_rna", inplace=True)

# %%
def get_post_code(x):
    x=str(x)
    pattern=r"\d{5}"
    a= re.findall(pattern, x)
    a= ''.join(a).strip()
    return a

# %%
associations["post_code"]= associations["adresse"].apply(get_post_code)

# %%
associations["country"]= "France"

# %%
associations.head()
# Out:
#     asso_id association_name                             adresse  \
# 6         6            make4   14 RUE ST GUILLAUME 75007 PARIS 7
# 8         8       voteetvous  133 RUE ST DOMINIQUE 75007 PARIS 7
# 26       26    lesbricodeurs  8 PL LOUIS CHAZETTE 69001 LYON 1ER
# 38       38      democracyos         17 RUE MYRHA 75018 PARIS 18
# 39       39         polipart      70 BD DE CLICHY 75018 PARIS 18
#
#                                 effectif    creation  \
# 6   Entre 3 et 5 salariés  (donnée 2020)  11/01/2017
# 8      Au moins 1 salarié  (donnée 2023)  27/01/2014
# 26  Entre 1 et 2 salariés  (donnée 2020)  30/04/2016
# 38     Au moins 1 salarié  (donnée 2023)  21/04/2015
# 39              0 salarié  (donnée 2023)  09/03/2019
#
#                                 objet_de_lassociation  inscription_rna  \
# 6                                                 NaN                0
# 8   Renforcer l'exercice démocratique du vote, en ...                1
# 26  Diffuser la culture numérique et accompagner d...                1
# 38  Représenter la communauté qui développe et qui...                1
# 39  Améliorer la relation entre institutions, élus...                1
#
#    date_inscr post_code country
# 6         NaT     75007  France
# 8  2014-01-27     75007  France
# 26 2015-11-05     69001  France
# 38 2015-04-21     75018  France
# 39 2019-03-09     75018  France

# %% [markdown]
# ### Companies table

# %%
companies= pd.DataFrame(companies_info.loc[companies_info['activite']!="Autres organisations fonctionnant par adhésion volontaire"])

# %%
companies.drop(columns=['inscription_au_rna', 'identifiant_association', 'objet_de_lassociation', 'statut_insee'], inplace=True)

# %%
#companies.inscription_au_rcs.value_counts()

# %%
companies["inscription_rcs"]=companies['inscription_au_rcs'].apply(clean_inscriptions)

# %%
import re

def greffe(x):
     x=str(x)
     pattern = " [A-Z]+"
     a= re.findall(pattern, x)
     a= ''.join(a).strip()
     return a

# %%
companies["city"]= companies['inscription_au_rcs'].apply(greffe)

# %%
companies["date_inscr_rad"]=pd.to_datetime(companies['inscription_au_rcs'].apply(get_date), dayfirst=True)

# %%
def select_appr_col(x, y): 
    x=str(x)
    y=str(y)
    if x=="NaN":
        return y
    elif y=="Nan":
        return x

# %%
companies["directors"]=companies["dirigeants"].astype(str).replace("nan", '')+companies["dirigeant"].astype(str).replace("nan", '')

# %%
companies.drop(columns=["dirigeants", "dirigeant", "inscription_au_rcs"], inplace=True)

# %%
import re
def fix_K_social(x):
    x=str(x)
    x.replace('€', '')
    x.replace(' ', '')
    if "," in x: 
        y= re.split(',', x)[0]
        y= re.split(' ', y)
        return "".join(y)
    else:
        return 0

# %%
#test line 
# companies.capital_social.apply(fix_K_social).astype(int)

# %%
companies["capital_social"]= companies.capital_social.apply(fix_K_social).astype(int)

# %%
print(list(companies.companyname))
# Out:
# ['citility', 'poligma', 'voxcracy', 'LLL_2', 'bluenove', 'ecivis', 'civimetric', 'vooter', 'organigram_97', 'forcity_mere', 'mymairie', 'quorum', 'fullmobs', 'mairesetcitoyens', 'parlonspo', 'make3', 'consultvox', 'loomio', 'politiker', 'citizenlabbv', 'datagora', 'ouiville', 'forcity', 'accromedias', 'crowdpac', 'ledrenche', 'youvote', 'make2', 'ecreall_nova_ideo', 'neocity', 'citieszen', 'politicus', 'capcollectif', 'whip', 'voxestudio', 'LLL', 'citybay_ambitions', 'politizr', 'digitalebox', 'mesopinions', 'madeinvote', 'kawaa', 'ciwik', 'digiworks', 'equivote_myopencity', 'make', 'kohero', 'openagora', 'moneparti', 'nousrassemble', 'bittle', 'marston_massiet', 'koom', 'reperage_urbain', 'D21', 'IDcity', 'Stig', 'opensourcepolitics', 'GOV', 'fluicity', 'civocracy']

# %%
companies['companyname'] = companies['companyname'].replace(['LLL', 'make', 'citizenlabbv', 'voxestudio', 'marston_massiet'], ['liberté_living_lab', 'make.org', 'citizenlobbv', 'VOXE', 'marston'])

# %%
companies["post_code"]= companies["adresse"].apply(get_post_code)

# %%
companies["country"]="France"

# %% [markdown]
# ### export to sql and csv

# %%
companies.to_csv("companies_info.csv", sep=";", index=False)

# %%
companies.to_sql('companies_info', engine, 'civictech', if_exists='replace', index=False)
# Out:
# 61

# %%
associations.to_csv("associations_info.csv", sep=';', index=False)

# %%
associations.to_sql("associations_info", engine, 'civictech', if_exists='replace', index=False)
# Out:
# 15

# %%
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_sql.html

# you can pass data types here 
# from sqlalchemy.types import Integer
# df.to_sql('integers', con=engine, index=False,
#           dtype={"A": Integer()})
