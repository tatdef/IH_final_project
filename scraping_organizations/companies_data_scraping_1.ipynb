# %% [markdown]
# ## Creating html file list

# %%
import pandas as pd

# %%
import os
file_list = [f for f in os.listdir('htmls') if f.endswith(".html")]
len(file_list)
print(file_list)
# Out:
# ['citility.html', 'poligma.html', 'voxcracy.html', 'LLL_2.html', 'bluenove.html', 'ecivis.html', 'make4.html', 'civimetric.html', 'voteetvous.html', 'vooter.html', 'organigram_97.html', 'forcity_mere.html', 'mymairie.html', 'quorum.html', 'fullmobs.html', 'mairesetcitoyens.html', 'parlonspo.html', 'make3.html', 'consultvox.html', 'loomio.html', 'politiker.html', 'citizenlabbv.html', 'datagora.html', 'ouiville.html', 'forcity.html', 'accromedias.html', 'lesbricodeurs.html', 'crowdpac.html', 'ledrenche.html', 'youvote.html', 'make2.html', 'ecreall_nova_ideo.html', 'neocity.html', 'citieszen.html', 'politicus.html', 'capcollectif.html', 'whip.html', 'voxestudio.html', 'democracyos.html', 'polipart.html', 'LLL.html', 'hacktiv.html', 'voxpublic.html', 'citybay_ambitions.html', 'politizr.html', 'digitalebox.html', 'mesopinions.html', 'assemblee_virtuelle.html', 'madeinvote.html', 'wesignit.html', 'mieuxvoter.html', 'kawaa.html', 'ciwik.html', 'data_for_good.html', 'digiworks.html', 'equivote_myopencity.html', 'make.html', 'kohero.html', 'openagora.html', 'moneparti.html', 'nousrassemble.html', 'bittle.html', 'marston_massiet.html', 'democratieouverte.html', 'koom.html', 'purpoz.html', 'reperage_urbain.html', 'regardscitoyens.html', 'D21.html', 'IDcity.html', 'Stig.html', 'opensourcepolitics.html', 'GOV.html', 'veritepol.html', 'fluicity.html', 'civocracy.html']

# %% [markdown]
# ## Importing htmls into dictionary

# %%
capco= pd.read_html("htmls/capcollectif.html")

# %%
capco
# Out:
# [              0                                                  1
#  0     Adresse :               25 RUE CLAUDE TILLIER 75012 PARIS 12
#  1    Activité :          Édition de logiciels système et de réseau
#  2    Effectif :             Entre 20 et 49 salariés  (donnée 2020)
#  3    Création :                                         16/05/2014
#  4  Dirigeants :  Cyril Pereira Lage, KARILA AUDIT ET CONSEIL, F...,
#                        0                                            1
#  0               SIREN :                                  803 377 571
#  1       SIRET (siège) :                            803 377 571 00036
#  2     Forme juridique :          SAS, société par actions simplifiée
#  3        Numéro de TVA:                                FR12803377571
#  4  Inscription au RCS :  INSCRIT (au greffe de PARIS, le 08/07/2014)
#  5          Numéro RCS :                     803 377 571 R.C.S. Paris
#  6      Capital social :                                  14 000,00 €,
#                                          0  \
#  0          Activité principale déclarée :
#  1                       Code NAF ou APE :
#  2                    Domaine d’activité :
#  3              Conventions collectives  :
#  4  Date de clôture d'exercice comptable :
#
#                                                     1
#  0  Conception, réalisation et diffusion de tout p...
#  1  58.29A (Édition de logiciels système et de rés...
#  2                                            Édition
#  3  IDCC 9999  Bureaux d'études techniques, des ca...
#  4                                         31/12/2023  ,
#                              Performance   2020    2019    2018   2017
#  0                Chiffre d'affaires (€)  1,93M   2,38M    1,5M   840K
#  1                       Marge brute (€)  1,93M   2,38M    1,5M   849K
#  2                      EBITDA - EBE (€)  -178K    117K  -67,9K  2,47K
#  3           Résultat d'exploitation (€)  -211K   71,2K  -84,9K  2,29K
#  4                      Résultat net (€)  -134K    148K   8,46K  68,4K
#  5                            Croissance   2020    2019    2018   2017
#  6          Taux de croissance du CA (%)    -19     592      78    825
#  7               Taux de marge brute (%)    100     100     100    101
#  8            Taux de marge d'EBITDA (%)    -92      49     -45     03
#  9      Taux de marge opérationnelle (%)   -109       3     -57     03
#  10                          Gestion BFR   2020    2019    2018   2017
#  11                              BFR (€)  -106K  -57,4K    183K  24,1K
#  12                 BFR exploitation (€)   226K    351K    370K   195K
#  13            BFR hors exploitation (€)  -332K   -408K   -187K  -171K
#  14                        BFR (j de CA)    -20     -88     446    104
#  15           BFR exploitation (j de CA)    427     538     903    845
#  16      BFR hors exploitation (j de CA)   -627    -626    -457   -741
#  17        Délai de paiement clients (j)    606     868     110    113
#  18   Délai de paiement fournisseurs (j)    559     908     674    794
#  19            Ratio des stocks / CA (j)      0       0       0      0
#  20                 Autonomie financière   2020    2019    2018   2017
#  21       Capacité d'autofinancement (€)  -100K    194K     28K  76,9K
#  22  Capacité d'autofinancement / CA (%)    -52      82      19     91
#  23    Fonds de roulement net global (€)  1,46M   1,52M   1,38M  1,61M
#  24                    Couverture du BFR   -138    -264      75    667
#  25                       Trésorerie (€)  1,56M   1,57M   1,19M  1,58M
#  26               Dettes financières (€)   228K    181K    201K   202K
#  27            Capacité de remboursement    133     -72    -355    -18
#  28        Ratio d'endettement (Gearing)    -09     -09     -07     -1
#  29             Autonomie financière (%)     61     622     709    729
#  30          Taux de levier (DFN/EBITDA)     75    -119     146   -560
#  31                          Solvabilité   2020    2019    2018   2017
#  32   Etat des dettes à 1 an au plus (€)   703K    805K    411K   333K
#  33                   Liquidité générale     31      29      43     58
#  34                Couverture des dettes    -02     -02     -03      0
#  35                    Fonds propres (€)  1,45M   1,59M   1,44M  1,43M
#  36                          Rentabilité   2020    2019    2018   2017
#  37                      Marge nette (%)    -69      62      06     81
#  38    Rentabilité sur fonds propres (%)    -92      93      06     48
#  39           Rentabilité économique (%)    -56      58      04     35
#  40                   Valeur ajoutée (€)  1,31M   1,52M   1,06M   545K
#  41              Valeur ajoutée / CA (%)    679     637     706    648
#  42                 Structure d'activité   2020    2019    2018   2017
#  43     Salaires et charges sociales (€)  1,47M   1,37M    1,1M   528K
#  44                    Salaires / CA (%)    764     575     737    628
#  45                  Impôts et taxes (€)  28,5K   23,7K   19,9K  4,46K
#  46    Chiffre d'affaires à l'export (€)    NaN     417     44K    15K,
#                      0                                     1
#  0         Téléphone :                        Non disponible
#  1             Email :                        Non disponible
#  2     Site internet :                        Non disponible
#  3  Adresse complète :  25 RUE CLAUDE TILLIER 75012 PARIS 12,
#     Prestataire                  Service      Unnamed: 2
#  0          NaN   Financement innovation  En savoir plus
#  1          NaN            Domiciliation  En savoir plus
#  2          NaN                     Paie  En savoir plus
#  3          NaN  Logiciel de facturation  En savoir plus
#  4          NaN             Recouvrement  En savoir plus]

# %%
data_companies=dict()
for i in range(len(file_list)):
    a= pd.read_html('htmls/'+str(file_list[i]))
    data_companies[(file_list[i]).split('.html')[0]] = a

# %%
data_companies.keys()
# Out:
# dict_keys(['citility', 'poligma', 'voxcracy', 'LLL_2', 'bluenove', 'ecivis', 'make4', 'civimetric', 'voteetvous', 'vooter', 'organigram_97', 'forcity_mere', 'mymairie', 'quorum', 'fullmobs', 'mairesetcitoyens', 'parlonspo', 'make3', 'consultvox', 'loomio', 'politiker', 'citizenlabbv', 'datagora', 'ouiville', 'forcity', 'accromedias', 'lesbricodeurs', 'crowdpac', 'ledrenche', 'youvote', 'make2', 'ecreall_nova_ideo', 'neocity', 'citieszen', 'politicus', 'capcollectif', 'whip', 'voxestudio', 'democracyos', 'polipart', 'LLL', 'hacktiv', 'voxpublic', 'citybay_ambitions', 'politizr', 'digitalebox', 'mesopinions', 'assemblee_virtuelle', 'madeinvote', 'wesignit', 'mieuxvoter', 'kawaa', 'ciwik', 'data_for_good', 'digiworks', 'equivote_myopencity', 'make', 'kohero', 'openagora', 'moneparti', 'nousrassemble', 'bittle', 'marston_massiet', 'democratieouverte', 'koom', 'purpoz', 'reperage_urbain', 'regardscitoyens', 'D21', 'IDcity', 'Stig', 'opensourcepolitics', 'GOV', 'veritepol', 'fluicity', 'civocracy'])

# %%
type(data_companies['citility'])
# Out:
# list

# %%
type(data_companies['citility'][0])
# Out:
# pandas.core.frame.DataFrame

# %%
data_companies['citility'][0] # adress
# [0] provides basic information : adress, activity, number of employees, date of creation, directors 
# it's a dataframe
# Out:
#               0                                   1
# 0     Adresse :  5 RUE DE LA CLAIRE 69009 LYON 9EME
# 1    Activité :    Édition de logiciels applicatifs
# 2    Effectif :            0 salarié  (donnée 2019)
# 3    Création :                          05/05/2014
# 4  Dirigeants :   André MAY, ODICEO, Sabine SCHNECK

# %%
data_companies['citility'][1]
# [1] provides company information : SIREN, juridical form, TVA number, inscription RCA, n°, social capital 
# it's a dataframe
# Out:
#                       0                                           1
# 0               SIREN :                                 802 503 276
# 1       SIRET (siège) :                           802 503 276 00023
# 2     Forme juridique :         SAS, société par actions simplifiée
# 3        Numéro de TVA:                               FR07802503276
# 4  Inscription au RCS :  INSCRIT (au greffe de LYON, le 12/05/2014)
# 5          Numéro RCS :                     802 503 276 R.C.S. Lyon
# 6      Capital social :                                 39 620,00 €

# %%
pd.DataFrame(data_companies['citility'][2])
# [2] provides information on the activity - activité déclarée, code NAF, domaine d'activité, convention coll supposée, cloture exercice
# it's a dataframe
# Out:
#                                                    0  \
# 0                     Activité principale déclarée :
# 1                                  Code NAF ou APE :
# 2                               Domaine d’activité :
# 3  Convention collective  supposéeNous avons esti...
# 4             Date de clôture d'exercice comptable :
#
#                                                    1
# 0                  Edition de logiciels applicatifs.
# 1          58.29C (Édition de logiciels applicatifs)
# 2                                            Édition
# 3  Bureaux d'études techniques et sociétés de con...
# 4                                         31/12/2023

# %%
pd.DataFrame(data_companies['citility'][3])
# provides data per year for financial performance
# it's a dataframe with 3 columns
# Out:
#                             Performance   2017    2016
# 0                Chiffre d'affaires (€)    NaN   30,7K
# 1                       Marge brute (€)    NaN    527K
# 2                      EBITDA - EBE (€)    NaN   -295K
# 3           Résultat d'exploitation (€)    NaN   -296K
# 4                      Résultat net (€)  -562K   -238K
# 5                            Croissance   2017    2016
# 6          Taux de croissance du CA (%)    NaN       4
# 7               Taux de marge brute (%)    NaN   1,72K
# 8            Taux de marge d'EBITDA (%)    NaN    -961
# 9      Taux de marge opérationnelle (%)    NaN    -965
# 10                          Gestion BFR   2017    2016
# 11                              BFR (€)  -247K   -213K
# 12                 BFR exploitation (€)  -134K   -217K
# 13            BFR hors exploitation (€)  -112K   3,78K
# 14                        BFR (j de CA)    NaN  -2,53K
# 15           BFR exploitation (j de CA)    NaN  -2,58K
# 16      BFR hors exploitation (j de CA)    NaN     449
# 17        Délai de paiement clients (j)    NaN     535
# 18   Délai de paiement fournisseurs (j)    NaN     566
# 19            Ratio des stocks / CA (j)    NaN       0
# 20                 Autonomie financière   2017    2016
# 21       Capacité d'autofinancement (€)    NaN   -289K
# 22  Capacité d'autofinancement / CA (%)    NaN    -942
# 23    Fonds de roulement net global (€)   549K   -210K
# 24                    Couverture du BFR    -22       1
# 25                       Trésorerie (€)   796K    2,9K
# 26               Dettes financières (€)   406K    476K
# 27            Capacité de remboursement    NaN     -16
# 28        Ratio d'endettement (Gearing)    -03      12
# 29             Autonomie financière (%)    617     278
# 30          Taux de levier (DFN/EBITDA)    NaN     -16
# 31                          Solvabilité   2017    2016
# 32   Etat des dettes à 1 an au plus (€)   591K    604K
# 33                   Liquidité générale     17      05
# 34                Couverture des dettes    -32      23
# 35                    Fonds propres (€)  1,38M    382K
# 36                          Rentabilité   2017    2016
# 37                      Marge nette (%)    NaN    -775
# 38    Rentabilité sur fonds propres (%)    NaN    -623
# 39           Rentabilité économique (%)    NaN    -173
# 40                   Valeur ajoutée (€)    NaN    351K
# 41              Valeur ajoutée / CA (%)    NaN   1,14K
# 42                 Structure d'activité   2017    2016
# 43     Salaires et charges sociales (€)    NaN    636K
# 44                    Salaires / CA (%)    NaN   2,07K
# 45                  Impôts et taxes (€)    NaN   9,16K

# %%
pd.DataFrame(data_companies['citility'][4])
# it's a dataframe
# Out:
#                     0                                   1
# 0         Téléphone :                      Non disponible
# 1             Email :                      Non disponible
# 2     Site internet :                      Non disponible
# 3  Adresse complète :  5 RUE DE LA CLAIRE 69009 LYON 9EME

# %% [markdown]
# ## from nested dataframes in dictionary to a dataframe

# %%
citility=pd.concat([pd.DataFrame(data_companies['citility'][0]), pd.DataFrame(data_companies['citility'][1]), pd.DataFrame(data_companies['citility'][2][0:3]), pd.DataFrame(data_companies['citility'][4])], axis=0).reset_index(drop=True)

# %%
citility
# Out:
#                                  0                                           1
# 0                        Adresse :          5 RUE DE LA CLAIRE 69009 LYON 9EME
# 1                       Activité :            Édition de logiciels applicatifs
# 2                       Effectif :                    0 salarié  (donnée 2019)
# 3                       Création :                                  05/05/2014
# 4                     Dirigeants :           André MAY, ODICEO, Sabine SCHNECK
# 5                          SIREN :                                 802 503 276
# 6                  SIRET (siège) :                           802 503 276 00023
# 7                Forme juridique :         SAS, société par actions simplifiée
# 8                   Numéro de TVA:                               FR07802503276
# 9             Inscription au RCS :  INSCRIT (au greffe de LYON, le 12/05/2014)
# 10                    Numéro RCS :                     802 503 276 R.C.S. Lyon
# 11                Capital social :                                 39 620,00 €
# 12  Activité principale déclarée :           Edition de logiciels applicatifs.
# 13               Code NAF ou APE :   58.29C (Édition de logiciels applicatifs)
# 14            Domaine d’activité :                                     Édition
# 15                     Téléphone :                              Non disponible
# 16                         Email :                              Non disponible
# 17                 Site internet :                              Non disponible
# 18              Adresse complète :          5 RUE DE LA CLAIRE 69009 LYON 9EME

# %%
list(data_companies.keys())
# Out:
# ['citility',
#  'poligma',
#  'voxcracy',
#  'LLL_2',
#  'bluenove',
#  'ecivis',
#  'make4',
#  'civimetric',
#  'voteetvous',
#  'vooter',
#  'organigram_97',
#  'forcity_mere',
#  'mymairie',
#  'quorum',
#  'fullmobs',
#  'mairesetcitoyens',
#  'parlonspo',
#  'make3',
#  'consultvox',
#  'loomio',
#  'politiker',
#  'citizenlabbv',
#  'datagora',
#  'ouiville',
#  'forcity',
#  'accromedias',
#  'lesbricodeurs',
#  'crowdpac',
#  'ledrenche',
#  'youvote',
#  'make2',
#  'ecreall_nova_ideo',
#  'neocity',
#  'citieszen',
#  'politicus',
#  'capcollectif',
#  'whip',
#  'voxestudio',
#  'democracyos',
#  'polipart',
#  'LLL',
#  'hacktiv',
#  'voxpublic',
#  'citybay_ambitions',
#  'politizr',
#  'digitalebox',
#  'mesopinions',
#  'assemblee_virtuelle',
#  'madeinvote',
#  'wesignit',
#  'mieuxvoter',
#  'kawaa',
#  'ciwik',
#  'data_for_good',
#  'digiworks',
#  'equivote_myopencity',
#  'make',
#  'kohero',
#  'openagora',
#  'moneparti',
#  'nousrassemble',
#  'bittle',
#  'marston_massiet',
#  'democratieouverte',
#  'koom',
#  'purpoz',
#  'reperage_urbain',
#  'regardscitoyens',
#  'D21',
#  'IDcity',
#  'Stig',
#  'opensourcepolitics',
#  'GOV',
#  'veritepol',
#  'fluicity',
#  'civocracy']

# %%
pd.DataFrame(data_companies['citility'][2][0:3])
# Out:
#                                 0                                          1
# 0  Activité principale déclarée :          Edition de logiciels applicatifs.
# 1               Code NAF ou APE :  58.29C (Édition de logiciels applicatifs)
# 2            Domaine d’activité :                                    Édition

# %%
new_df=pd.concat([pd.DataFrame(data_companies['citility'][0][0]), pd.DataFrame(data_companies['citility'][1][0]), pd.DataFrame(data_companies['citility'][2][0][0:3])], axis=0).reset_index(drop=True)
new_df.columns=['ind']
for i in list(data_companies.keys()):
    a= pd.concat([pd.DataFrame(data_companies[str(i)][0]), pd.DataFrame(data_companies[str(i)][1]), pd.DataFrame(data_companies[str(i)][2][0:3])], axis=0).reset_index(drop=True)   
    a.columns=['ind', i]
    new_df= new_df.merge(a, how='outer')

# %%
new_df
# Out:
#                                ind  \
# 0                        Adresse :
# 1                       Activité :
# 2                       Effectif :
# 3                       Création :
# 4                     Dirigeants :
# 5                          SIREN :
# 6                  SIRET (siège) :
# 7                Forme juridique :
# 8                   Numéro de TVA:
# 9             Inscription au RCS :
# 10                    Numéro RCS :
# 11                Capital social :
# 12  Activité principale déclarée :
# 13               Code NAF ou APE :
# 14            Domaine d’activité :
# 15                     Dirigeant :
# 16    Capital variable (minimum) :
# 17        Convention collective  :
# 18            Inscription au RNA :
# 19       Identifiant association :
# 20        Objet de l'association :
# 21                  Statut INSEE :
#
#                                       citility  \
# 0           5 RUE DE LA CLAIRE 69009 LYON 9EME
# 1             Édition de logiciels applicatifs
# 2                     0 salarié  (donnée 2019)
# 3                                   05/05/2014
# 4            André MAY, ODICEO, Sabine SCHNECK
# 5                                  802 503 276
# 6                            802 503 276 00023
# 7          SAS, société par actions simplifiée
# 8                                FR07802503276
# 9   INSCRIT (au greffe de LYON, le 12/05/2014)
# 10                     802 503 276 R.C.S. Lyon
# 11                                 39 620,00 €
# 12           Edition de logiciels applicatifs.
# 13   58.29C (Édition de logiciels applicatifs)
# 14                                     Édition
# 15                                         NaN
# 16                                         NaN
# 17                                         NaN
# 18                                         NaN
# 19                                         NaN
# 20                                         NaN
# 21                                         NaN
#
#                                               poligma  \
# 0     RPT BENJAMIN FRANKLIN 34960 MONTPELLIER CEDEX 2
# 1      Conseil en systèmes et logiciels informatiques
# 2                Entre 3 et 5 salariés  (donnée 2020)
# 3                                          01/09/2015
# 4                                                 NaN
# 5                                         813 463 601
# 6                                   813 463 601 00027
# 7                 SAS, société par actions simplifiée
# 8                                       FR19813463601
# 9   INSCRIT (au greffe de MONTPELLIER, le 11/09/2015)
# 10                     813 463 601 R.C.S. Montpellier
# 11                                        20 944,00 €
# 12  Développement de services informatiques et num...
# 13  62.02A (Conseil en systèmes et logiciels infor...
# 14  Programmation, conseil et autres activités inf...
# 15                                    Philippe GERARD
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
#
#                                              voxcracy  \
# 0                      1133 RTE FENERIE 06580 PEGOMAS
# 1                          Programmation informatique
# 2                                           0 salarié
# 3                                          01/09/2014
# 4                       Olivier ROCCA, Pascal RUSCICA
# 5                                         803 548 031
# 6                                   803 548 031 00019
# 7                 SAS, société par actions simplifiée
# 8                                       FR08803548031
# 9        INSCRIT (au greffe de GRASSE, le 17/07/2014)
# 10                          803 548 031 R.C.S. Grasse
# 11                                         1 000,00 €
# 12  La recherche, le développement et la commercia...
# 13                62.01Z (Programmation informatique)
# 14  Programmation, conseil et autres activités inf...
# 15                                                NaN
# 16                                           100,00 €
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
#
#                                                 LLL_2  \
# 0                       16 RUE DU CAIRE 75002 PARIS 2
# 1   Autres activités de soutien aux entreprises n....
# 2                Entre 3 et 5 salariés  (donnée 2020)
# 3                                          16/01/2015
# 4               ANNAMAMASHOW, Raymond Maeder, 3APEXCO
# 5                                         809 375 744
# 6                                   809 375 744 00012
# 7                 SAS, société par actions simplifiée
# 8                                       FR61809375744
# 9         INSCRIT (au greffe de PARIS, le 03/02/2015)
# 10                           809 375 744 R.C.S. Paris
# 11                                        45 000,00 €
# 12  Développement de nouvelles formes de collabora...
# 13  82.99Z (Autres activités de soutien aux entrep...
# 14  Activités administratives et autres activités ...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
#
#                                              bluenove  \
# 0                   112 B RUE CARDINET 75017 PARIS 17
# 1   Conseil pour les affaires et autres conseils d...
# 2              Entre 20 et 49 salariés  (donnée 2020)
# 3                                          23/01/2008
# 4   GROUPE BLUENOVE INC., Guillaume Drancy, Carole...
# 5                                         502 204 944
# 6                                   502 204 944 00057
# 7                 SAS, société par actions simplifiée
# 8                                       FR77502204944
# 9         INSCRIT (au greffe de PARIS, le 21/11/2019)
# 10                           502 204 944 R.C.S. Paris
# 11                                        56 445,00 €
# 12  L'activité de conseil en stratégie d'accompagn...
# 13  70.22Z (Conseil pour les affaires et autres co...
# 14  Activités des sièges sociaux ; conseil de gestion
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
#
#                                                ecivis  \
# 0                   3 IMP JEAN MERMOZ 31470 FONSORBES
# 1                          Programmation informatique
# 2                            0 salarié  (donnée 2018)
# 3                                          16/12/2016
# 4                                                 NaN
# 5                                         824 613 160
# 6                                   824 613 160 00012
# 7                 SAS, société par actions simplifiée
# 8                                       FR89824613160
# 9        RADIÉ (du greffe de TOULOUSE, le 31/10/2018)
# 10                        824 613 160 R.C.S. Toulouse
# 11                                        20 000,00 €
# 12  Prestation de services et accès à une platefor...
# 13                62.01Z (Programmation informatique)
# 14  Programmation, conseil et autres activités inf...
# 15                                        Rémi POSTIC
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
#
#                                                 make4  \
# 0                   14 RUE ST GUILLAUME 75007 PARIS 7
# 1   Autres organisations fonctionnant par adhésion...
# 2                Entre 3 et 5 salariés  (donnée 2020)
# 3                                          11/01/2017
# 4                                                 NaN
# 5                                         827 559 964
# 6                                   827 559 964 00016
# 7                                Association déclarée
# 8                                       FR18827559964
# 9                                         Non inscrit
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13  94.99Z (Autres organisations fonctionnant par ...
# 14           Activités des organisations associatives
# 15                                                NaN
# 16                                                NaN
# 17  Bureaux d'études techniques, des cabinets d'in...
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
#
#                                            civimetric  \
# 0                12 PAS DE LA FONDERIE 75011 PARIS 11
# 1   Conseil pour les affaires et autres conseils d...
# 2                            0 salarié  (donnée 2019)
# 3                                          16/02/2018
# 4                                                 NaN
# 5                                         837 570 316
# 6                                   837 570 316 00013
# 7              SARL, société à responsabilité limitée
# 8                                       FR68837570316
# 9           RADIÉ (du greffe de PARIS, le 04/08/2020)
# 10                           837 570 316 R.C.S. Paris
# 11                                         3 300,00 €
# 12  Le conseil et la réalisation d'études quantita...
# 13  70.22Z (Conseil pour les affaires et autres co...
# 14  Activités des sièges sociaux ; conseil de gestion
# 15                                      Fabien Durand
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
#
#                                            voteetvous  ...  \
# 0                  133 RUE ST DOMINIQUE 75007 PARIS 7  ...
# 1   Autres organisations fonctionnant par adhésion...  ...
# 2                   Au moins 1 salarié  (donnée 2023)  ...
# 3                                          27/01/2014  ...
# 4                                                 NaN  ...
# 5                                         800 468 001  ...
# 6                                   800 468 001 00014  ...
# 7                                Association déclarée  ...
# 8                                       FR41800468001  ...
# 9                                         Non inscrit  ...
# 10                                                NaN  ...
# 11                                                NaN  ...
# 12                                                NaN  ...
# 13  94.99Z (Autres organisations fonctionnant par ...  ...
# 14           Activités des organisations associatives  ...
# 15                                                NaN  ...
# 16                                                NaN  ...
# 17                                                NaN  ...
# 18                             INSCRITE le 27/01/2014  ...
# 19                                         W751223032  ...
# 20  Renforcer l'exercice démocratique du vote, en ...  ...
# 21                                                NaN  ...
#
#                                       reperage_urbain  \
# 0                   210 RUE SAINT MAUR 75010 PARIS 10
# 1   Recherche-développement en sciences humaines e...
# 2                Entre 3 et 5 salariés  (donnée 2020)
# 3                                          07/10/2004
# 4                                                 NaN
# 5                                         479 228 710
# 6                                   479 228 710 00014
# 7              SARL, société à responsabilité limitée
# 8                                       FR60479228710
# 9         INSCRIT (au greffe de PARIS, le 28/10/2004)
# 10                           479 228 710 R.C.S. Paris
# 11                                         5 000,00 €
# 12  Étude et conseil, en sociologie, urbanisme, am...
# 13  72.20Z (Recherche-développement en sciences hu...
# 14               Recherche-développement scientifique
# 15                                       ERIC HAMELIN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
#
#                                       regardscitoyens  \
# 0                        10 CHE TRICOU 31200 TOULOUSE
# 1   Autres organisations fonctionnant par adhésion...
# 2                            0 salarié  (donnée 2023)
# 3                                          15/07/2013
# 4                                                 NaN
# 5                                         801 998 444
# 6                                   801 998 444 00013
# 7                                Association déclarée
# 8                                       FR69801998444
# 9                                         Non inscrit
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13  94.99Z (Autres organisations fonctionnant par ...
# 14           Activités des organisations associatives
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                             INSCRITE le 09/06/2010
# 19                                         W691076577
# 20  Promouvoir par la pratique le libre accès aux ...
# 21                                                NaN
#
#                                                   D21  \
# 0          23 RUE JEAN JACQUES ROUSSEAU 75001 PARIS 1
# 1   Conseil pour les affaires et autres conseils d...
# 2                   Au moins 1 salarié  (donnée 2023)
# 3                                          26/10/2017
# 4                                                 NaN
# 5                                         833 097 801
# 6                                   833 097 801 00017
# 7   EURL, entreprise unipersonnelle à responsabili...
# 8                                       FR48833097801
# 9           RADIÉ (du greffe de PARIS, le 17/01/2022)
# 10                           833 097 801 R.C.S. Paris
# 11                                           100,00 €
# 12  L'aide à la concertation et la prise de décisi...
# 13  70.22Z (Conseil pour les affaires et autres co...
# 14  Activités des sièges sociaux ; conseil de gestion
# 15                                        Andrew Gray
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                              ACTIF
#
#                                                IDcity  \
# 0                         PARC MENEZ 29900 CONCARNEAU
# 1                          Programmation informatique
# 2                Entre 6 et 9 salariés  (donnée 2020)
# 3                                          19/05/2015
# 4                                                 NaN
# 5                                         811 548 759
# 6                                   811 548 759 00018
# 7                 SAS, société par actions simplifiée
# 8                                       FR27811548759
# 9       INSCRIT (au greffe de QUIMPER, le 27/05/2015)
# 10                         811 548 759 R.C.S. Quimper
# 11                                         1 000,00 €
# 12  Prestation de services, édition et commerciali...
# 13                62.01Z (Programmation informatique)
# 14  Programmation, conseil et autres activités inf...
# 15                                     Antoine JESTIN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
#
#                                                  Stig  \
# 0                       114 RUE DE GRANGE 79000 NIORT
# 1                          Programmation informatique
# 2                            0 salarié  (donnée 2023)
# 3                                          20/09/2015
# 4                        CONNORS SAS, Geoffroy MICHEL
# 5                                         813 756 194
# 6                                   813 756 194 00037
# 7                 SAS, société par actions simplifiée
# 8                                       FR45813756194
# 9         INSCRIT (au greffe de NIORT, le 11/10/2022)
# 10                           813 756 194 R.C.S. Niort
# 11                                        35 000,00 €
# 12  Édition, développement et exploitation de site...
# 13                62.01Z (Programmation informatique)
# 14  Programmation, conseil et autres activités inf...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
#
#                                    opensourcepolitics  \
# 0                  32 RUE DES CASCADES 75020 PARIS 20
# 1                                   Portails Internet
# 2              Entre 10 et 19 salariés  (donnée 2020)
# 3                                          12/05/2016
# 4                   Olivier Buchotte, Valentin Chaput
# 5                                         820 412 161
# 6                                   820 412 161 00011
# 7              SARL, société à responsabilité limitée
# 8                                       FR11820412161
# 9         INSCRIT (au greffe de PARIS, le 20/05/2016)
# 10                           820 412 161 R.C.S. Paris
# 11                                         5 000,00 €
# 12  Outils et méthodes de démocratie en ligne (log...
# 13                         63.12Z (Portails Internet)
# 14                             Services d'information
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
#
#                                                   GOV  \
# 0                    48 RUE DE PROVENCE 75009 PARIS 9
# 1                          Programmation informatique
# 2                            0 salarié  (donnée 2019)
# 3                                          22/04/2014
# 4                                                 NaN
# 5                                         801 906 033
# 6                                   801 906 033 00015
# 7                 SAS, société par actions simplifiée
# 8                                       FR62801906033
# 9           RADIÉ (du greffe de PARIS, le 12/06/2020)
# 10                           801 906 033 R.C.S. Paris
# 11                                         1 674,00 €
# 12  Développement et mise en service d'application...
# 13                62.01Z (Programmation informatique)
# 14  Programmation, conseil et autres activités inf...
# 15                            Pierre-Alexandre Teulié
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
#
#                                             veritepol  \
# 0                   30 RUE JULES FERRY 64200 BIARRITZ
# 1   Autres organisations fonctionnant par adhésion...
# 2                            0 salarié  (donnée 2023)
# 3                                          30/06/2015
# 4                                                 NaN
# 5                                         819 027 491
# 6                                   819 027 491 00011
# 7                                Association déclarée
# 8                                       FR26819027491
# 9                                         Non inscrit
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13  94.99Z (Autres organisations fonctionnant par ...
# 14           Activités des organisations associatives
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                             INSCRITE le 30/06/2015
# 19                                         W641007002
# 20  D'impulser et promouvoir de nouvelles formes d...
# 21                                                NaN
#
#                                              fluicity  \
# 0                         17 RUE MESLAY 75003 PARIS 3
# 1                          Programmation informatique
# 2                            0 salarié  (donnée 2023)
# 3                                          10/07/2015
# 4   Julie De La Vallee De Rarecourt De Pimodan, Ni...
# 5                                         812 620 318
# 6                                   812 620 318 00020
# 7                 SAS, société par actions simplifiée
# 8                                       FR27812620318
# 9         INSCRIT (au greffe de PARIS, le 21/07/2015)
# 10                           812 620 318 R.C.S. Paris
# 11                                        41 190,00 €
# 12  Le développement et l'exploitation de plate fo...
# 13                62.01Z (Programmation informatique)
# 14  Programmation, conseil et autres activités inf...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
#
#                                             civocracy
# 0                     84 RUE DELEUVRE 69004 LYON 4EME
# 1                                   Portails Internet
# 2                   Au moins 1 salarié  (donnée 2023)
# 3                                          09/10/2020
# 4                                                 NaN
# 5                                         890 397 375
# 6                                   890 397 375 00019
# 7                 SAS, société par actions simplifiée
# 8                                       FR26890397375
# 9          INSCRIT (au greffe de LYON, le 27/10/2020)
# 10                            890 397 375 R.C.S. Lyon
# 11                                         8 079,68 €
# 12  Promouvoir des formes de discussions collabora...
# 13                         63.12Z (Portails Internet)
# 14                             Services d'information
# 15                                        Chloé PAHUD
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
#
# [22 rows x 77 columns]

# %%
len(pd.DataFrame(data_companies['citility'][3]))
# Out:
# 46

# %%
new_df.set_index("ind", inplace=True)

# %%
new_df.drop(['SIREN :', 'SIRET (siège) :', 'Numéro de TVA:', 'Numéro RCS :', 'Capital variable (minimum) :'], axis=0, inplace=True)

# %%
new_df.reset_index(inplace=True)

# %%
new_df.drop([new_df.index[12]], inplace=True)

# %%
new_df.reset_index(drop=True, inplace=True)

# %%
new_df.T
# Out:
#                                                                  0   \
# ind                                                       Adresse :
# citility                         5 RUE DE LA CLAIRE 69009 LYON 9EME
# poligma             RPT BENJAMIN FRANKLIN 34960 MONTPELLIER CEDEX 2
# voxcracy                             1133 RTE FENERIE 06580 PEGOMAS
# LLL_2                                 16 RUE DU CAIRE 75002 PARIS 2
# ...                                                             ...
# opensourcepolitics               32 RUE DES CASCADES 75020 PARIS 20
# GOV                                48 RUE DE PROVENCE 75009 PARIS 9
# veritepol                         30 RUE JULES FERRY 64200 BIARRITZ
# fluicity                                17 RUE MESLAY 75003 PARIS 3
# civocracy                           84 RUE DELEUVRE 69004 LYON 4EME
#
#                                                                    1   \
# ind                                                        Activité :
# citility                             Édition de logiciels applicatifs
# poligma                Conseil en systèmes et logiciels informatiques
# voxcracy                                   Programmation informatique
# LLL_2               Autres activités de soutien aux entreprises n....
# ...                                                               ...
# opensourcepolitics                                  Portails Internet
# GOV                                        Programmation informatique
# veritepol           Autres organisations fonctionnant par adhésion...
# fluicity                                   Programmation informatique
# civocracy                                           Portails Internet
#
#                                                         2           3   \
# ind                                             Effectif :  Création :
# citility                          0 salarié  (donnée 2019)  05/05/2014
# poligma               Entre 3 et 5 salariés  (donnée 2020)  01/09/2015
# voxcracy                                         0 salarié  01/09/2014
# LLL_2                 Entre 3 et 5 salariés  (donnée 2020)  16/01/2015
# ...                                                    ...         ...
# opensourcepolitics  Entre 10 et 19 salariés  (donnée 2020)  12/05/2016
# GOV                               0 salarié  (donnée 2019)  22/04/2014
# veritepol                         0 salarié  (donnée 2023)  30/06/2015
# fluicity                          0 salarié  (donnée 2023)  10/07/2015
# civocracy                Au moins 1 salarié  (donnée 2023)  09/10/2020
#
#                                                                    4   \
# ind                                                      Dirigeants :
# citility                            André MAY, ODICEO, Sabine SCHNECK
# poligma                                                           NaN
# voxcracy                                Olivier ROCCA, Pascal RUSCICA
# LLL_2                           ANNAMAMASHOW, Raymond Maeder, 3APEXCO
# ...                                                               ...
# opensourcepolitics                  Olivier Buchotte, Valentin Chaput
# GOV                                                               NaN
# veritepol                                                         NaN
# fluicity            Julie De La Vallee De Rarecourt De Pimodan, Ni...
# civocracy                                                         NaN
#
#                                                         5   \
# ind                                      Forme juridique :
# citility               SAS, société par actions simplifiée
# poligma                SAS, société par actions simplifiée
# voxcracy               SAS, société par actions simplifiée
# LLL_2                  SAS, société par actions simplifiée
# ...                                                    ...
# opensourcepolitics  SARL, société à responsabilité limitée
# GOV                    SAS, société par actions simplifiée
# veritepol                             Association déclarée
# fluicity               SAS, société par actions simplifiée
# civocracy              SAS, société par actions simplifiée
#
#                                                                    6   \
# ind                                              Inscription au RCS :
# citility                   INSCRIT (au greffe de LYON, le 12/05/2014)
# poligma             INSCRIT (au greffe de MONTPELLIER, le 11/09/2015)
# voxcracy                 INSCRIT (au greffe de GRASSE, le 17/07/2014)
# LLL_2                     INSCRIT (au greffe de PARIS, le 03/02/2015)
# ...                                                               ...
# opensourcepolitics        INSCRIT (au greffe de PARIS, le 20/05/2016)
# GOV                         RADIÉ (du greffe de PARIS, le 12/06/2020)
# veritepol                                                 Non inscrit
# fluicity                  INSCRIT (au greffe de PARIS, le 21/07/2015)
# civocracy                  INSCRIT (au greffe de LYON, le 27/10/2020)
#
#                                   7   \
# ind                 Capital social :
# citility                 39 620,00 €
# poligma                  20 944,00 €
# voxcracy                  1 000,00 €
# LLL_2                    45 000,00 €
# ...                              ...
# opensourcepolitics        5 000,00 €
# GOV                       1 674,00 €
# veritepol                        NaN
# fluicity                 41 190,00 €
# civocracy                 8 079,68 €
#
#                                                                    8   \
# ind                                    Activité principale déclarée :
# citility                            Edition de logiciels applicatifs.
# poligma             Développement de services informatiques et num...
# voxcracy            La recherche, le développement et la commercia...
# LLL_2               Développement de nouvelles formes de collabora...
# ...                                                               ...
# opensourcepolitics  Outils et méthodes de démocratie en ligne (log...
# GOV                 Développement et mise en service d'application...
# veritepol                                                         NaN
# fluicity            Le développement et l'exploitation de plate fo...
# civocracy           Promouvoir des formes de discussions collabora...
#
#                                                                    9   \
# ind                                                 Code NAF ou APE :
# citility                    58.29C (Édition de logiciels applicatifs)
# poligma             62.02A (Conseil en systèmes et logiciels infor...
# voxcracy                          62.01Z (Programmation informatique)
# LLL_2               82.99Z (Autres activités de soutien aux entrep...
# ...                                                               ...
# opensourcepolitics                         63.12Z (Portails Internet)
# GOV                               62.01Z (Programmation informatique)
# veritepol           94.99Z (Autres organisations fonctionnant par ...
# fluicity                          62.01Z (Programmation informatique)
# civocracy                                  63.12Z (Portails Internet)
#
#                                                                    10  \
# ind                                              Domaine d’activité :
# citility                                                      Édition
# poligma             Programmation, conseil et autres activités inf...
# voxcracy            Programmation, conseil et autres activités inf...
# LLL_2               Activités administratives et autres activités ...
# ...                                                               ...
# opensourcepolitics                             Services d'information
# GOV                 Programmation, conseil et autres activités inf...
# veritepol                    Activités des organisations associatives
# fluicity            Programmation, conseil et autres activités inf...
# civocracy                                      Services d'information
#
#                                          11                      12  \
# ind                             Dirigeant :    Inscription au RNA :
# citility                                NaN                     NaN
# poligma                     Philippe GERARD                     NaN
# voxcracy                                NaN                     NaN
# LLL_2                                   NaN                     NaN
# ...                                     ...                     ...
# opensourcepolitics                      NaN                     NaN
# GOV                 Pierre-Alexandre Teulié                     NaN
# veritepol                               NaN  INSCRITE le 30/06/2015
# fluicity                                NaN                     NaN
# civocracy                       Chloé PAHUD                     NaN
#
#                                            13  \
# ind                 Identifiant association :
# citility                                  NaN
# poligma                                   NaN
# voxcracy                                  NaN
# LLL_2                                     NaN
# ...                                       ...
# opensourcepolitics                        NaN
# GOV                                       NaN
# veritepol                          W641007002
# fluicity                                  NaN
# civocracy                                 NaN
#
#                                                                    14  \
# ind                                          Objet de l'association :
# citility                                                          NaN
# poligma                                                           NaN
# voxcracy                                                          NaN
# LLL_2                                                             NaN
# ...                                                               ...
# opensourcepolitics                                                NaN
# GOV                                                               NaN
# veritepol           D'impulser et promouvoir de nouvelles formes d...
# fluicity                                                          NaN
# civocracy                                                         NaN
#
#                                 15
# ind                 Statut INSEE :
# citility                       NaN
# poligma                        NaN
# voxcracy                       NaN
# LLL_2                          NaN
# ...                            ...
# opensourcepolitics             NaN
# GOV                            NaN
# veritepol                      NaN
# fluicity                       NaN
# civocracy                      NaN
#
# [77 rows x 16 columns]

# %%
(new_df.set_index("ind").T).to_csv('companies_info_data.csv', sep=';')

# %%
finance_df=pd.DataFrame(data_companies['citility'][3])
for i in list(data_companies.keys()):
    if len(data_companies[str(i)][3]) > 10:
        b= pd.DataFrame(data_companies[str(i)][3]).set_index("Performance").add_suffix('_'+i)
        finance_df=finance_df.merge(b, how='outer', on="Performance")
finance_df.drop(columns=['2017', '2016'], inplace=True)

# %%
finance_df
# Out:
#                             Performance 2017_citility 2016_citility  \
# 0                Chiffre d'affaires (€)           NaN         30,7K
# 1                       Marge brute (€)           NaN          527K
# 2                      EBITDA - EBE (€)           NaN         -295K
# 3           Résultat d'exploitation (€)           NaN         -296K
# 4                      Résultat net (€)         -562K         -238K
# 5                            Croissance          2017          2016
# 6          Taux de croissance du CA (%)           NaN             4
# 7               Taux de marge brute (%)           NaN         1,72K
# 8            Taux de marge d'EBITDA (%)           NaN          -961
# 9      Taux de marge opérationnelle (%)           NaN          -965
# 10                          Gestion BFR          2017          2016
# 11                              BFR (€)         -247K         -213K
# 12                 BFR exploitation (€)         -134K         -217K
# 13            BFR hors exploitation (€)         -112K         3,78K
# 14                        BFR (j de CA)           NaN        -2,53K
# 15           BFR exploitation (j de CA)           NaN        -2,58K
# 16      BFR hors exploitation (j de CA)           NaN           449
# 17        Délai de paiement clients (j)           NaN           535
# 18   Délai de paiement fournisseurs (j)           NaN           566
# 19            Ratio des stocks / CA (j)           NaN             0
# 20                 Autonomie financière          2017          2016
# 21       Capacité d'autofinancement (€)           NaN         -289K
# 22  Capacité d'autofinancement / CA (%)           NaN          -942
# 23    Fonds de roulement net global (€)          549K         -210K
# 24                    Couverture du BFR           -22             1
# 25                       Trésorerie (€)          796K          2,9K
# 26               Dettes financières (€)          406K          476K
# 27            Capacité de remboursement           NaN           -16
# 28        Ratio d'endettement (Gearing)           -03            12
# 29             Autonomie financière (%)           617           278
# 30          Taux de levier (DFN/EBITDA)           NaN           -16
# 31                          Solvabilité          2017          2016
# 32   Etat des dettes à 1 an au plus (€)          591K          604K
# 33                   Liquidité générale            17            05
# 34                Couverture des dettes           -32            23
# 35                    Fonds propres (€)         1,38M          382K
# 36                          Rentabilité          2017          2016
# 37                      Marge nette (%)           NaN          -775
# 38    Rentabilité sur fonds propres (%)           NaN          -623
# 39           Rentabilité économique (%)           NaN          -173
# 40                   Valeur ajoutée (€)           NaN          351K
# 41              Valeur ajoutée / CA (%)           NaN         1,14K
# 42                 Structure d'activité          2017          2016
# 43     Salaires et charges sociales (€)           NaN          636K
# 44                    Salaires / CA (%)           NaN         2,07K
# 45                  Impôts et taxes (€)           NaN         9,16K
# 46    Chiffre d'affaires à l'export (€)           NaN           NaN
#
#    2019_voxcracy 2018_voxcracy 2017_voxcracy 2016_voxcracy 2020_LLL_2  \
# 0          46,3K         16,7K         1,74K             0       473K
# 1          46,3K          157K         75,9K           NaN       473K
# 2         -31,5K         -123K        -24,4K        -1,08K      24,7K
# 3         -38,5K         -130K        -30,3K        -4,91K     -42,7K
# 4           -39K         -112K        -23,4K        -4,91K     -44,9K
# 5           2019          2018          2017          2016       2020
# 6            177           861           NaN           NaN         25
# 7            100           940         4,36K           NaN        100
# 8           -682          -734         -1,4K           NaN         52
# 9           -833          -776        -1,74K           NaN         -9
# 10          2019          2018          2017          2016       2020
# 11        -44,9K        -27,4K         7,68K        -2,46K       321K
# 12        -28,3K        -25,6K        -17,7K           NaN       635K
# 13        -16,6K        -1,74K         25,4K        -2,46K      -314K
# 14          -355          -598         1,61K           NaN        248
# 15          -223          -560        -3,72K           NaN        490
# 16          -131          -379         5,33K           NaN       -242
# 17            28           924           263           NaN        610
# 18           237           612           856             0        168
# 19             0             0             0           NaN          0
# 20          2019          2018          2017          2016       2020
# 21          -32K         -105K        -17,6K        -1,08K      22,5K
# 22          -691          -626        -1,01K           NaN         47
# 23        -44,9K        -14,2K         85,7K        -2,44K       348K
# 24             1            05           112             1         11
# 25           NaN         13,2K           78K            20      26,9K
# 26         51,6K         50,4K           NaN           NaN       483K
# 27           -16           -04            44             0        203
# 28            01            01           -01           -02         44
# 29           833           837           955             4         84
# 30           -16           -03            32             0        185
# 31          2019          2018          2017          2016       2020
# 32          103K         57,4K           NaN           NaN        NaN
# 33            01            07           NaN           NaN        NaN
# 34           118           166           -62          -127         05
# 35          513K          552K          569K           111       103K
# 36          2019          2018          2017          2016       2020
# 37          -842          -668        -1,35K           NaN        -95
# 38           -76          -202           -41        -4,42K       -437
# 39           -63          -169           -39          -177        -37
# 40         2,17K          -21K        -5,04K          -942       136K
# 41            47          -126          -290           NaN        287
# 42          2019          2018          2017          2016       2020
# 43         33,6K          101K         19,1K           NaN      97,1K
# 44           725           602          1,1K           NaN        205
# 45           137         1,12K           329           140      14,2K
# 46           NaN            5K           NaN           NaN        NaN
#
#    2019_LLL_2 2018_LLL_2  ...  2020_reperage_urbain 2019_reperage_urbain  \
# 0        462K       300K  ...                  113K                 214K
# 1        462K       300K  ...                  113K                 214K
# 2        160K      89,7K  ...                -24,1K               -23,3K
# 3       95,2K      25,9K  ...                -24,5K               -23,7K
# 4       62,4K      19,8K  ...                -24,9K               -24,4K
# 5        2019       2018  ...                  2020                 2019
# 6         539        NaN  ...                   -47                  -77
# 7         100        100  ...                   100                  100
# 8         346        299  ...                  -213                 -109
# 9         206         86  ...                  -216                 -111
# 10       2019       2018  ...                  2020                 2019
# 11      -130K      -119K  ...                 12,8K                6,23K
# 12       112K      -124K  ...                 43,9K                34,1K
# 13      -242K      5,33K  ...                -31,1K               -27,9K
# 14       -103       -144  ...                   412                  106
# 15        886       -151  ...                   141                  582
# 16       -192         65  ...                  -100                 -476
# 17        231         05  ...                   153                  608
# 18        388        367  ...                   319                   82
# 19          0          0  ...                     0                    0
# 20       2019       2018  ...                  2020                 2019
# 21       127K      83,6K  ...                -24,5K                 -24K
# 22        275        279  ...                  -216                 -112
# 23      -128K      -112K  ...                 44,2K                28,7K
# 24          1         09  ...                    35                   46
# 25      1,33K      2,63K  ...                 31,4K                22,5K
# 26      28,4K       166K  ...                 40,1K                  191
# 27         02          2  ...                   -04                   09
# 28         02         19  ...                    21                  -08
# 29        203        164  ...                    49                  464
# 30         02         18  ...                   -04                    1
# 31       2019       2018  ...                  2020                 2019
# 32        NaN        NaN  ...                   NaN                  NaN
# 33        NaN        NaN  ...                   NaN                  NaN
# 34        112         22  ...                     0                    0
# 35       148K      85,3K  ...                 4,09K                  29K
# 36       2019       2018  ...                  2020                 2019
# 37        135         66  ...                   -22                 -114
# 38        423        232  ...                  -610                 -843
# 39         86         38  ...                  -298                 -391
# 40       292K       175K  ...                   68K                 135K
# 41        632        584  ...                    60                  629
# 42       2019       2018  ...                  2020                 2019
# 43       126K      80,2K  ...                 90,2K                 154K
# 44        274        267  ...                   795                  719
# 45      7,35K      5,22K  ...                 3,36K                4,13K
# 46        NaN        NaN  ...                   NaN                  NaN
#
#    2018_reperage_urbain 2016_IDcity 2019_Stig 2018_Stig  \
# 0                  232K       9,95K      151K       134
# 1                  232K       9,95K      151K       135
# 2                 19,3K        -496     55,2K    -9,86K
# 3                   19K        -495     54,2K    -11,5K
# 4                 16,9K        -495     38,8K    -2,04K
# 5                  2018        2016      2019      2018
# 6                    43         NaN      112K       NaN
# 7                   100         100       100       101
# 8                    83          -5       366    -7,36K
# 9                    82          -5        36    -8,61K
# 10                 2018        2016      2019      2018
# 11                23,4K      -19,1K    -32,3K     1,05K
# 12                56,8K        7,2K    -7,94K       NaN
# 13               -33,4K      -26,3K    -24,4K     1,05K
# 14                  368        -702      -782     2,86K
# 15                  894         264      -192         0
# 16                 -526        -966       -59     2,86K
# 17                  926         264       110         0
# 18                  121           0       205         0
# 19                    0           0         0         0
# 20                 2018        2016      2019      2018
# 21                17,2K        -495     39,8K      -360
# 22                   74          -5       264      -269
# 23                52,8K         474     39,7K     1,05K
# 24                   23           0       -12         1
# 25                29,4K       19,6K       72K       NaN
# 26                  210         NaN       NaN        58
# 27                  -17         396       -18       -02
# 28                  -05        -389       -18         0
# 29                  567          19       322       975
# 30                  -15         395       -13         0
# 31                 2018        2016      2019      2018
# 32                  NaN         NaN     86,3K       NaN
# 33                  NaN         NaN        15       NaN
# 34                    0           0         0       213
# 35                53,4K         504       41K     2,23K
# 36                 2018        2016      2019      2018
# 37                   73          -5       257    -1,52K
# 38                  317        -982       946      -915
# 39                   18         -18       305      -892
# 40                 161K        -339     55,4K    -9,86K
# 41                  695         -34       368    -7,36K
# 42                 2018        2016      2019      2018
# 43                 137K         NaN       NaN       NaN
# 44                  591           0         0         0
# 45                4,79K         157        77       NaN
# 46                  NaN         NaN       NaN       NaN
#
#    2021_opensourcepolitics 2020_opensourcepolitics 2019_opensourcepolitics  \
# 0                    1,33M                    824K                    433K
# 1                    1,34M                    686K                    433K
# 2                     277K                    205K                   65,9K
# 3                     284K                    188K                   64,2K
# 4                     235K                    154K                   60,2K
# 5                     2021                    2020                    2019
# 6                      614                     905                      67
# 7                      101                     832                     100
# 8                      208                     249                     152
# 9                      213                     228                     148
# 10                    2021                    2020                    2019
# 11                   66,7K                   47,9K                    -27K
# 12                    266K                    269K                    121K
# 13                   -199K                   -221K                   -148K
# 14                     183                     212                    -228
# 15                     729                     119                     102
# 16                    -546                    -979                    -125
# 17                     811                     123                     106
# 18                     357                     188                     153
# 19                       0                       0                       0
# 20                    2021                    2020                    2019
# 21                    243K                    171K                   61,8K
# 22                     182                     207                     143
# 23                    439K                    259K                    115K
# 24                      66                      54                     -43
# 25                    372K                    211K                    142K
# 26                     NaN                     NaN                     NaN
# 27                     -15                     -12                     -23
# 28                     -08                     -08                     -12
# 29                     635                     536                     429
# 30                     -13                      -1                     -22
# 31                    2021                    2020                    2019
# 32                     NaN                     NaN                     NaN
# 33                     NaN                     NaN                     NaN
# 34                     -01                     -01                       0
# 35                    477K                    270K                    116K
# 36                    2021                    2020                    2019
# 37                     177                     186                     139
# 38                     494                     569                     517
# 39                     314                     305                     222
# 40                   1,03M                    658K                    326K
# 41                     771                     798                     754
# 42                    2021                    2020                    2019
# 43                    793K                    462K                    279K
# 44                     596                     561                     644
# 45                   7,03K                   4,05K                   1,62K
# 46                    160K                    123K                     NaN
#
#    2018_opensourcepolitics
# 0                     259K
# 1                     259K
# 2                    17,2K
# 3                    15,4K
# 4                    14,3K
# 5                     2018
# 6                      442
# 7                      100
# 8                       66
# 9                       59
# 10                    2018
# 11                   19,4K
# 12                   32,9K
# 13                  -13,4K
# 14                     274
# 15                     463
# 16                    -189
# 17                     676
# 18                     446
# 19                       0
# 20                    2018
# 21                   16,1K
# 22                      62
# 23                   54,1K
# 24                      28
# 25                   34,7K
# 26                     NaN
# 27                     -22
# 28                     -06
# 29                     565
# 30                      -2
# 31                    2018
# 32                     NaN
# 33                     NaN
# 34                     -01
# 35                   56,2K
# 36                    2018
# 37                      55
# 38                     254
# 39                     144
# 40                    135K
# 41                     523
# 42                    2018
# 43                    125K
# 44                     484
# 45                   1,16K
# 46                     NaN
#
# [47 rows x 75 columns]

# %%
finance_df2= (finance_df.set_index("Performance").T)

# %%
finance_df2.reset_index(inplace=True)

# %%
finance_df2.columns
# Out:
# Index(['index', 'Chiffre d'affaires (€)', 'Marge brute (€)',
#        'EBITDA - EBE (€)', 'Résultat d'exploitation (€)', 'Résultat net (€)',
#        'Croissance', 'Taux de croissance du CA (%)', 'Taux de marge brute (%)',
#        'Taux de marge d'EBITDA (%)', 'Taux de marge opérationnelle (%)',
#        'Gestion BFR', 'BFR (€)', 'BFR exploitation (€)',
#        'BFR hors exploitation (€)', 'BFR (j de CA)',
#        'BFR exploitation (j de CA)', 'BFR hors exploitation (j de CA)',
#        'Délai de paiement clients (j)', 'Délai de paiement fournisseurs (j)',
#        'Ratio des stocks / CA (j)', 'Autonomie financière',
#        'Capacité d'autofinancement (€)', 'Capacité d'autofinancement / CA (%)',
#        'Fonds de roulement net global (€)', 'Couverture du BFR',
#        'Trésorerie (€)', 'Dettes financières (€)', 'Capacité de remboursement',
#        'Ratio d'endettement (Gearing)', 'Autonomie financière (%)',
#        'Taux de levier (DFN/EBITDA)', 'Solvabilité',
#        'Etat des dettes à 1 an au plus (€)', 'Liquidité générale',
#        'Couverture des dettes', 'Fonds propres (€)', 'Rentabilité',
#        'Marge nette (%)', 'Rentabilité sur fonds propres (%)',
#        'Rentabilité économique (%)', 'Valeur ajoutée (€)',
#        'Valeur ajoutée / CA (%)', 'Structure d'activité',
#        'Salaires et charges sociales (€)', 'Salaires / CA (%)',
#        'Impôts et taxes (€)', 'Chiffre d'affaires à l'export (€)'],
#       dtype='object', name='Performance')

# %%
import inflection
import re
new_col_names=[]
for i in list(finance_df2.columns):
    i=i.lower().replace(' de', '_').replace(' du', '_').replace("'", '').replace(' ', '_').replace('é', 'e').replace('(€)','e').replace('(%)','pc').replace('/','sur').replace('à', 'a').replace('è', 'e').replace('(', '').replace(')', '').replace('ô', 'o').replace('__', '_').replace('s_t', 'surdet')
    new_col_names.append(inflection.underscore(i))
print(new_col_names)
# Out:
# ['index', 'chiffre_daffaires_e', 'marge_brute_e', 'ebitda___ebe_e', 'resultat_dexploitation_e', 'resultat_net_e', 'croissance', 'taux_croissance_ca_pc', 'taux_marge_brute_pc', 'taux_marge_debitda_pc', 'taux_marge_operationnelle_pc', 'gestion_bfr', 'bfr_e', 'bfr_exploitation_e', 'bfr_hors_exploitation_e', 'bfr_j_ca', 'bfr_exploitation_j_ca', 'bfr_hors_exploitation_j_ca', 'delai_paiement_clients_j', 'delai_paiement_fournisseurs_j', 'ratio_s_stocks_sur_ca_j', 'autonomie_financiere', 'capacite_dautofinancement_e', 'capacite_dautofinancement_sur_ca_pc', 'fonds_roulement_net_global_e', 'couverture_bfr', 'tresorerie_e', 'dettes_financieres_e', 'capacite_remboursement', 'ratio_dendettement_gearing', 'autonomie_financiere_pc', 'taux_levier_dfnsurebitda', 'solvabilite', 'etat_surdettes_a_1_an_au_plus_e', 'liquidite_generale', 'couverture_surdettes', 'fonds_propres_e', 'rentabilite', 'marge_nette_pc', 'rentabilite_sur_fonds_propres_pc', 'rentabilite_economique_pc', 'valeur_ajoutee_e', 'valeur_ajoutee_sur_ca_pc', 'structure_dactivite', 'salaires_et_charges_sociales_e', 'salaires_sur_ca_pc', 'impots_et_taxes_e', 'chiffre_daffaires_a_lexport_e']

# %%
finance_df2.columns= new_col_names

# %%
finance_df2.head()
# Out:
#            index chiffre_daffaires_e marge_brute_e ebitda___ebe_e  \
# 0  2017_citility                 NaN           NaN            NaN
# 1  2016_citility               30,7K          527K          -295K
# 2  2019_voxcracy               46,3K         46,3K         -31,5K
# 3  2018_voxcracy               16,7K          157K          -123K
# 4  2017_voxcracy               1,74K         75,9K         -24,4K
#
#   resultat_dexploitation_e resultat_net_e croissance taux_croissance_ca_pc  \
# 0                      NaN          -562K       2017                   NaN
# 1                    -296K          -238K       2016                     4
# 2                   -38,5K           -39K       2019                   177
# 3                    -130K          -112K       2018                   861
# 4                   -30,3K         -23,4K       2017                   NaN
#
#   taux_marge_brute_pc taux_marge_debitda_pc  ... marge_nette_pc  \
# 0                 NaN                   NaN  ...            NaN
# 1               1,72K                  -961  ...           -775
# 2                 100                  -682  ...           -842
# 3                 940                  -734  ...           -668
# 4               4,36K                 -1,4K  ...         -1,35K
#
#   rentabilite_sur_fonds_propres_pc rentabilite_economique_pc valeur_ajoutee_e  \
# 0                              NaN                       NaN              NaN
# 1                             -623                      -173             351K
# 2                              -76                       -63            2,17K
# 3                             -202                      -169             -21K
# 4                              -41                       -39           -5,04K
#
#   valeur_ajoutee_sur_ca_pc structure_dactivite salaires_et_charges_sociales_e  \
# 0                      NaN                2017                            NaN
# 1                    1,14K                2016                           636K
# 2                       47                2019                          33,6K
# 3                     -126                2018                           101K
# 4                     -290                2017                          19,1K
#
#   salaires_sur_ca_pc impots_et_taxes_e chiffre_daffaires_a_lexport_e
# 0                NaN               NaN                           NaN
# 1              2,07K             9,16K                           NaN
# 2                725               137                           NaN
# 3                602             1,12K                            5K
# 4               1,1K               329                           NaN
#
# [5 rows x 48 columns]

# %%
import re

def fix_columns(x):
    x=str(x)
    if x== 'nan':
        return 0
    elif 'K' in x:
        if ',' in x:
            return int(re.split('[,K]', x)[0]+re.split('[,K]', x)[1]+'0'*(3-len(re.split('[,K]', x)[1])))
        else:
            return int(x.replace('K', '000'))
    elif 'M' in x:
        if ',' in x:
            return int(re.split('[,M]', x)[0]+re.split('[,M]', x)[1]+'0'*(6-len(re.split('[,M]', x)[1])))
        else:
            return int(x.replace('M', '000'))
    else:
        return x

# %%
# to test the function on one series 
# finance_df2['chiffre_daffaires_e'].apply(fix_columns)

# %%
finance_df2.set_index("index", inplace=True)

# %%
for i in list(finance_df2.columns)[0:]: 
    finance_df2[i]= finance_df2[i].apply(fix_columns)

# %%
#### NEW COLUMN NAME 
# finance_df2=finance_df2.apply(pd.to_numeric).reset_index()

# %%
finance_df2.dtypes
# Out:
# index                                   object
# chiffre_daffaires_e                    float64
# marge_brute_e                            int64
# ebitda___ebe_e                           int64
# resultat_dexploitation_e                 int64
# resultat_net_e                           int64
# croissance                             float64
# taux_croissance_ca_pc                    int64
# taux_marge_brute_pc                      int64
# taux_marge_debitda_pc                    int64
# taux_marge_operationnelle_pc             int64
# gestion_bfr                            float64
# bfr_e                                    int64
# bfr_exploitation_e                       int64
# bfr_hors_exploitation_e                  int64
# bfr_j_ca                                 int64
# bfr_exploitation_j_ca                    int64
# bfr_hors_exploitation_j_ca               int64
# delai_paiement_clients_j                 int64
# delai_paiement_fournisseurs_j            int64
# ratio_s_stocks_sur_ca_j                  int64
# autonomie_financiere                   float64
# capacite_dautofinancement_e              int64
# capacite_dautofinancement_sur_ca_pc      int64
# fonds_roulement_net_global_e             int64
# couverture_bfr                           int64
# tresorerie_e                             int64
# dettes_financieres_e                     int64
# capacite_remboursement                   int64
# ratio_dendettement_gearing               int64
# autonomie_financiere_pc                  int64
# taux_levier_dfnsurebitda                 int64
# solvabilite                            float64
# etat_surdettes_a_1_an_au_plus_e          int64
# liquidite_generale                       int64
# couverture_surdettes                     int64
# fonds_propres_e                          int64
# rentabilite                            float64
# marge_nette_pc                           int64
# rentabilite_sur_fonds_propres_pc         int64
# rentabilite_economique_pc                int64
# valeur_ajoutee_e                         int64
# valeur_ajoutee_sur_ca_pc                 int64
# structure_dactivite                    float64
# salaires_et_charges_sociales_e           int64
# salaires_sur_ca_pc                       int64
# impots_et_taxes_e                        int64
# chiffre_daffaires_a_lexport_e            int64
# dtype: object

# %%
finance_df2.head(10)
# Out:
#       index  chiffre_daffaires_e  marge_brute_e  ebitda___ebe_e  \
# 0  citility                  0.0              0               0
# 1  citility              30700.0         527000         -295000
# 2  voxcracy              46300.0          46300          -31500
# 3  voxcracy              16700.0         157000         -123000
# 4  voxcracy               1740.0          75900          -24400
# 5  voxcracy                  0.0              0           -1080
# 6       LLL             473000.0         473000           24700
# 7       LLL             462000.0         462000          160000
# 8       LLL             300000.0         300000           89700
# 9       LLL                  0.0              0               0
#
#    resultat_dexploitation_e  resultat_net_e  croissance  \
# 0                         0         -562000      2017.0
# 1                   -296000         -238000      2016.0
# 2                    -38500          -39000      2019.0
# 3                   -130000         -112000      2018.0
# 4                    -30300          -23400      2017.0
# 5                     -4910           -4910      2016.0
# 6                    -42700          -44900      2020.0
# 7                     95200           62400      2019.0
# 8                     25900           19800      2018.0
# 9                         0               0      2017.0
#
#    taux_croissance_ca_pc  taux_marge_brute_pc  taux_marge_debitda_pc  ...  \
# 0                      0                    0                      0  ...
# 1                      4                 1720                   -961  ...
# 2                    177                  100                   -682  ...
# 3                    861                  940                   -734  ...
# 4                      0                 4360                  -1400  ...
# 5                      0                    0                      0  ...
# 6                     25                  100                     52  ...
# 7                    539                  100                    346  ...
# 8                      0                  100                    299  ...
# 9                      0                    0                      0  ...
#
#    marge_nette_pc  rentabilite_sur_fonds_propres_pc  \
# 0               0                                 0
# 1            -775                              -623
# 2            -842                               -76
# 3            -668                              -202
# 4           -1350                               -41
# 5               0                             -4420
# 6             -95                              -437
# 7             135                               423
# 8              66                               232
# 9               0                                 0
#
#    rentabilite_economique_pc  valeur_ajoutee_e  valeur_ajoutee_sur_ca_pc  \
# 0                          0                 0                         0
# 1                       -173            351000                      1140
# 2                        -63              2170                        47
# 3                       -169            -21000                      -126
# 4                        -39             -5040                      -290
# 5                       -177              -942                         0
# 6                        -37            136000                       287
# 7                         86            292000                       632
# 8                         38            175000                       584
# 9                          0                 0                         0
#
#    structure_dactivite  salaires_et_charges_sociales_e  salaires_sur_ca_pc  \
# 0               2017.0                               0                   0
# 1               2016.0                          636000                2070
# 2               2019.0                           33600                 725
# 3               2018.0                          101000                 602
# 4               2017.0                           19100                1100
# 5               2016.0                               0                   0
# 6               2020.0                           97100                 205
# 7               2019.0                          126000                 274
# 8               2018.0                           80200                 267
# 9               2017.0                               0                   0
#
#    impots_et_taxes_e  chiffre_daffaires_a_lexport_e
# 0                  0                              0
# 1               9160                              0
# 2                137                              0
# 3               1120                           5000
# 4                329                              0
# 5                140                              0
# 6              14200                              0
# 7               7350                              0
# 8               5220                              0
# 9                  0                              0
#
# [10 rows x 48 columns]

# %%
#finance_df2["company"]= 
#[re.split('_', str(finance_df2["index"]))][0]
def create_company_col(x):
    x=str(x)
    return x.split('_')[1]

# %%
finance_df2["index"]= finance_df2["index"].apply(create_company_col)

# %%
(finance_df.set_index("Performance").T).to_csv("companies_finance_data.csv", sep=';')
