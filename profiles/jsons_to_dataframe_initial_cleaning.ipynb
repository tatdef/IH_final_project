# %% [markdown]
# # Importing json profiles into a database

# %%
import pandas as pd
import json
import numpy as np

# %%
def create_profile(x):
    with open('jsons/'+str(x)) as f:
        dict1 = json.load(f)
    list_col= ['experience', 'education', 'languages']
    for n in list_col:
        if n in dict1:
            for i in range(len(dict1[n])): 
                dict1[str(n+str(i+1))]= dict1[n][i]
    data = pd.DataFrame.from_dict(dict1, orient='index').T
    return data

# %%
import os
file_list = [f for f in os.listdir('jsons') if f.endswith(".json")]
len(file_list)
# you can replace the list file_list by whatever list of jsons you want to import
# Out:
# 49

# %%
initial_profile=create_profile('brachetantoine.json')

# %%
list_profiles=file_list
profiles = initial_profile
for i in list_profiles:
    a= create_profile(i)
    profiles= pd.concat((profiles,a),axis=0)

# %%
profiles.reset_index()
# Out:
#     index                                            summary  \
# 0       0  Antoine croit à l’intelligence de tous et à la...
# 1       0  French Entrepreneur - Founder and Managing Par...
# 2       0  Inspired by the power we can build to change t...
# 3       0  Antoine croit à l’intelligence de tous et à la...
# 4       0  IT Consultant, Technical Expert, Lead develope...
# 5       0                                                NaN
# 6       0                                       People Power
# 7       0  16+ years of experience driving change in the ...
# 8       0                                                NaN
# 9       0  17 ans d'expérience, intelligence collective, ...
# 10      0  After eight years of social entrepreneurship i...
# 11      0  ⇒ Rendez-vous sur jerem.io pour télécharger mo...
# 12      0  Experienced Chief Executive Officer with a dem...
# 13      0                                                NaN
# 14      0  Drawing on 7 years of experience as a Team Lea...
# 15      0                                                NaN
# 16      0                                                NaN
# 17      0                                                NaN
# 18      0  Expert on democratic innovations and civic tec...
# 19      0  OpenGov : #transparence #participation #collab...
# 20      0  Président et co-fondateur de bluenove, société...
# 21      0  Througout my 12 years experience in start-up a...
# 22      0  IT Consultant, Trainer, Technical Expert, Lead...
# 23      0  Co-Founder & Co-President of bluenove Group, a...
# 24      0                                                NaN
# 25      0                                                NaN
# 26      0  Experienced head of development and chief of r...
# 27      0  As a product manager in a CivicTech startup, I...
# 28      0                                                NaN
# 29      0  Quelques infos  : \n \n- Le nombre de personne...
# 30      0  Polyvalent, committed, pragmatic and open-mind...
# 31      0  Experienced serial entrepreneur and engaged Ch...
# 32      0  1990-1999 : Procter & Gamble : Finance & Accou...
# 33      0                                                NaN
# 34      0                                                NaN
# 35      0                                                NaN
# 36      0                                                NaN
# 37      0  Journaliste, passée de la rédaction à l'éditio...
# 38      0  Curious, motivated and cheerful, I am particul...
# 39      0                                                NaN
# 40      0  Digital transformation, social innovation, dis...
# 41      0  Product Manager with 8 years of experience. Pa...
# 42      0  Graduated of Paris I Panthéon Sorbonne univers...
# 43      0  I'm co-founder of Fintech Billy, the platform ...
# 44      0         Consulting citizens has never been easier!
# 45      0  I'm a software engineer specialized in web tec...
# 46      0  Journaliste, biberonnée à la créativité chez K...
# 47      0                                                NaN
#
#                                      industryName        lastName student  \
# 0                   IT Services and IT Consulting         Brachet   False
# 1   Venture Capital and Private Equity Principals           Demri   False
# 2                  Civic and Social Organizations         Durieux   False
# 3                   IT Services and IT Consulting         Brachet   False
# 4                   IT Services and IT Consulting         Jaillot   False
# 5                   IT Services and IT Consulting        Vanneroy   False
# 6                  Civic and Social Organizations         DEMBELE   False
# 7                   IT Services and IT Consulting      de Pimodan   False
# 8                        Non-profit Organizations          Rosado   False
# 9                   IT Services and IT Consulting         Barbier   False
# 10                 Civic and Social Organizations           Pahud   False
# 11           Technology, Information and Internet           Paret   False
# 12                   Online Audio and Video Media   de Roquefeuil   False
# 13                           Advertising Services      LECOURTOIS   False
# 14                  IT Services and IT Consulting             AMI   False
# 15           Technology, Information and Internet    Schlumberger   False
# 16           Technology, Information and Internet          Combaz   False
# 17                             Financial Services            Snow   False
# 18                          Public Policy Offices          Chaput   False
# 19                          Public Policy Offices            Lage   False
# 20               Business Consulting and Services        Escoubes   False
# 21           Technology, Information and Internet            Pons   False
# 22           Technology, Information and Internet           Lacot   False
# 23               Business Consulting and Services           Duval   False
# 24                          Public Policy Offices        Gaboriau   False
# 25           Technology, Information and Internet       Vignolles   False
# 26                   Online Audio and Video Media  McGrath-Dehecq   False
# 27                  IT Services and IT Consulting       Le Botlan   False
# 28                                 Graphic Design           Patte   False
# 29             Professional Training and Coaching       Pelissard   False
# 30                 Civic and Social Organizations         Colombe   False
# 31                 Civic and Social Organizations         Dauchez   False
# 32                          Public Policy Offices          TEULIÉ   False
# 33                                    Photography          Cochin   False
# 34                  IT Services and IT Consulting        Buchotte   False
# 35                            Retail Art Supplies      Deffrennes   False
# 36           Technology, Information and Internet           Albet   False
# 37                 Civic and Social Organizations          Vaturi   False
# 38           Technology, Information and Internet        Bessoles   False
# 39                             Marketing Services         Canivet   False
# 40                 Civic and Social Organizations        Le Masne   False
# 41           Technology, Information and Internet         Deville   False
# 42                 Civic and Social Organizations     des Gachons   False
# 43                           Software Development        Arrouard   False
# 44                  IT Services and IT Consulting        de Briey   False
# 45                  IT Services and IT Consulting           Meiss   False
# 46                   Online Audio and Video Media         Richard   False
# 47                          Public Policy Offices     Dernoncourt   False
#
#    geoCountryName            geoCountryUrn geoLocationBackfilled    elt  \
# 0          France  urn:li:fs_geo:105015875                 False  False
# 1          France  urn:li:fs_geo:105015875                 False  False
# 2          France  urn:li:fs_geo:105015875                 False  False
# 3          France  urn:li:fs_geo:105015875                 False  False
# 4          France  urn:li:fs_geo:105015875                 False  False
# 5          France  urn:li:fs_geo:105015875                 False  False
# 6          France  urn:li:fs_geo:105015875                 False  False
# 7          France  urn:li:fs_geo:105015875                 False  False
# 8          France  urn:li:fs_geo:105015875                 False  False
# 9          France  urn:li:fs_geo:105015875                 False  False
# 10        Germany  urn:li:fs_geo:101282230                 False  False
# 11         France  urn:li:fs_geo:105015875                 False  False
# 12         France  urn:li:fs_geo:105015875                 False  False
# 13         France  urn:li:fs_geo:105015875                 False  False
# 14        Germany  urn:li:fs_geo:101282230                 False  False
# 15         France  urn:li:fs_geo:105015875                 False  False
# 16        Germany  urn:li:fs_geo:101282230                 False  False
# 17        Germany  urn:li:fs_geo:101282230                 False  False
# 18         France  urn:li:fs_geo:105015875                 False  False
# 19         France  urn:li:fs_geo:105015875                 False  False
# 20         France  urn:li:fs_geo:105015875                 False  False
# 21            NaN                      NaN                 False  False
# 22         France  urn:li:fs_geo:105015875                 False  False
# 23         France  urn:li:fs_geo:105015875                 False  False
# 24         France  urn:li:fs_geo:105015875                 False  False
# 25         France  urn:li:fs_geo:105015875                 False  False
# 26         France  urn:li:fs_geo:105015875                 False  False
# 27        Germany  urn:li:fs_geo:101282230                 False  False
# 28         France  urn:li:fs_geo:105015875                 False  False
# 29            NaN                      NaN                 False  False
# 30         France  urn:li:fs_geo:105015875                 False  False
# 31         France  urn:li:fs_geo:105015875                 False  False
# 32         France  urn:li:fs_geo:105015875                 False  False
# 33         France  urn:li:fs_geo:105015875                 False  False
# 34         France  urn:li:fs_geo:105015875                 False  False
# 35         France  urn:li:fs_geo:105015875                 False  False
# 36         France  urn:li:fs_geo:105015875                 False  False
# 37         France  urn:li:fs_geo:105015875                 False  False
# 38         France  urn:li:fs_geo:105015875                 False  False
# 39         France  urn:li:fs_geo:105015875                 False  False
# 40        Germany  urn:li:fs_geo:101282230                 False  False
# 41         France  urn:li:fs_geo:105015875                 False  False
# 42         France  urn:li:fs_geo:105015875                 False  False
# 43         France  urn:li:fs_geo:105015875                 False  False
# 44        Belgium  urn:li:fs_geo:100565514                 False  False
# 45         France  urn:li:fs_geo:105015875                 False  False
# 46         France  urn:li:fs_geo:105015875                 False  False
# 47         France  urn:li:fs_geo:105015875                 False  False
#
#                 industryUrn  ...  \
# 0     urn:li:fs_industry:96  ...
# 1    urn:li:fs_industry:106  ...
# 2     urn:li:fs_industry:90  ...
# 3     urn:li:fs_industry:96  ...
# 4     urn:li:fs_industry:96  ...
# 5     urn:li:fs_industry:96  ...
# 6     urn:li:fs_industry:90  ...
# 7     urn:li:fs_industry:96  ...
# 8    urn:li:fs_industry:100  ...
# 9     urn:li:fs_industry:96  ...
# 10    urn:li:fs_industry:90  ...
# 11     urn:li:fs_industry:6  ...
# 12   urn:li:fs_industry:113  ...
# 13    urn:li:fs_industry:80  ...
# 14    urn:li:fs_industry:96  ...
# 15     urn:li:fs_industry:6  ...
# 16     urn:li:fs_industry:6  ...
# 17    urn:li:fs_industry:43  ...
# 18    urn:li:fs_industry:79  ...
# 19    urn:li:fs_industry:79  ...
# 20    urn:li:fs_industry:11  ...
# 21     urn:li:fs_industry:6  ...
# 22     urn:li:fs_industry:6  ...
# 23    urn:li:fs_industry:11  ...
# 24    urn:li:fs_industry:79  ...
# 25     urn:li:fs_industry:6  ...
# 26   urn:li:fs_industry:113  ...
# 27    urn:li:fs_industry:96  ...
# 28   urn:li:fs_industry:140  ...
# 29   urn:li:fs_industry:105  ...
# 30    urn:li:fs_industry:90  ...
# 31    urn:li:fs_industry:90  ...
# 32    urn:li:fs_industry:79  ...
# 33   urn:li:fs_industry:136  ...
# 34    urn:li:fs_industry:96  ...
# 35   urn:li:fs_industry:111  ...
# 36     urn:li:fs_industry:6  ...
# 37    urn:li:fs_industry:90  ...
# 38     urn:li:fs_industry:6  ...
# 39  urn:li:fs_industry:1862  ...
# 40    urn:li:fs_industry:90  ...
# 41     urn:li:fs_industry:6  ...
# 42    urn:li:fs_industry:90  ...
# 43     urn:li:fs_industry:4  ...
# 44    urn:li:fs_industry:96  ...
# 45    urn:li:fs_industry:96  ...
# 46   urn:li:fs_industry:113  ...
# 47    urn:li:fs_industry:79  ...
#
#                                            languages1  \
# 0   {'name': 'English', 'proficiency': 'FULL_PROFE...
# 1                                                 NaN
# 2   {'name': 'Anglais', 'proficiency': 'NATIVE_OR_...
# 3   {'name': 'English', 'proficiency': 'FULL_PROFE...
# 4                                 {'name': 'Anglais'}
# 5                                                 NaN
# 6   {'name': 'Anglais', 'proficiency': 'FULL_PROFE...
# 7   {'name': 'Arabic', 'proficiency': 'LIMITED_WOR...
# 8   {'name': 'Anglais', 'proficiency': 'PROFESSION...
# 9                                                 NaN
# 10  {'name': 'Chinese', 'proficiency': 'PROFESSION...
# 11  {'name': 'English', 'proficiency': 'FULL_PROFE...
# 12  {'name': 'English', 'proficiency': 'NATIVE_OR_...
# 13                                                NaN
# 14                                                NaN
# 15  {'name': 'Allemand', 'proficiency': 'LIMITED_W...
# 16                                                NaN
# 17                                                NaN
# 18  {'name': 'Anglais', 'proficiency': 'PROFESSION...
# 19                                                NaN
# 20                                                NaN
# 21  {'name': 'English', 'proficiency': 'FULL_PROFE...
# 22  {'name': 'English', 'proficiency': 'FULL_PROFE...
# 23                                                NaN
# 24  {'name': 'Allemand', 'proficiency': 'PROFESSIO...
# 25  {'name': 'Allemand', 'proficiency': 'ELEMENTARY'}
# 26  {'name': 'Allemand', 'proficiency': 'LIMITED_W...
# 27  {'name': 'Allemand', 'proficiency': 'LIMITED_W...
# 28  {'name': 'Anglais', 'proficiency': 'FULL_PROFE...
# 29                                {'name': 'English'}
# 30                               {'name': 'Allemand'}
# 31                                                NaN
# 32                                {'name': 'Spanish'}
# 33  {'name': 'Anglais', 'proficiency': 'FULL_PROFE...
# 34                                                NaN
# 35  {'name': 'Allemand', 'proficiency': 'ELEMENTARY'}
# 36  {'name': 'Anglais', 'proficiency': 'FULL_PROFE...
# 37  {'name': 'Anglais', 'proficiency': 'NATIVE_OR_...
# 38  {'name': 'Anglais', 'proficiency': 'FULL_PROFE...
# 39                                                NaN
# 40     {'name': 'Czech', 'proficiency': 'ELEMENTARY'}
# 41  {'name': 'Anglais (Toefl IBT 103)', 'proficien...
# 42                                                NaN
# 43  {'name': 'Allemand', 'proficiency': 'LIMITED_W...
# 44  {'name': 'Anglais', 'proficiency': 'FULL_PROFE...
# 45  {'name': 'English', 'proficiency': 'PROFESSION...
# 46  {'name': 'Anglais', 'proficiency': 'FULL_PROFE...
# 47                                                NaN
#
#                                            languages2  \
# 0   {'name': 'French', 'proficiency': 'NATIVE_OR_B...
# 1                                                 NaN
# 2                                {'name': 'Espagnol'}
# 3   {'name': 'French', 'proficiency': 'NATIVE_OR_B...
# 4                                                 NaN
# 5                                                 NaN
# 6   {'name': 'Espagnol', 'proficiency': 'LIMITED_W...
# 7                                 {'name': 'English'}
# 8   {'name': 'Français', 'proficiency': 'NATIVE_OR...
# 9                                                 NaN
# 10  {'name': 'English', 'proficiency': 'FULL_PROFE...
# 11  {'name': 'French', 'proficiency': 'NATIVE_OR_B...
# 12  {'name': 'French', 'proficiency': 'NATIVE_OR_B...
# 13                                                NaN
# 14                                                NaN
# 15  {'name': 'Anglais', 'proficiency': 'FULL_PROFE...
# 16                                                NaN
# 17                                                NaN
# 18  {'name': 'Chinois', 'proficiency': 'LIMITED_WO...
# 19                                                NaN
# 20                                                NaN
# 21  {'name': 'French', 'proficiency': 'NATIVE_OR_B...
# 22  {'name': 'French', 'proficiency': 'NATIVE_OR_B...
# 23                                                NaN
# 24  {'name': 'Anglais', 'proficiency': 'NATIVE_OR_...
# 25  {'name': 'Anglais', 'proficiency': 'PROFESSION...
# 26  {'name': 'Anglais', 'proficiency': 'NATIVE_OR_...
# 27  {'name': 'Anglais', 'proficiency': 'FULL_PROFE...
# 28  {'name': 'Espagnol', 'proficiency': 'ELEMENTARY'}
# 29                                                NaN
# 30                                {'name': 'Anglais'}
# 31                                                NaN
# 32                                                NaN
# 33  {'name': 'Arabe (Egypte)', 'proficiency': 'LIM...
# 34                                                NaN
# 35  {'name': 'Anglais', 'proficiency': 'FULL_PROFE...
# 36  {'name': 'Espagnol', 'proficiency': 'FULL_PROF...
# 37  {'name': 'Espagnol', 'proficiency': 'LIMITED_W...
# 38  {'name': 'Espagnol', 'proficiency': 'NATIVE_OR...
# 39                                                NaN
# 40  {'name': 'English', 'proficiency': 'NATIVE_OR_...
# 41  {'name': 'Espagnol', 'proficiency': 'NATIVE_OR...
# 42                                                NaN
# 43  {'name': 'Anglais', 'proficiency': 'PROFESSION...
# 44  {'name': 'Espagnol', 'proficiency': 'PROFESSIO...
# 45  {'name': 'French', 'proficiency': 'NATIVE_OR_B...
# 46  {'name': 'Espagnol', 'proficiency': 'FULL_PROF...
# 47                                                NaN
#
#                                            languages3 locationName  \
# 0     {'name': 'German', 'proficiency': 'ELEMENTARY'}          NaN
# 1                                                 NaN       France
# 2                                 {'name': 'Italien'}       France
# 3     {'name': 'German', 'proficiency': 'ELEMENTARY'}          NaN
# 4                                                 NaN       France
# 5                                                 NaN       France
# 6   {'name': 'Français', 'proficiency': 'NATIVE_OR...       France
# 7   {'name': 'French', 'proficiency': 'NATIVE_OR_B...       France
# 8                                                 NaN       France
# 9                                                 NaN       France
# 10  {'name': 'French', 'proficiency': 'NATIVE_OR_B...      Germany
# 11                                                NaN       France
# 12  {'name': 'Spanish', 'proficiency': 'NATIVE_OR_...       France
# 13                                                NaN       France
# 14                                                NaN      Germany
# 15  {'name': 'Français', 'proficiency': 'NATIVE_OR...       France
# 16                                                NaN      Germany
# 17                                                NaN      Germany
# 18  {'name': 'Français', 'proficiency': 'NATIVE_OR...       France
# 19                                                NaN       France
# 20                                                NaN       France
# 21   {'name': 'Spanish', 'proficiency': 'ELEMENTARY'}        Other
# 22  {'name': 'German', 'proficiency': 'PROFESSIONA...       France
# 23                                                NaN       France
# 24  {'name': 'Catalan', 'proficiency': 'LIMITED_WO...       France
# 25  {'name': 'Italien', 'proficiency': 'LIMITED_WO...       France
# 26  {'name': 'Espagnol', 'proficiency': 'PROFESSIO...       France
# 27  {'name': 'Français', 'proficiency': 'NATIVE_OR...      Germany
# 28  {'name': 'Français', 'proficiency': 'NATIVE_OR...       France
# 29                                                NaN        Other
# 30                                                NaN       France
# 31                                                NaN       France
# 32                                                NaN       France
# 33  {'name': 'Arabe (Tunisie)', 'proficiency': 'LI...       France
# 34                                                NaN          NaN
# 35  {'name': 'Espagnol', 'proficiency': 'ELEMENTARY'}       France
# 36  {'name': 'Portugais', 'proficiency': 'FULL_PRO...       France
# 37                                                NaN       France
# 38  {'name': 'Français', 'proficiency': 'NATIVE_OR...       France
# 39                                                NaN       France
# 40  {'name': 'French', 'proficiency': 'NATIVE_OR_B...      Germany
# 41  {'name': 'Français', 'proficiency': 'NATIVE_OR...       France
# 42                                                NaN       France
# 43                                                NaN       France
# 44  {'name': 'Français', 'proficiency': 'NATIVE_OR...      Belgium
# 45  {'name': 'Spanish', 'proficiency': 'LIMITED_WO...       France
# 46  {'name': 'Mandarin', 'proficiency': 'ELEMENTARY'}       France
# 47                                                NaN       France
#
#                                  birthDate  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# 5                                      NaN
# 6                   {'month': 3, 'day': 7}
# 7                                      NaN
# 8                                      NaN
# 9    {'month': 7, 'year': 1982, 'day': 27}
# 10   {'month': 2, 'year': 1980, 'day': 29}
# 11                                     NaN
# 12                                     NaN
# 13    {'month': 2, 'year': 1984, 'day': 8}
# 14                                     NaN
# 15                  {'month': 4, 'day': 5}
# 16                                     NaN
# 17                 {'month': 9, 'day': 14}
# 18    {'month': 8, 'year': 1987, 'day': 3}
# 19  {'month': 10, 'year': 1976, 'day': 23}
# 20                                     NaN
# 21                                     NaN
# 22                  {'month': 1, 'day': 2}
# 23                                     NaN
# 24                                     NaN
# 25                                     NaN
# 26                                     NaN
# 27                                     NaN
# 28  {'month': 12, 'year': 1971, 'day': 20}
# 29                                     NaN
# 30                                     NaN
# 31                                     NaN
# 32                 {'month': 4, 'day': 19}
# 33                                     NaN
# 34                                     NaN
# 35                                     NaN
# 36                                     NaN
# 37                                     NaN
# 38                                     NaN
# 39                 {'month': 5, 'day': 23}
# 40                                     NaN
# 41                                     NaN
# 42                                     NaN
# 43    {'month': 7, 'year': 1986, 'day': 2}
# 44                                     NaN
# 45                                     NaN
# 46                                     NaN
# 47                                     NaN
#
#                                            languages4              address  \
# 0                                                 NaN                  NaN
# 1                                                 NaN                  NaN
# 2                                                 NaN                  NaN
# 3                                                 NaN                  NaN
# 4                                                 NaN                  NaN
# 5                                                 NaN                  NaN
# 6      {'name': 'Hindi', 'proficiency': 'ELEMENTARY'}                  NaN
# 7   {'name': 'Spanish', 'proficiency': 'LIMITED_WO...                  NaN
# 8                                                 NaN                  NaN
# 9                                                 NaN                  NaN
# 10  {'name': 'German', 'proficiency': 'LIMITED_WOR...  chloe@civocracy.org
# 11                                                NaN                  NaN
# 12                                                NaN                  NaN
# 13                                                NaN                  NaN
# 14                                                NaN                  NaN
# 15                                                NaN                  NaN
# 16                                                NaN                  NaN
# 17                                                NaN                  NaN
# 18                                                NaN                  NaN
# 19                                                NaN                  NaN
# 20                                                NaN                  NaN
# 21                                                NaN                  NaN
# 22                                                NaN                  NaN
# 23                                                NaN                  NaN
# 24  {'name': 'Espagnol', 'proficiency': 'PROFESSIO...                  NaN
# 25                                                NaN                  NaN
# 26  {'name': 'Français', 'proficiency': 'NATIVE_OR...                  NaN
# 27                                                NaN                  NaN
# 28  {'name': 'Polonais', 'proficiency': 'ELEMENTARY'}                  NaN
# 29                                                NaN                  NaN
# 30                                                NaN                  NaN
# 31                                                NaN                  NaN
# 32                                                NaN                  NaN
# 33  {'name': 'Arabe Moderne Standar', 'proficiency...                  NaN
# 34                                                NaN                  NaN
# 35  {'name': 'Français', 'proficiency': 'NATIVE_OR...                  NaN
# 36                                                NaN                  NaN
# 37                                                NaN                  NaN
# 38                                                NaN                  NaN
# 39                                                NaN                  NaN
# 40  {'name': 'German', 'proficiency': 'FULL_PROFES...                  NaN
# 41  {'name': 'Portugais', 'proficiency': 'LIMITED_...                  NaN
# 42                                                NaN                  NaN
# 43                                                NaN                  NaN
# 44  {'name': 'Néerlandais', 'proficiency': 'NATIVE...                  NaN
# 45                                                NaN                  NaN
# 46                                                NaN                  NaN
# 47                                                NaN                  NaN
#
#                                            languages5  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10   {'name': 'Italian', 'proficiency': 'ELEMENTARY'}
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24  {'name': 'Français', 'proficiency': 'NATIVE_OR...
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33  {'name': 'Espagnol', 'proficiency': 'FULL_PROF...
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
#
#                                            languages6  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10   {'name': 'Spanish', 'proficiency': 'ELEMENTARY'}
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24   {'name': 'Italien', 'proficiency': 'ELEMENTARY'}
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33  {'name': 'Français', 'proficiency': 'NATIVE_OR...
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
#
#                                           languages7
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
# 10                                               NaN
# 11                                               NaN
# 12                                               NaN
# 13                                               NaN
# 14                                               NaN
# 15                                               NaN
# 16                                               NaN
# 17                                               NaN
# 18                                               NaN
# 19                                               NaN
# 20                                               NaN
# 21                                               NaN
# 22                                               NaN
# 23                                               NaN
# 24                                               NaN
# 25                                               NaN
# 26                                               NaN
# 27                                               NaN
# 28                                               NaN
# 29                                               NaN
# 30                                               NaN
# 31                                               NaN
# 32                                               NaN
# 33  {'name': 'Italien', 'proficiency': 'ELEMENTARY'}
# 34                                               NaN
# 35                                               NaN
# 36                                               NaN
# 37                                               NaN
# 38                                               NaN
# 39                                               NaN
# 40                                               NaN
# 41                                               NaN
# 42                                               NaN
# 43                                               NaN
# 44                                               NaN
# 45                                               NaN
# 46                                               NaN
# 47                                               NaN
#
# [48 rows x 51 columns]

# %%
profiles_explo= profiles.copy()

# %% [markdown]
# # Initial cleaning

# %% [markdown]
# ### dropping useless columns and duplicates

# %%
pd.options.display.max_rows = 100
profiles_explo.describe().T

# total 48 rows

# ['profile_id'] = str : linkedin id - num and letters, 47 unique 
# ['lastName'] - full 
# ['firstName'] - full 
# ['geoCountryName'] = country name, 3 values, 46 filled
# ['geoLocationName'] = region name, 11 unique - check and recode 
# ['birthDate'] = 35 missing  

# ['summary'] = text, includes \n, 32 unique
# ['industryName'] = short text, full, 16 unique
# ['headline'] = professional headline, 47 unique 

# ['experience'] = liste de dictionnaires. chaque élément est accessible par [0], [1] - full 
# ['education'][0] = liste de dictionnaires - full 
# ['languages'] = list de dictionnaires - name, proficiency - 32 
# ['publications'] =  16 
# ['certifications'] = 11
# ['volunteer'] = 17 
# ['honors'] =  12
# ['projects'] =  22

# to drop : 
# displayPictureUrl', 'img_100_100', 'img_200_200', 'img_400_400', 'img_800_800',
# ['student'] = boolean T/F - only false 
# ['geoCountryUrn'] === CODED - internal LIn code 
# ['geoLocationBackfilled'] === boolean T/F - only false 
# ['elt'] === boolean T/F - only false 
# ['industryUrn'] === CODED (format urn:li:fs_industry:96) // to industryName 
# ['displayPictureUrl'] = url to picture (not accessible without linkedin )
# ['img_100_100', 'img_200_200', 'img_400_400', 'img_800_800'] = ref of image not accessible 
# ['profile_urn'] = str : format urn:li:fs_miniProfile:ACoAAAA615EBaNquQR5gOz_oFr9emeCr0ZNw67M 
# ['member_urn'] = str : format urn:li:member:3856273
# ['public_id'] = str : lastnamefirstname lower ()
# ['entityUrn'] === CODED (format urn:li:fs_profile:ACoAAAA615EBaNquQR5gOz_oFr9emeCr0ZNw67M)
# ['geoLocation']) === CODED, 12 unique 
# ['location'] === dictionary with one nested dictionary, country code - 4 unique 
# ['locationName'] = country name, 4 values (incl. other), 46 filled
# ['address'] = only 1 value (email)
# Out:
#                       count unique  \
# summary                  33     32
# industryName             48     16
# lastName                 48     47
# student                  48      1
# geoCountryName           46      3
# geoCountryUrn            46      3
# geoLocationBackfilled    48      1
# elt                      48      1
# industryUrn              48     16
# firstName                48     41
# entityUrn                48     47
# geoLocation              46     12
# geoLocationName          44     11
# location                 48      4
# headline                 48     47
# displayPictureUrl        47     46
# img_100_100              47     46
# img_200_200              47     46
# img_400_400              47     46
# img_800_800              47     46
# profile_id               48     47
# profile_urn              48     47
# member_urn               48     47
# public_id                48     47
# experience               48     47
# education                48     47
# languages                48     32
# publications             48     16
# certifications           48     11
# volunteer                48     17
# honors                   48     12
# projects                 48     22
# experience1              48     47
# experience2              48     47
# experience3              48     47
# experience4              46     45
# experience5              45     44
# education1               47     46
# education2               42     41
# education3               36     35
# languages1               33     17
# languages2               30     17
# languages3               25     15
# locationName             45      4
# birthDate                13     13
# languages4               11     10
# address                   1      1
# languages5                3      3
# languages6                3      3
# languages7                1      1
#
#                                                                      top freq
# summary                Antoine croit à l’intelligence de tous et à la...    2
# industryName                               IT Services and IT Consulting   11
# lastName                                                         Brachet    2
# student                                                            False   48
# geoCountryName                                                    France   39
# geoCountryUrn                                    urn:li:fs_geo:105015875   39
# geoLocationBackfilled                                              False   48
# elt                                                                False   48
# industryUrn                                        urn:li:fs_industry:96   11
# firstName                                                        Antoine    3
# entityUrn              urn:li:fs_profile:ACoAAAA615EBaNquQR5gOz_oFr9e...    2
# geoLocation                         {'geoUrn': 'urn:li:fs_geo:90009659'}   15
# geoLocationName                        Greater Paris Metropolitan Region   15
# location                        {'basicLocation': {'countryCode': 'fr'}}   39
# headline               Directeur associé de bluenove, initiateur du m...    2
# displayPictureUrl      https://media.licdn.com/dms/image/C4D03AQHqKKC...    2
# img_100_100            100_100/0/1533636584521?e=1691020800&v=beta&t=...    2
# img_200_200            200_200/0/1533636584521?e=1691020800&v=beta&t=...    2
# img_400_400            400_400/0/1533636584521?e=1691020800&v=beta&t=...    2
# img_800_800            800_800/0/1533636584521?e=1691020800&v=beta&t=...    2
# profile_id                       ACoAAAA615EBaNquQR5gOz_oFr9emeCr0ZNw67M    2
# profile_urn            urn:li:fs_miniProfile:ACoAAAA615EBaNquQR5gOz_o...    2
# member_urn                                         urn:li:member:3856273    2
# public_id                                                 brachetantoine    2
# experience             [{'locationName': 'Paris Area, France', 'entit...    2
# education              [{'entityUrn': 'urn:li:fs_education:(ACoAAAA61...    2
# languages                                                             []   15
# publications                                                          []   32
# certifications                                                        []   38
# volunteer                                                             []   32
# honors                                                                []   37
# projects                                                              []   27
# experience1            {'locationName': 'Paris Area, France', 'entity...    2
# experience2            {'entityUrn': 'urn:li:fs_position:(ACoAAAA615E...    2
# experience3            {'locationName': 'Paris', 'entityUrn': 'urn:li...    2
# experience4            {'locationName': 'Paris Area, France', 'entity...    2
# experience5            {'locationName': 'Paris', 'entityUrn': 'urn:li...    2
# education1             {'entityUrn': 'urn:li:fs_education:(ACoAAAA615...    2
# education2             {'entityUrn': 'urn:li:fs_education:(ACoAAAA615...    2
# education3             {'entityUrn': 'urn:li:fs_education:(ACoAAAA615...    2
# languages1             {'name': 'Anglais', 'proficiency': 'FULL_PROFE...    7
# languages2             {'name': 'French', 'proficiency': 'NATIVE_OR_B...    7
# languages3             {'name': 'Français', 'proficiency': 'NATIVE_OR...    8
# locationName                                                      France   36
# birthDate                                         {'month': 3, 'day': 7}    1
# languages4             {'name': 'Français', 'proficiency': 'NATIVE_OR...    2
# address                                              chloe@civocracy.org    1
# languages5              {'name': 'Italian', 'proficiency': 'ELEMENTARY'}    1
# languages6              {'name': 'Spanish', 'proficiency': 'ELEMENTARY'}    1
# languages7              {'name': 'Italien', 'proficiency': 'ELEMENTARY'}    1

# %%
profiles_explo.columns
# Out:
# Index(['summary', 'industryName', 'lastName', 'student', 'geoCountryName',
#        'geoCountryUrn', 'geoLocationBackfilled', 'elt', 'industryUrn',
#        'firstName', 'entityUrn', 'geoLocation', 'geoLocationName', 'location',
#        'headline', 'displayPictureUrl', 'img_100_100', 'img_200_200',
#        'img_400_400', 'img_800_800', 'profile_id', 'profile_urn', 'member_urn',
#        'public_id', 'experience', 'education', 'languages', 'publications',
#        'certifications', 'volunteer', 'honors', 'projects', 'experience1',
#        'experience2', 'experience3', 'experience4', 'experience5',
#        'education1', 'education2', 'education3', 'languages1', 'languages2',
#        'languages3', 'locationName', 'birthDate', 'languages4', 'address',
#        'languages5', 'languages6', 'languages7'],
#       dtype='object')

# %%
profiles_explo_2= profiles_explo[['profile_id', 'lastName', 'firstName', 'geoCountryName', 'geoLocationName', 'birthDate', 
                                  'summary', 'industryName', 'headline', 'experience', 'education', 
                                  'languages', 'publications', 'certifications', 'volunteer', 'honors', 'projects', 
                                  'experience1','experience2', 'experience3', 'experience4', 'experience5',
                                  'education1', 'education2', 'education3', 'languages1', 'languages2',
                                  'languages3','languages4', 'languages5', 'languages6', 'languages7']]

# %%
mask = profiles_explo_2.duplicated(subset=['profile_id'], keep='first')
dropped = profiles_explo_2.loc[mask]
dropped
# Out:
#                                 profile_id lastName firstName geoCountryName  \
# 0  ACoAAAA615EBaNquQR5gOz_oFr9emeCr0ZNw67M  Brachet   Antoine         France
#
#                      geoLocationName birthDate  \
# 0  Greater Paris Metropolitan Region       NaN
#
#                                              summary  \
# 0  Antoine croit à l’intelligence de tous et à la...
#
#                     industryName  \
# 0  IT Services and IT Consulting
#
#                                             headline  \
# 0  Directeur associé de bluenove, initiateur du m...
#
#                                           experience  ...  \
# 0  [{'locationName': 'Paris Area, France', 'entit...  ...
#
#                                           education1  \
# 0  {'entityUrn': 'urn:li:fs_education:(ACoAAAA615...
#
#                                           education2  \
# 0  {'entityUrn': 'urn:li:fs_education:(ACoAAAA615...
#
#                                           education3  \
# 0  {'entityUrn': 'urn:li:fs_education:(ACoAAAA615...
#
#                                           languages1  \
# 0  {'name': 'English', 'proficiency': 'FULL_PROFE...
#
#                                           languages2  \
# 0  {'name': 'French', 'proficiency': 'NATIVE_OR_B...
#
#                                         languages3 languages4 languages5  \
# 0  {'name': 'German', 'proficiency': 'ELEMENTARY'}        NaN        NaN
#
#   languages6 languages7
# 0        NaN        NaN
#
# [1 rows x 32 columns]

# %%
profiles_explo_2.drop_duplicates(subset=['profile_id'], keep='first', inplace=True)
# Out:
# /var/folders/5g/jskfzb8j377fh7wl3_rxvkrc0000gn/T/ipykernel_4701/3791079629.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   profiles_explo_2.drop_duplicates(subset=['profile_id'], keep='first', inplace=True)

# %% [markdown]
# ### Recoding the honors, publications, volunteer, projects, certifications and languages columns

# %%
profiles_explo_2.isna().sum().sort_values(ascending=False)
# we have 47 rows 
# we will drop the columns with more than 37 missing values
# for columns projects, publications, languages, certifications, and honors 
# we will create one column that states whether this section was filled
# and keep the detail in just the original column, as text.
# Out:
# languages7         46
# languages6         44
# languages5         44
# languages4         36
# birthDate          34
# languages3         23
# languages2         18
# summary            15
# languages1         15
# education3         12
# education2          6
# geoLocationName     4
# experience5         3
# geoCountryName      2
# experience4         2
# education1          1
# experience2         0
# experience3         0
# profile_id          0
# experience1         0
# lastName            0
# honors              0
# volunteer           0
# certifications      0
# publications        0
# languages           0
# education           0
# experience          0
# headline            0
# industryName        0
# firstName           0
# projects            0
# dtype: int64

# %%
#HONORS
profiles_explo_2['honors'] = (profiles_explo_2['honors']).astype(str)
profiles_explo_2['honors_stated']=np.where(profiles_explo_2['honors']=='[]', '0', '1')
profiles_explo_2['honors_stated'].value_counts()
# Out:
# /var/folders/5g/jskfzb8j377fh7wl3_rxvkrc0000gn/T/ipykernel_4701/1776863395.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   profiles_explo_2['honors'] = (profiles_explo_2['honors']).astype(str)
# /var/folders/5g/jskfzb8j377fh7wl3_rxvkrc0000gn/T/ipykernel_4701/1776863395.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   profiles_explo_2['honors_stated']=np.where(profiles_explo_2['honors']=='[]', '0', '1')
# 0    36
# 1    11
# Name: honors_stated, dtype: int64

# %%
#PUBLICATIONS
profiles_explo_2['publications'] = (profiles_explo_2['publications'] ).astype(str)
profiles_explo_2['pubs_stated']=np.where(profiles_explo_2['publications']=='[]', '0', '1')
profiles_explo_2['pubs_stated'].value_counts()
# Out:
# /var/folders/5g/jskfzb8j377fh7wl3_rxvkrc0000gn/T/ipykernel_4701/4098475400.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   profiles_explo_2['publications'] = (profiles_explo_2['publications'] ).astype(str)
# /var/folders/5g/jskfzb8j377fh7wl3_rxvkrc0000gn/T/ipykernel_4701/4098475400.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   profiles_explo_2['pubs_stated']=np.where(profiles_explo_2['publications']=='[]', '0', '1')
# 0    32
# 1    15
# Name: pubs_stated, dtype: int64

# %%
#VOLUNTEER
profiles_explo_2['volunteer'] = (profiles_explo_2['volunteer'] ).astype(str)
profiles_explo_2['volunteer_stated']=np.where(profiles_explo_2['volunteer']=='[]', '0', '1')
profiles_explo_2['volunteer_stated'].value_counts()
# Out:
# /var/folders/5g/jskfzb8j377fh7wl3_rxvkrc0000gn/T/ipykernel_4701/4089623348.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   profiles_explo_2['volunteer'] = (profiles_explo_2['volunteer'] ).astype(str)
# /var/folders/5g/jskfzb8j377fh7wl3_rxvkrc0000gn/T/ipykernel_4701/4089623348.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   profiles_explo_2['volunteer_stated']=np.where(profiles_explo_2['volunteer']=='[]', '0', '1')
# 0    31
# 1    16
# Name: volunteer_stated, dtype: int64

# %%
#PROJECTS
profiles_explo_2['projects'] = (profiles_explo_2['projects'] ).astype(str)
profiles_explo_2['projects_stated']=np.where(profiles_explo_2['projects']=='[]', '0', '1')
profiles_explo_2['projects_stated'].value_counts()
# Out:
# /var/folders/5g/jskfzb8j377fh7wl3_rxvkrc0000gn/T/ipykernel_4701/1493996562.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   profiles_explo_2['projects'] = (profiles_explo_2['projects'] ).astype(str)
# /var/folders/5g/jskfzb8j377fh7wl3_rxvkrc0000gn/T/ipykernel_4701/1493996562.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   profiles_explo_2['projects_stated']=np.where(profiles_explo_2['projects']=='[]', '0', '1')
# 0    26
# 1    21
# Name: projects_stated, dtype: int64

# %%
# CERTIFICATIONS
profiles_explo_2['certifications'] = (profiles_explo_2['certifications'] ).astype(str)
profiles_explo_2['certifications_stated']=np.where(profiles_explo_2['certifications']=='[]', '0', '1')
profiles_explo_2['certifications_stated'].value_counts()
# Out:
# /var/folders/5g/jskfzb8j377fh7wl3_rxvkrc0000gn/T/ipykernel_4701/3917862411.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   profiles_explo_2['certifications'] = (profiles_explo_2['certifications'] ).astype(str)
# /var/folders/5g/jskfzb8j377fh7wl3_rxvkrc0000gn/T/ipykernel_4701/3917862411.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   profiles_explo_2['certifications_stated']=np.where(profiles_explo_2['certifications']=='[]', '0', '1')
# 0    37
# 1    10
# Name: certifications_stated, dtype: int64

# %%
# LANGUAGE_COUNT
profiles_explo_2['languages'] = (profiles_explo_2['languages']).astype(str)
profiles_explo_2['languages3'] = (profiles_explo_2['languages3']).astype(str)
profiles_explo_2['languages_over2']=np.where(profiles_explo_2['languages3']=='nan', '0', '1')
profiles_explo_2['languages_over2'].value_counts()
# Out:
# /var/folders/5g/jskfzb8j377fh7wl3_rxvkrc0000gn/T/ipykernel_4701/3974138507.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   profiles_explo_2['languages'] = (profiles_explo_2['languages']).astype(str)
# /var/folders/5g/jskfzb8j377fh7wl3_rxvkrc0000gn/T/ipykernel_4701/3974138507.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   profiles_explo_2['languages3'] = (profiles_explo_2['languages3']).astype(str)
# /var/folders/5g/jskfzb8j377fh7wl3_rxvkrc0000gn/T/ipykernel_4701/3974138507.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   profiles_explo_2['languages_over2']=np.where(profiles_explo_2['languages3']=='nan', '0', '1')
# 1    24
# 0    23
# Name: languages_over2, dtype: int64

# %%
# LANGUAGES
profiles_explo_2['languages_stated']=np.where(profiles_explo_2['languages']=='[]', '0', '1')
profiles_explo_2['languages_stated'].value_counts()
# Out:
# /var/folders/5g/jskfzb8j377fh7wl3_rxvkrc0000gn/T/ipykernel_4701/2128251405.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   profiles_explo_2['languages_stated']=np.where(profiles_explo_2['languages']=='[]', '0', '1')
# 1    32
# 0    15
# Name: languages_stated, dtype: int64

# %%
# DROPPING THE COLUMNS WE HAVE RECODED 
profiles_explo_2.drop(columns=['languages1', 'languages2',
       'languages3', 'languages4', 'languages5', 'languages6', 'languages7'], inplace=True)
# Out:
# /var/folders/5g/jskfzb8j377fh7wl3_rxvkrc0000gn/T/ipykernel_4701/3414638624.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   profiles_explo_2.drop(columns=['languages1', 'languages2',

# %% [markdown]
# Notes for later :
# * there is surely a better way to deal with the languages, publications, honors, volunteers, project and certifications information. However, we have so many missing values that a yes/no column for each of these categories (filled or not) already provides some information.
# * the languages category could be split in different ways. We chose to highlight the profiles who state 3 or more languages spoken. For this category, the name of languages could be treated as text.
#
# **Important**
# We should change the import code to not split the languages, publications, honors, volunteers, projects and certification columns, but instead just add a column based on the existing ones.

# %% [markdown]
# ### Dealing with the experience and education columns

# %%
profiles_explo_2.describe()
# Out:
#                                      profile_id lastName firstName  \
# count                                        47       47        47
# unique                                       47       47        41
# top     ACoAAAA615EBaNquQR5gOz_oFr9emeCr0ZNw67M  Brachet   Nicolas
# freq                                          1        1         3
#
#        geoCountryName       geoLocationName               birthDate  \
# count              45                    43                      13
# unique              3                    11                      13
# top            France  Paris, Île-de-France  {'month': 3, 'day': 7}
# freq               38                    15                       1
#
#                                                   summary  \
# count                                                  32
# unique                                                 32
# top     Antoine croit à l’intelligence de tous et à la...
# freq                                                    1
#
#                          industryName  \
# count                              47
# unique                             16
# top     IT Services and IT Consulting
# freq                               10
#
#                                                  headline  \
# count                                                  47
# unique                                                 47
# top     Directeur associé de bluenove, initiateur du m...
# freq                                                    1
#
#                                                experience  ...  \
# count                                                  47  ...
# unique                                                 47  ...
# top     [{'locationName': 'Paris Area, France', 'entit...  ...
# freq                                                    1  ...
#
#                                                education1  \
# count                                                  46
# unique                                                 46
# top     {'entityUrn': 'urn:li:fs_education:(ACoAAAA615...
# freq                                                    1
#
#                                                education2  \
# count                                                  41
# unique                                                 41
# top     {'entityUrn': 'urn:li:fs_education:(ACoAAAA615...
# freq                                                    1
#
#                                                education3 honors_stated  \
# count                                                  35            47
# unique                                                 35             2
# top     {'entityUrn': 'urn:li:fs_education:(ACoAAAA615...             0
# freq                                                    1            36
#
#        pubs_stated volunteer_stated projects_stated certifications_stated  \
# count           47               47              47                    47
# unique           2                2               2                     2
# top              0                0               0                     0
# freq            32               31              26                    37
#
#        languages_over2 languages_stated
# count               47               47
# unique               2                2
# top                  1                1
# freq                24               32
#
# [4 rows x 32 columns]

# %%
profiles_experience=pd.concat([profiles_explo_2, 
pd.DataFrame(profiles_explo_2['experience1'].apply(pd.Series)).add_prefix('exp1_'), 
pd.DataFrame(profiles_explo_2['experience2'].apply(pd.Series)).add_prefix('exp2_'), 
pd.DataFrame(profiles_explo_2['experience3'].apply(pd.Series)).add_prefix('exp3_'), 
pd.DataFrame(profiles_explo_2['experience4'].apply(pd.Series)).add_prefix('exp4_'), 
pd.DataFrame(profiles_explo_2['experience5'].apply(pd.Series)).add_prefix('exp5_')], 
axis=1).reset_index(drop=True)

# %%
profiles_experience= pd.concat([profiles_experience, 
pd.DataFrame(profiles_experience['education1'].apply(pd.Series)).add_prefix('ed1_'), 
pd.DataFrame(profiles_experience['education2'].apply(pd.Series)).add_prefix('ed2_'), 
pd.DataFrame(profiles_experience['education3'].apply(pd.Series)).add_prefix('ed3_')], 
axis=1).reset_index(drop=True)

# %%
print(list(profiles_experience.columns))
# Out:
# ['profile_id', 'lastName', 'firstName', 'geoCountryName', 'geoLocationName', 'birthDate', 'summary', 'industryName', 'headline', 'experience', 'education', 'languages', 'publications', 'certifications', 'volunteer', 'honors', 'projects', 'experience1', 'experience2', 'experience3', 'experience4', 'experience5', 'education1', 'education2', 'education3', 'honors_stated', 'pubs_stated', 'volunteer_stated', 'projects_stated', 'certifications_stated', 'languages_over2', 'languages_stated', 'exp1_locationName', 'exp1_entityUrn', 'exp1_geoLocationName', 'exp1_companyName', 'exp1_timePeriod', 'exp1_description', 'exp1_company', 'exp1_title', 'exp1_companyUrn', 'exp1_companyLogoUrl', 'exp1_$anti_abuse_metadata', 'exp1_geoUrn', 'exp1_region', 'exp1_honors', 'exp1_organizations', 'exp2_entityUrn', 'exp2_companyName', 'exp2_timePeriod', 'exp2_company', 'exp2_title', 'exp2_companyUrn', 'exp2_companyLogoUrl', 'exp2_locationName', 'exp2_geoLocationName', 'exp2_geoUrn', 'exp2_description', 'exp2_region', 'exp2_$anti_abuse_metadata', 'exp2_organizations', 'exp2_projects', 'exp2_honors', 'exp3_locationName', 'exp3_entityUrn', 'exp3_geoLocationName', 'exp3_companyName', 'exp3_timePeriod', 'exp3_company', 'exp3_title', 'exp3_companyUrn', 'exp3_companyLogoUrl', 'exp3_geoUrn', 'exp3_description', 'exp3_region', 'exp3_$anti_abuse_metadata', 'exp3_projects', 'exp4_locationName', 'exp4_entityUrn', 'exp4_geoLocationName', 'exp4_geoUrn', 'exp4_companyName', 'exp4_timePeriod', 'exp4_description', 'exp4_company', 'exp4_title', 'exp4_region', 'exp4_companyUrn', 'exp4_companyLogoUrl', 'exp4_0', 'exp4_projects', 'exp4_$anti_abuse_metadata', 'exp5_locationName', 'exp5_entityUrn', 'exp5_geoLocationName', 'exp5_companyName', 'exp5_timePeriod', 'exp5_description', 'exp5_company', 'exp5_title', 'exp5_companyUrn', 'exp5_companyLogoUrl', 'exp5_geoUrn', 'exp5_honors', 'exp5_region', 'exp5_0', 'exp5_projects', 'exp5_$anti_abuse_metadata', 'exp5_organizations', 'exp1_startDate', 'exp2_startDate', 'exp3_startDate', 'exp4_startDate', 'exp5_startDate', 'exp1_endDate', 'exp2_endDate', 'exp3_endDate', 'exp4_endDate', 'exp5_endDate', 'exp1_startDate_month', 'exp2_startDate_month', 'exp3_startDate_month', 'exp4_startDate_month', 'exp5_startDate_month', 'exp1_startDate_year', 'exp1_endDate_month', 'exp1_endDate_year', 'exp2_startDate_year', 'exp2_endDate_month', 'exp2_endDate_year', 'exp3_startDate_year', 'exp3_endDate_month', 'exp3_endDate_year', 'exp4_startDate_year', 'exp4_endDate_month', 'exp4_endDate_year', 'exp5_startDate_year', 'exp5_endDate_month', 'exp5_endDate_year', 'exp1_industry', 'exp2_industry', 'exp3_industry', 'exp4_industry', 'exp5_industry', 'exp1_company_empl', 'exp2_company_empl', 'exp3_company_empl', 'exp4_company_empl', 'exp5_company_empl', 'exp1_company_empl_low', 'exp1_company_empl_high', 'exp2_company_empl_low', 'exp2_company_empl_high', 'exp3_company_empl_low', 'exp3_company_empl_high', 'exp4_company_empl_low', 'exp4_company_empl_high', 'exp5_company_empl_low', 'exp5_company_empl_high', 'ed1_entityUrn', 'ed1_school', 'ed1_timePeriod', 'ed1_degreeName', 'ed1_schoolName', 'ed1_fieldOfStudy', 'ed1_schoolUrn', 'ed1_activities', 'ed1_description', 'ed1_fieldOfStudyUrn', 'ed1_grade', 'ed1_courses', 'ed1_degreeUrn', 'ed1_0', 'ed1_projects', 'ed1_honors', 'ed2_entityUrn', 'ed2_timePeriod', 'ed2_schoolName', 'ed2_school', 'ed2_fieldOfStudy', 'ed2_schoolUrn', 'ed2_degreeName', 'ed2_0', 'ed2_activities', 'ed2_grade', 'ed2_description', 'ed2_fieldOfStudyUrn', 'ed2_projects', 'ed2_honors', 'ed3_entityUrn', 'ed3_grade', 'ed3_timePeriod', 'ed3_degreeName', 'ed3_schoolName', 'ed3_fieldOfStudy', 'ed3_school', 'ed3_schoolUrn', 'ed3_description', 'ed3_fieldOfStudyUrn', 'ed3_0', 'ed3_activities', 'ed3_degreeUrn', 'ed3_courses', 'ed3_honors']

# %%
for i in range (1,6):
    profiles_experience['exp'+str(i)+'_startDate_month']= (pd.DataFrame(profiles_experience['exp'+str(i)+'_timePeriod'].apply(pd.Series))['startDate']).apply(pd.Series)['month']
    profiles_experience['exp'+str(i)+'_startDate_year']= (pd.DataFrame(profiles_experience['exp'+str(i)+'_timePeriod'].apply(pd.Series))['startDate']).apply(pd.Series)['year']
    profiles_experience['exp'+str(i)+'_endDate_month']= (pd.DataFrame(profiles_experience['exp'+str(i)+'_timePeriod'].apply(pd.Series))['endDate']).apply(pd.Series)['month']
    profiles_experience['exp'+str(i)+'_endDate_year']= (pd.DataFrame(profiles_experience['exp'+str(i)+'_timePeriod'].apply(pd.Series))['endDate']).apply(pd.Series)['year']
    profiles_experience['exp'+str(i)+'_industry']= str(pd.DataFrame(profiles_experience['exp1_company'].apply(pd.Series))['industries'])
    profiles_experience['exp'+str(i)+'_company_empl_low']= (pd.DataFrame(profiles_experience['exp1_company'].apply(pd.Series))['employeeCountRange']).apply(pd.Series)['start']
    profiles_experience['exp'+str(i)+'_company_empl_high']= (pd.DataFrame(profiles_experience['exp1_company'].apply(pd.Series))['employeeCountRange']).apply(pd.Series)['end']

# %%
for i in range (1,4):
    profiles_experience['ed'+str(i)+'_startDate_month']= (pd.DataFrame(profiles_experience['ed'+str(i)+'_timePeriod'].apply(pd.Series))['startDate']).apply(pd.Series)['month']
    profiles_experience['ed'+str(i)+'_startDate_year']= (pd.DataFrame(profiles_experience['ed'+str(i)+'_timePeriod'].apply(pd.Series))['startDate']).apply(pd.Series)['year']

# %%
profiles_experience.head()
# Out:
#                                 profile_id  lastName firstName geoCountryName  \
# 0  ACoAAAA615EBaNquQR5gOz_oFr9emeCr0ZNw67M   Brachet   Antoine         France
# 1  ACoAAAfK9YwBjZr16cDaVuxZICOg0QUnbPiUoXE     Demri     Bobby         France
# 2  ACoAAAUn_5ABqO0mSShQxo4gFyTaCDoaYUk5Fm8   Durieux     Sarah         France
# 3  ACoAAARi9fcBfH1GjbFHnWc1QqHftfh3LQjRUEg   Jaillot   Bastien         France
# 4  ACoAAApOhv4B3_GF-OGg8-ipxxkMf6AOggWigl8  Vanneroy    Coline         France
#
#                      geoLocationName birthDate  \
# 0  Greater Paris Metropolitan Region       NaN
# 1               Paris, Île-de-France       NaN
# 2               Paris, Île-de-France       NaN
# 3  Greater Paris Metropolitan Region       NaN
# 4  Greater Paris Metropolitan Region       NaN
#
#                                              summary  \
# 0  Antoine croit à l’intelligence de tous et à la...
# 1  French Entrepreneur - Founder and Managing Par...
# 2  Inspired by the power we can build to change t...
# 3  IT Consultant, Technical Expert, Lead develope...
# 4                                                NaN
#
#                                     industryName  \
# 0                  IT Services and IT Consulting
# 1  Venture Capital and Private Equity Principals
# 2                 Civic and Social Organizations
# 3                  IT Services and IT Consulting
# 4                  IT Services and IT Consulting
#
#                                             headline  \
# 0  Directeur associé de bluenove, initiateur du m...
# 1        Founder & Managing Partner at ROCH Ventures
# 2  Co-director Multitudes Foundation - Activist a...
# 3                           Web expert chez Jolicode
# 4       Directrice des opérations chez Cap Collectif
#
#                                           experience  ... ed3_activities  \
# 0  [{'locationName': 'Paris Area, France', 'entit...  ...            NaN
# 1  [{'entityUrn': 'urn:li:fs_position:(ACoAAAfK9Y...  ...            NaN
# 2  [{'entityUrn': 'urn:li:fs_position:(ACoAAAUn_5...  ...            NaN
# 3  [{'entityUrn': 'urn:li:fs_position:(ACoAAARi9f...  ...            NaN
# 4  [{'entityUrn': 'urn:li:fs_position:(ACoAAApOhv...  ...            NaN
#
#   ed3_degreeUrn ed3_courses ed3_honors ed1_startDate_month ed1_startDate_year  \
# 0           NaN         NaN        NaN                 NaN             1998.0
# 1           NaN         NaN        NaN                 NaN             2006.0
# 2           NaN         NaN        NaN                 3.0             2022.0
# 3           NaN         NaN        NaN                 NaN             2004.0
# 4           NaN         NaN        NaN                 NaN             2005.0
#
#   ed2_startDate_month ed2_startDate_year ed3_startDate_month  \
# 0                 NaN             1996.0                 NaN
# 1                 NaN             2005.0                 NaN
# 2                 9.0             2020.0                 9.0
# 3                 NaN                NaN                 NaN
# 4                 NaN             2002.0                 NaN
#
#   ed3_startDate_year
# 0             1993.0
# 1             1998.0
# 2             2020.0
# 3                NaN
# 4                NaN
#
# [5 rows x 210 columns]

# %%
print(list(profiles_experience.columns))
# Out:
# ['profile_id', 'lastName', 'firstName', 'geoCountryName', 'geoLocationName', 'birthDate', 'summary', 'industryName', 'headline', 'experience', 'education', 'languages', 'publications', 'certifications', 'volunteer', 'honors', 'projects', 'experience1', 'experience2', 'experience3', 'experience4', 'experience5', 'education1', 'education2', 'education3', 'honors_stated', 'pubs_stated', 'volunteer_stated', 'projects_stated', 'certifications_stated', 'languages_over2', 'languages_stated', 'exp1_locationName', 'exp1_entityUrn', 'exp1_geoLocationName', 'exp1_companyName', 'exp1_timePeriod', 'exp1_description', 'exp1_company', 'exp1_title', 'exp1_companyUrn', 'exp1_companyLogoUrl', 'exp1_$anti_abuse_metadata', 'exp1_geoUrn', 'exp1_region', 'exp1_honors', 'exp1_organizations', 'exp2_entityUrn', 'exp2_companyName', 'exp2_timePeriod', 'exp2_company', 'exp2_title', 'exp2_companyUrn', 'exp2_companyLogoUrl', 'exp2_locationName', 'exp2_geoLocationName', 'exp2_geoUrn', 'exp2_description', 'exp2_region', 'exp2_$anti_abuse_metadata', 'exp2_organizations', 'exp2_projects', 'exp2_honors', 'exp3_locationName', 'exp3_entityUrn', 'exp3_geoLocationName', 'exp3_companyName', 'exp3_timePeriod', 'exp3_company', 'exp3_title', 'exp3_companyUrn', 'exp3_companyLogoUrl', 'exp3_geoUrn', 'exp3_description', 'exp3_region', 'exp3_$anti_abuse_metadata', 'exp3_projects', 'exp4_locationName', 'exp4_entityUrn', 'exp4_geoLocationName', 'exp4_geoUrn', 'exp4_companyName', 'exp4_timePeriod', 'exp4_description', 'exp4_company', 'exp4_title', 'exp4_region', 'exp4_companyUrn', 'exp4_companyLogoUrl', 'exp4_0', 'exp4_projects', 'exp4_$anti_abuse_metadata', 'exp5_locationName', 'exp5_entityUrn', 'exp5_geoLocationName', 'exp5_companyName', 'exp5_timePeriod', 'exp5_description', 'exp5_company', 'exp5_title', 'exp5_companyUrn', 'exp5_companyLogoUrl', 'exp5_geoUrn', 'exp5_honors', 'exp5_region', 'exp5_0', 'exp5_projects', 'exp5_$anti_abuse_metadata', 'exp5_organizations', 'exp1_startDate', 'exp2_startDate', 'exp3_startDate', 'exp4_startDate', 'exp5_startDate', 'exp1_endDate', 'exp2_endDate', 'exp3_endDate', 'exp4_endDate', 'exp5_endDate', 'exp1_startDate_month', 'exp2_startDate_month', 'exp3_startDate_month', 'exp4_startDate_month', 'exp5_startDate_month', 'exp1_startDate_year', 'exp1_endDate_month', 'exp1_endDate_year', 'exp2_startDate_year', 'exp2_endDate_month', 'exp2_endDate_year', 'exp3_startDate_year', 'exp3_endDate_month', 'exp3_endDate_year', 'exp4_startDate_year', 'exp4_endDate_month', 'exp4_endDate_year', 'exp5_startDate_year', 'exp5_endDate_month', 'exp5_endDate_year', 'exp1_industry', 'exp2_industry', 'exp3_industry', 'exp4_industry', 'exp5_industry', 'exp1_company_empl', 'exp2_company_empl', 'exp3_company_empl', 'exp4_company_empl', 'exp5_company_empl', 'exp1_company_empl_low', 'exp1_company_empl_high', 'exp2_company_empl_low', 'exp2_company_empl_high', 'exp3_company_empl_low', 'exp3_company_empl_high', 'exp4_company_empl_low', 'exp4_company_empl_high', 'exp5_company_empl_low', 'exp5_company_empl_high', 'ed1_entityUrn', 'ed1_school', 'ed1_timePeriod', 'ed1_degreeName', 'ed1_schoolName', 'ed1_fieldOfStudy', 'ed1_schoolUrn', 'ed1_activities', 'ed1_description', 'ed1_fieldOfStudyUrn', 'ed1_grade', 'ed1_courses', 'ed1_degreeUrn', 'ed1_0', 'ed1_projects', 'ed1_honors', 'ed2_entityUrn', 'ed2_timePeriod', 'ed2_schoolName', 'ed2_school', 'ed2_fieldOfStudy', 'ed2_schoolUrn', 'ed2_degreeName', 'ed2_0', 'ed2_activities', 'ed2_grade', 'ed2_description', 'ed2_fieldOfStudyUrn', 'ed2_projects', 'ed2_honors', 'ed3_entityUrn', 'ed3_grade', 'ed3_timePeriod', 'ed3_degreeName', 'ed3_schoolName', 'ed3_fieldOfStudy', 'ed3_school', 'ed3_schoolUrn', 'ed3_description', 'ed3_fieldOfStudyUrn', 'ed3_0', 'ed3_activities', 'ed3_degreeUrn', 'ed3_courses', 'ed3_honors', 'ed1_startDate_month', 'ed1_startDate_year', 'ed2_startDate_month', 'ed2_startDate_year', 'ed3_startDate_month', 'ed3_startDate_year']

# %%
list_columns=[i for i in profiles_experience.columns if ("Urn" in i or "Logo" in i or "_region" in i or '_abuse' in i or '_geo' in i or '_proj' in i or '_organi' in i or '_0' in i)]
#to check before dropping 
# profiles_experience[list_columns]
profiles_experience.drop(columns=list_columns, inplace=True)

# %% [markdown]
# ## Exporting

# %%
profiles_experience.to_csv("profile_data_reprocessed.csv", sep=';', index=False)
